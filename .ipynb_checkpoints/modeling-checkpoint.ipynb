# %% [markdown]
# # create models from ASVset genome objects

# %%
from load_genomes_to_modelseedpy import GenomeLoader
from cobra.io import write_sbml_model
# from glob import glob
from tqdm import tqdm
import os

loader = GenomeLoader()
# genome_ids = loader.list_available_genomes()#[:10]

def write_model(gID):
    model = loader.build_model(gID, printing=False)
    write_sbml_model(model, f'models/{gID}.xml')

# for genome_id in tqdm(genome_ids):
#     model_path = f'models/{genome_id}.xml'
#     if os.path.exists(model_path):  continue
#     try:
#         model = loader.build_model(genome_id, printing=False)
#         write_sbml_model(model, model_path)
#         # print(f"✓ {genome_id}") 
#     except Exception as e:
#         print(f"✗ {genome_id}: {e}")


# parallelize the effort
args = [gID for gID in loader.list_available_genomes() if not os.path.exists(f'models/{gID}.xml')]#[:2]
print(len(args), "will be processed")
parallelize = False
if parallelize:
    from multiprocess import Pool
    from os import cpu_count
    
    cpus = int(cpu_count()/8)
    print(f"{cpus} cores are being used.  The first argument is {args[0]}")
    pool = Pool(cpus)
    outputs = pool.map(write_model, args)
    
    print(f"missing iterativeIDs", missing_iterativeIDs)
    print(f"missing IDs", missing_IDs)
else:
    for arg in args:
        # print(arg)
        write_model(arg)
# Out:
# 100%|██████████| 1698/1698 [1:21:00<00:00,  2.86s/it]

# %% [markdown]
# # create community models from the member models and abundances

# %%
from cobra.io import read_sbml_model, write_sbml_model
from pandas import read_csv, Series
from mscommunity import MSCommunity
from tqdm import tqdm
from json import load
import os

# ab_df = read_csv("model_inputs/abundances.csv").set_index("seq")
# for sample in ab_df.columns:
#     print(sample, end=" ")
#     sample_abundances = ab_df[ab_df[sample] > 0]
#     print(len(sample_abundances))
iterativeIDs = load(open("modeling_files/iterativeIDs.json", 'r'))
ASV_sets = load(open("modeling_files/ASV_sets.json", 'r'))
redunant_asvs = {v:k for k,vs in ASV_sets.items() for v in vs}
abundances = load(open("modeling_files/ASVset_abundances.json", 'r'))
# missing_members = []
# for sample, ASVabun in tqdm(abundances.items()):
#     if os.path.exists(f"models/{sample}_comm.xml"):
#         continue
#     models = []
#     for ASV, abun in ASVabun.items():
#         ASVset = iterativeIDs[redunant_asvs.get(ASV, ASV)]
#         model_path = f"models/{ASVset}.xml"
#         #TODO:  investigate why these ASVs did not have any genomeIDs
#         if not os.path.exists(model_path):  # some ASVs have no genomeIDs
#             continue
            
#         # try:
#         model = read_sbml_model(model_path)
#         # except:
#         models.append(model)
#     comm = MSCommunity(member_models=models)
#     write_sbml_model(comm.util.model, f"models/{sample}_comm.xml")


def create_comm(item):
    sample = item[0]
    models = []
    for ASV, abun in item[1].items():
        ASVset = iterativeIDs[redunant_asvs.get(ASV, ASV)]
        model_path = f"models/{ASVset}.xml"
        #TODO:  investigate why these ASVs did not have any genomeIDs
        if not os.path.exists(model_path):  # some ASVs have no genomeIDs
            continue
            
        # try:
        model = read_sbml_model(model_path)
        # except:
        models.append(model)
    comm = MSCommunity(member_models=models)
    write_sbml_model(comm.util.model, f"models/{sample}_comm.xml")

# parallelize the effort
args = list([item for item in abundances.items() if not os.path.exists(f"models/{item[0]}_comm.xml")])
print(len(args), "will be processed")
parallelize = True
if parallelize:
    from multiprocess import Pool
    from os import cpu_count
    
    cpus = min(len(args), int(cpu_count()/8))
    print(f"{cpus} cores are being used.  The first argument is {args[0]}")
    pool = Pool(cpus)
    outputs = pool.map(create_comm, args)
    
    print(f"missing iterativeIDs", missing_iterativeIDs)
    print(f"missing IDs", missing_IDs)
else:
    for arg in args:
        # print(arg)
        create_comm(arg)
# Out:
# 16 will be processed
# 16 cores are being used.  The first argument is ('C3', {'7f78afb7e1d45cd528fe9cd909c93fb5': 0.002491889872193666, '0fec351445f84bd482075ceda6123f46': 0.2580847663227067, '38b371de3be6ddef03bea94294e9830d': 0.03002708160249733, '63f37ee4b481fccdffca10160ed5b944': 0.03608264194234495, '35dbde30af820a2c3bcd85216229ad6a': 0.017615479571591992, 'd3cf08daefed96f494257ceff63a6cf8': 0.005776131827066854, 'a5b2537343a26f4daf0379a8b46eb2ef': 0.014099656454003483, '04869be25e3dc4d526ce3824d407aedf': 0.00887089828608216, '3343d19c0bc1759a66023cbc86c92592': 0.002951224418820203, 'c55a8101fb6c187736f0af61f720cb92': 0.10712638401711012, 'ec92f6331d8ecb50e3f0dee8fbf3bcb0': 0.030450052155473202, 'ea156f972cd3802c3fac147e4200ba7a': 0.0017875769120343642, '4bea53b2aad77f2569a0182f6b84255e': 0.0115312108257056, '83adaf3a09d08c93f2abea6a4c815592': 0.03351993798725384, '0709277372b3816e3986842fb10c8e96': 0.006700542593526704, 'e6485d233ed2b8b9a2f3f50f0747b9d2': 0.0039866410206298225, 'b4eac52cfa36ce63f24be2fc530ad204': 0.001266997774526167, '499a635c6e7dcd5c8ef518302aa50011': 0.0020019330351269114, '93fadef301b62aa732e42bf1142b3afa': 0.008105340725039973, 'd42912a22b570ab99938b745999ae2cc': 0.014044153536328598, 'c571cb007a7d9e2dfc56e8c0b4e24104': 0.0016229820334099265, '8466f2635d9fbf9c51a04877474f3d09': 0.032507488108275, '01a7c19fe64d4300e6e5a8a7280a10bb': 0.006166566185198614, '9feda0d620fa50b57ce3f848e1b48975': 0.015194403772294545, 'b3d8bf326297fb9b18ea4fef1ce8d4a6': 0.004627795485503573, '430c875622713c0d7662add2d8e7db60': 0.002532081644648442, 'deb262fd92af4fdcd3b6240303048b2a': 0.002516770499428333, '25c54c57b4a4283237b33fdae82003c0': 0.01401927290909393, '1f4fb4bfdca6c9d13106ed533362a62e': 0.0038430989804347187, '28f1a500a5a6ebd1cede9322b50bcaad': 0.0030162968085084216, 'a82691ab5fd4e8d3d3b23b7958c8e764': 0.008920659520549046, '113b0d8ebf97fc5aba85fa06ecfdbb1a': 0.008622092073742838, '868a2dd217365ddd6d6ab64d48aeed4a': 0.001272739447732942, '4e4ca97fadb8b8e92470ccce2ff91460': 0.001469870521201489, '6aa300d5323cbf75dc53cec3e6acb87c': 0.0018507354173211408, '5631fe818e588992529f6071afc9cda5': 0.0037952516303692754, 'e8e82cf023a3abd684fe7e817acc9bf0': 0.0050335409888554415, '37a9f9625f201b6e61c29ac09ec54683': 0.03867596818787628, '212e304679f170a464d2616b3f94a250': 0.0018067158560610315, '0eff2f70a09cbdfd1a1684adcb990931': 0.0029301715803908696, 'e357ec372ce3fdd9cc473b8f57edc002': 0.001469870521201489, '181a2b6fbc1d5f5de022772f08fb875c': 0.008289074537689853, '99daab1404e1c027be5dce96473d53ab': 0.0010296749286028439, '33e423de05448134722fcf4bd6a224d7': 0.001477526098812156, '206069e5a5041e6c7f39a4141aefdc19': 0.002759835028559657, '472fdc0687378563f0c9da6da7638e1a': 0.009791481253735452, 'd3156233792852376762d588f607ac71': 0.002669882011636771, '1351e87aa6c89a114e5104be8fe7c817': 0.001272739447732942, '60da7a21ae2997bc70a9730fd8151a29': 0.002202891897400792, '8e6faab8acc1bdcba46f098a739aec14': 0.003971329865408489, 'e75fd72fb216d3d4c964602d8c338f65': 0.008176154797936193, 'be9dcf562f0ab066c0b252d527a42d19': 0.003205772304366302, '826b2dad200d99cccec78d01acb38da4': 0.004365592012345583, '4c31c3e198534eab45b6d92b61f75b10': 0.07345716226644829, 'a039c1ac15b3f4bc5cf1db8a5f1cc0fd': 0.03900515794512515, 'b7806c4f83108800a9c32dc83c148d95': 0.001517717871266932, '58b2cf308363fb35b932620518786116': 0.001165561391187281, 'abaecd8b82d14efc7ccc4dcb7f864cba': 0.002677537579246213, '02809af9a001c44a58624822e0e44569': 0.0010947473182910624, '01bc6f144e0f577c7a5364ebafdb3509': 0.0021091110916725726, 'c7553191e309cfc2e28aea2507e7afdf': 0.0023579173040118957, 'c88944b6267ea10d43d5ee264d29ae94': 0.002953138303221645, 'e144d237c973d831d708cac2c17df968': 0.007879501235531427, 'a43c475502b54cdee1385dcca3109bfe': 0.001511976188058932, '7f1023e871bcd3a4f7ac96f3a40c9a8d': 0.0021033694084645724})
# bio1 from  becomes bio2
# bio1 from  becomes bio3
# bio1 from  becomes bio4
# bio1 from  becomes bio5
# bio1 from  becomes bio6
# bio1 from  becomes bio7
# bio1 from  becomes bio8
# bio1 from  becomes bio9
# bio1 from  becomes bio10
# bio1 from  becomes bio11
# bio1 from  becomes bio12
# bio1 from  becomes bio13
# bio1 from  becomes bio14
# bio1 from  becomes bio15
# bio1 from  becomes bio2
# bio1 from  becomes bio3
# bio1 from  becomes bio16
# bio1 from  becomes bio4
# bio1 from  becomes bio5
# bio1 from  becomes bio17
# bio1 from  becomes bio18
# bio1 from  becomes bio19
# bio1 from  becomes bio20
# bio1 from  becomes bio6
# bio1 from  becomes bio21
# bio1 from  becomes bio7
# bio1 from  becomes bio22
# bio1 from  becomes bio8
# bio1 from  becomes bio9
# bio1 from  becomes bio23
# bio1 from  becomes bio10
# bio1 from  becomes bio24
# bio1 from  becomes bio11
# bio1 from  becomes bio25
# bio1 from  becomes bio2
# bio1 from  becomes bio12
# bio1 from  becomes bio13
# bio1 from  becomes bio26
# bio1 from  becomes bio14
# bio1 from  becomes bio2
# bio1 from  becomes bio27
# bio1 from  becomes bio15
# bio1 from  becomes bio16
# bio1 bio1from  from  becomes  becomes bio3bio28
#
# bio1 from  becomes bio3
# bio1 from  becomes bio4
# bio1 from  becomes bio2
# bio1 from  becomes bio5
# bio1 from  becomes bio2
# bio1 from  becomes bio6
# bio1 from  becomes bio4
# bio1 from  becomes bio3
# bio1 from  becomes bio5
# bio1 from  becomes bio2
# bio1 from  becomes bio2
# bio1 from  becomes bio6
# bio1 from  becomes bio4
# bio1 from  becomes bio7
# bio1 from  becomes bio5
# bio1 from  becomes bio3
# bio1 from  becomes bio6
# bio1 from  becomes bio7
# bio1 from  becomes bio3
# bio1 from  becomes bio17
# bio1 from  becomes bio3
# bio1 from  becomes bio4
# bio1 from  becomes bio5
# bio1 from  becomes bio4
# bio1 from  becomes bio8
# bio1 from  becomes bio18
# bio1 from  becomes bio8
# bio1 from  becomes bio5
# bio1 from  becomes bio6
# bio1 from  becomes bio7
# bio1 from  becomes bio4
# bio1 from  becomes bio9
# bio1 from  becomesbio1  bio7from
#   becomes bio19
# bio1 from  becomes bio5
# bio1 from  bio1becomes  frombio9
#  becomes bio6
# bio1 from  becomes bio10
# bio1 from  becomes bio6
# bio1 from  becomes bio8
# bio1 from  becomes bio20
# bio1 from  becomes bio10
# bio1 from  becomes bio11
# bio1 from  becomes bio7
# bio1 from  becomes bio12
# bio1 from  becomes bio11
# bio1 from  becomes bio8
# bio1 from  becomes bio7
# bio1 from  becomes bio8
# bio1 from  becomes bio21
# bio1 from  becomes bio9
# bio1 from  becomes bio9
# bio1 from  becomes bio9
# bio1 from  becomes bio12
# bio1 from  becomes bio22
# bio1 from  becomes bio10
# bio1 from  becomes bio10
# bio1 from  becomes bio13
# bio1 from  becomes bio23
# bio1bio1  fromfrom    becomesbecomes  bio11
# bio13
# bio1 from  becomes bio14
# bio1 from  becomes bio14
# bio1 from  becomes bio8
# bio1 from  becomes bio10
# bio1bio1  fromfrom    becomesbecomes  bio15bio9
#
# bio1 from  becomes bio11
# bio1 from  becomes bio11
# bio1 from  becomes bio12
# bio1 from  becomes bio24
# bio1 from  becomes bio2
# bio1 from  becomes bio10
# bio1 from  becomes bio13
# bio1 from  becomes bio1bio16
# from  becomes bio12bio1
#  from  becomes bio12
# bio1 from  becomes bio17
# bio1 from  becomes bio11
# bio1 frombio1   frombecomes   bio15becomes
#  bio14
# bio1 from  becomes bio25
# bio1 from  becomes bio16
# bio1 from  becomes bio13
# bio1 from  becomes bio14
# bio1 from  becomes bio3
# bio1 from  becomes bio12
# bio1 from  becomes bio15
# bio1 from  becomes bio15
# bio1 from  becomesbio1  bio18from
#   becomes bio16
# bio1 from  becomes bio13
# bio1 from  becomes bio13
# bio1 from  becomes bio26
# bio1 frombio1   frombecomes   bio17becomes
#  bio14
# bio1 from  becomes bio4
# bio1 from  becomes bio16
# bio1 from  bio1becomes  frombio15
#  becomes bio19
# bio1 from  becomes bio16
# bio1 from  becomes bio27
# bio1 from  becomes bio14
# bio1 from  becomes bio17
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio28
# bio1 from  becomes bio5
# bio1 from  becomesbio1  bio18from
#  bio1  becomesfrom  bio17
# becomes bio15
# bio1 from  becomes bio6
# bio1 from  becomes bio7
# bio1 from  becomes bio17
# bio1 from  becomes bio18
# bio1 from  becomes bio8
# bio1 from  becomes bio20
# bio1 from  becomes bio19
# bio1 from  becomes bio2
# bio1 from  bio1becomes  frombio18
#  becomes bio16
# bio1 from  becomes bio18
# bio1 from  becomes bio21
# bio1 from  becomes bio29
# bio1 from  becomes bio9
# bio1 from  becomes bio17
# bio1 from  becomes bio19
# bio1 from  becomes bio30
# bio1 from  becomes bio22
# bio1 from  becomes bio19
# bio1 from  becomes bio3
# bio1 from  becomes bio20
# bio1 from  becomes bio10
# bio1 from  becomes bio31
# bio1 from  becomes bio19
# bio1 from  becomes bio23bio1
#  from  becomes bio21
# bio1 from  becomes bio11
# bio1 from  becomes bio4
# bio1 from  becomes bio18
# bio1 from  becomes bio32
# bio1 from  becomes bio5
# bio1 from  becomes bio12
# bio1 from  becomes bio6
# bio1 from  becomes bio20
# bio1 from  becomes bio20
# bio1 from  becomes bio33
# bio1 from  becomes bio19
# bio1 from  becomes bio24
# bio1 from  becomes bio22
# bio1 from  becomes bio13
# bio1 from  becomes bio20
# bio1 from  becomes bio21
# bio1 from  becomes bio2
# bio1 from  becomes bio20
# bio1 from  becomes bio21
# bio1 from  becomes bio23
# bio1 from  becomes bio7
# bio1 from  becomes bio25
# bio1 from  becomes bio22
# bio1 from  becomes bio3
# bio1 bio1from  from  becomes  becomesbio8
# bio22
# bio1 from  becomes bio21
# bio1 from  becomes bio24
# bio1 from  becomes bio23
# bio1 from  becomes bio22
# bio1 from  becomes bio14
# bio1 from  becomes bio23
# bio1 from  becomes bio15
# bio1 from  becomes bio21
# bio1 from  becomes bio23
# bio1 from bio1  becomesfrom  bio25
# becomes bio16
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++
# bio1 from  becomes bio26
#  biomass compound: cpd11416_c27
# c27
# bio1 from  becomes bio9
# bio1 from  becomes bio22
# bio1 from  becomes bio17
# bio1 from  becomes bio27
# bio1 from  becomes created atp hydrolysis reaction rxn00062_c27 for bio4
#
# Making biomass drain reaction for species:
# bio1 from  becomes bio10
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++
# bio1 from  becomes bio18
# bio1 from  becomes bio11
# bio1 from  becomes bio23
# bio1 from  becomes bio24
# bio1 from  becomes bio24
# bio1 from  becomes bio5
# bio1 from  becomes bio24
# bio1 from bio1  becomesfrom  bio12
# becomes bio19
# bio1 from  becomes bio20
# bio1 from  becomes bio28
# bio1 from  becomes bio6
# bio1 from  becomes bio7
# bio1 from  becomes bio25
# bio1 frombio1   frombecomes   becomesbio2
# bio13
# bio1 from  becomes bio8
# bio1 from  becomes bio24
# bio1 from  becomes bio2
# bio1 from  becomes bio14
# bio1 from  becomes bio25
# bio1 from  becomes bio26
# bio1 frombio1   frombecomes   bio25becomes
#  bio21
# bio1 from  becomes bio26
# bio1bio1  fromfrom    becomesbecomes  bio3bio29
#
# bio1 from  becomes bio15
# bio1 from  becomes bio4
# bio1 from  becomes bio22
# bio1 from  becomes bio3
# bio1 frombio1   frombecomes   bio5becomes
#  bio27
# bio1 from  becomes bio9
# bio1 from  becomes bio25
# bio1 from  becomes bio16
# bio1 from  becomes bio6
# bio1 from  becomes bio26
# bio1 from  becomes bio27
# bio1 from  becomes bio26
# bio1 from  becomes bio17
# bio1 from  becomes bio10
# bio1 from  becomes bio27
# bio1 from  becomes bio4bio1
#  from  becomes bio30
# bio1 from  becomes bio28
# bio1 from  becomes bio23
# bio1 from bio1  becomes from bio26
# becomes bio28
# bio1 from  becomes bio11
# bio1 from  becomes bio29
# bio1 from  becomes bio27
# bio1 from  becomes bio7
# bio1 from  becomes bio31
# bio1 from  becomesbio1  bio18from
#   becomes bio5
# bio1 from  becomes bio12
# bio1 from  becomes bio28
# bio1 from  becomes bio27
# bio1 from  becomes bio24
# bio1 from  becomes bio32
# bio1 from  becomesbio1  bio29from
#   becomes bio6
# bio1 frombio1   frombecomes   bio8
# becomes bio7
# bio1 from  becomes bio28
# bio1 from  becomes bio19
# bio1 from  becomes bio28
# bio1 from  becomes bio8
# bio1 from  becomes bio30
# bio1 from  becomes bio2bio1
#  from  becomes bio9
# bio1 from  becomes bio30
# bio1 from  becomes bio29
# bio1 from  becomes bio13
# bio1 from  becomes bio10
# bio1 from  becomes bio33
# bio1 frombio1  from  becomes  becomesbio29
# bio31
# bio1 from  becomes bio14
# bio1 from  becomes bio25
# bio1 from  becomes bio20
# bio1 from  becomes bio3
# bio1 from  becomes bio11
# bio1 from  becomes bio29
# bio1 from  becomes bio9
# bio1 frombio1   becomesfrom  bio4
# becomes bio15
# bio1 bio1from  from   becomesbecomes  bio31bio26
#
# bio1 frombio1   frombecomes   bio12becomes
#  bio1bio34
# from  becomes bio30
# bio1 from  becomes bio5
# bio1 from  becomes bio21
# bio1 from  becomes bio30
# bio1 from  becomes bio6
# bio1 from  becomes bio16
# bio1 from  becomes bio27bio1
#  frombio1   frombecomes   bio17becomes
#  bio10
# bio1 from  becomes bio18
# bio1 from  becomes bio32
# bio1 bio1from  from   becomesbecomes  bio2bio31
#
# bio1 from  becomes bio30
# bio1 from  becomes bio22bio1
#  from  becomes bio11
# bio1 from  becomes bio31
# bio1 from bio1  becomesfrom  bio32
# becomes bio33
# bio1 from  becomes bio32
# bio1 frombio1  from  becomes  becomesbio2
# bio28
# bio1 from  becomes bio19
# bio1 frombio1   frombecomes   bio31becomes
#  bio35
# bio1 from  becomes bio12
# bio1 bio1from   frombecomes   bio33becomes
#  bio34
# bio1 from  becomes bio3
# bio1 from  becomes bio36
# bio1 from  becomes bio32
# bio1 from  becomes bio13bio1
#  from  becomes bio37
# bio1 from  becomes bio35
# bio1 from  becomes bio1 bio33from
#   becomes bio34bio1
#  from  becomes bio20
# bio1 from  becomes bio32
# bio1 from  becomes bio23
# bio1 from  becomes bio14
# bio1 from  becomes bio36
# bio1 from  becomes bio33
# bio1 from  becomes bio38
# bio1 from  becomes bio24
# bio1 from  becomes bio34
# bio1 from  becomes bio15
# bio1 from  becomes bio34
# bio1 from  becomes bio39
# bio1 from  becomes bio7
# bio1 from  becomes bio33
# bio1 frombio1   frombecomes   bio16becomes
#  bio4
# bio1 from  becomes bio13
# bio1 from  becomes bio5
# bio1 from  becomes bio3
# bio1 from  becomes bio29
# bio1 from  becomes bio34
# bio1bio1  fromfrom    becomesbecomes  bio4bio6
#
# bio1 from  becomes bio35
# bio1 from  becomes bio17
# bio1 from  becomes bio8
# bio1 from  becomes bio5
# bio1 from  becomes bio35
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio6
# bio1 from  becomes bio36
# bio1 from  becomes bio9
# bio1 from  becomes bio18
# bio1 from  becomes bio14
# bio1 from  becomes bio36
# bio1 from  becomes bio10
# bio1 from  becomes bio30
# bio1 from  becomes bio15
# bio1 bio1from  from  bio1becomes   becomes frombio7 bio35
#
# becomes bio21
# bio1 bio1from  from  becomes  becomes bio25
# bio37
# bio1 from  becomes bio37
# bio1bio1  fromfrom    becomesbecomes  bio16bio11
#
# bio1 from  becomes bio36
# bio1 from  becomesbio1  bio19from
#   becomesbio1  bio31from
#   becomes bio7
# bio1 from  becomes bio12
# bio1 from  becomes bio35
# bio1 from  bio1becomes  frombio8
#  becomes bio17
# bio1 from  becomes bio37
# bio1 from  becomes bio13
# bio1 from  becomes bio32
# bio1 from  becomes bio22
# bio1 from  becomes bio26
# bio1 from  becomes bio18
# bio1 from  becomes bio8
# bio1 from  becomes bio9
# bio1 from  becomes bio14
# bio1 from  becomes bio38
# bio1 from  becomes bio19
# bio1 from  becomes bio20
# bio1 from  bio1becomesbio1   bio1frombio10from
#  from   becomesbecomes   becomesbio9bio27
#
# bio15
# bio1 from  becomes bio36
# bio1 from  becomes bio39
# bio1 from bio1  becomes from bio33
# becomes bio11
# bio1 from  becomes bio16
# bio1bio1  fromfrom    becomesbecomes  bio10bio20
#
# bio1 from  becomes bio21
# bio1 from  becomes bio21
# bio1 from  bio1becomes  frombio37
#  becomes bio23
# bio1 from  becomes bio12
# bio1 from  becomes bio11
# bio1 from  becomes bio17
# bio1 from  becomes bio38
# bio1 from  becomes bio13
# bio1 from  becomes bio12
# bio1 from  becomes bio28
# bio1 from  becomesbio1  bio38from
#   becomes bio18
# bio1 from  becomes bio34
# bio1 from  becomesbio1  bio22from
#   becomes bio14
# bio1 from  becomes bio13
# bio1 from  becomes bio39
# bio1 from  becomes bio19
# bio1 from  becomes bio20
# bio1 from  becomes bio22
# bio1 from  becomes bio29
# bio1 from  becomes bio35
# bio1 from  becomes bio14
# bio1 from  becomesbio1  bio21from
#  becomes bio23
# bio1 from  becomes bio15
# bio1 from  becomes bio30
# bio1 from  becomes bio24
# bio1 from  becomes bio16
# bio1 from  becomes bio15
# bio1 from  becomes bio23
# bio1 from  bio1becomes  frombio16
#  becomes bio25
# bio1 from  becomes bio17
# bio1 from  becomes bio18
# bio1 from  becomes bio22
# bio1 from  becomes bio31bio1
#  from  becomes bio24
# bio1 from  becomes bio24
# bio1 from  becomes bio36
# bio1 from  becomes bio17
# bio1 frombio1   from becomes  becomes bio19bio18
#
# bio1 frombio1   frombecomes   bio37becomes
#  bio26
# bio1 bio1from   from becomes  becomesbio23
# bio25
# bio1 from  becomes bio25
# bio1 from  becomes bio32
# bio1 from  becomes bio27
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++
# bio1 from  bio1becomes bio1 from  bio20from
#  becomes  becomesbio38
#  bio19
# bio1 from  becomes bio26
#  biomass compound: cpd11416_c32
# c32
# bio1 from  becomes bio33
# bio1 from  becomes bio24
# bio1 from  becomes bio28
# bio1 from  becomes bio1bio21
#  from  becomes bio20
# created atp hydrolysis reaction rxn00062_c32 for
# Making biomass drain reaction for species:
# bio1 from bio1  becomesfrom  bio26
# becomes bio39
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++
# bio1 from  becomes bio25
# bio1 from  becomes bio29
# bio1 from  becomes bio27
# bio1 from  becomes bio27
# bio1 from  becomes bio1bio22
# from  becomes bio21
# bio1 from  becomes bio34
# bio1 from  becomes bio23
# bio1 from  becomes bio22
# bio1 from  becomes bio1bio30
# from  becomes bio35
# bio1 from  becomes bio40
# bio1 from  becomes bio28
# bio1 from  becomes bio41
# bio1 from  becomes bio29
# bio1 from  becomes bio42
# bio1 from  becomes bio36
# bio1 from  becomes bio31
# bio1 from  becomes bio30
# bio1 from  becomes bio26
# bio1 from  becomes bio43
# bio1 from  becomes bio37
# bio1 from  becomes bio28
# bio1 from  becomes bio32
# bio1 from  becomes bio38
# bio1 from  becomes bio44
# bio1 from  becomes bio27
# bio1 from  becomes bio28
# bio1 from  becomes bio24
# bio1 from  becomes bio23
# bio1 from  becomes bio45
# bio1 from  becomes bio29
# bio1 from  becomes bio39
# bio1 from  becomes bio33
# bio1 from  becomes bio29
# bio1 from  becomes bio40
# bio1 from  becomes bio30
# bio1 from  becomes bio31
# bio1 from  becomes bio25
# bio1 from  becomes bio24
# bio1 from  becomes bio31
# bio1 from  becomes bio41
# bio1 from  becomes bio32
# bio1 from  becomesbio1  bio26frombio1
#    frombecomes   bio30becomes
# bio25
# bio1 from  becomes bio31
# bio1 from  becomes bio32
# bio1 from  becomes bio33
# bio1 from  becomes bio27
# bio1 from  becomes bio26
# bio1 from  becomes bio28
# bio1 from  becomes bio27
# bio1 from  becomes bio33
# bio1 from  becomes bio32
# bio1 from  becomes bio34
# bio1 from  becomes bio29
# bio1 from  becomes bio34
# bio1 from  becomes bio33
# bio1 from  becomes bio34
# bio1 from  becomes bio42
# bio1 from  becomes bio28
# bio1 from  becomes bio35
# bio1 from  becomes bio35
# bio1 from  becomes bio35
# bio1 from  becomes bio30
# bio1 from  becomes bio34
# bio1 from  becomes bio36
# bio1 from  becomes bio36
# bio1 from  becomes bio43
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio29
# bio1 from  becomes bio35
# bio1 from  becomes bio36
# bio1 from  becomes bio37
# bio1 from  becomes bio31
# bio1 from  becomes bio30
# bio1 from  becomes bio31
# bio1 frombio1   frombecomes   becomesbio37
#  bio44
# bio1 from  becomes bio37
# bio1 from  becomes bio36
# bio1 from  becomes bio38
# bio1 from  becomes bio32
# bio1 from  becomes bio45
# bio1 from  becomes bio1bio33
# from  becomes bio38
# bio1 from  becomes bio38
# bio1 from  becomes bio39
# bio1 from  becomes bio37
# bio1 from  becomes bio38
# bio1 from  becomes bio46
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio40
# bio1 from  becomes bio32
# bio1 from  becomes bio39
# bio1 from  becomes bio33
# bio1 from  becomes bio47
# bio1 from  becomes bio39
# bio1 from  becomes bio41
# bio1 from  becomes bio39
# bio1 from  becomes bio40
# bio1 from  becomes bio34
# bio1 from  becomes bio35
# bio1 from  becomes bio41
# bio1 from  becomes bio34
# bio1 from  becomes bio40
# bio1 from  becomes bio42
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio36
# bio1 from  becomes bio42
# bio1 from  becomes bio43
# bio1 from  becomes bio40
# bio1 from  becomes bio37
# bio1bio1  fromfrom    becomesbecomes  bio44bio35
#
# bio1 from  becomes bio43
# bio1 from  becomes bio41
# bio1 from  becomes bio1bio44
# from  becomes bio41
# bio1 from  becomes bio38
# bio1 from  becomes bio45
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio39
# bio1 from  becomes bio45
# bio1 from  bio1becomes  from bio36
# becomes bio42
# bio1 from  becomes bio40
# bio1 from  becomes bio46
# bio1 from  becomes bio41
# bio1 from  becomes bio37
# bio1 from  bio1becomes  frombio47
#  becomes bio42
# bio1 from  becomes bio42
# bio1 from  becomes bio1bio38
# from  becomes bio46
# bio1 from  becomes bio43
# bio1 from  becomes bio43
# bio1 from  becomes bio39
# bio1 from  becomes bio48
# bio1 from  becomes bio47
# bio1 from  becomes bio1bio44
# from  becomes bio43
# bio1 from  becomes bio40
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio44
# bio1 from  becomes bio45
# bio1 from  becomes bio41
# bio1 from  becomes bio48
# bio1 from  becomes bio42
# bio1 from  becomesbio1  bio46from
#   becomes bio44
# bio1 from  becomes bio43
# bio1 from  becomes bio45
# bio1 from  becomes bio45
# bio1 from  becomes bio46
# bio1 from  becomes bio46
# bio1 from  becomes bio47
# bio1 from  becomes bio49
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
#  biomass compound: cpd11416_c35
# c35
# bio1 from  becomesbio1  bio48from
#   becomes bio50
# bio1 from  becomes bio49
# created atp hydrolysis reaction rxn00062_c35 for
# bio1 from  becomes bio47
# bio1 from Making biomass drain reaction for species:
# becomes bio51
# bio1 from  becomes bio47
# bio1 from  becomes bio44
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++
# bio1 from  becomes bio48
# bio1 from  becomes bio48
# bio1 from  becomes bio45
# bio1 from  becomes bio1bio52
# from  becomes bio50
# bio1 from  becomes bio49
# bio1 from  becomes bio46
# bio1 from  becomes bio47
# bio1 from  becomes bio53
# bio1 from  becomes bio50
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c38
# c38
# bio1 from  becomes bio51
# bio1 from  becomes bio48
# bio1 from  becomes bio51
# bio1 from  becomes bio49
# bio1 from  becomes bio54
# bio1 from  becomes bio52
# bio1 from  becomes bio52
# bio1 from  becomes bio50
# bio1 from  becomes bio49
# bio1 from  becomes bio53
# bio1 from  becomes bio55
# bio1 from  becomes bio53
# bio1 from  becomes bio50
# bio1 from  becomes bio51
# bio1 from  becomes bio54
# bio1 from  becomes bio51
# created atp hydrolysis reaction rxn00062_c38 for
# Making biomass drain reaction for species:
# bio1 from  becomes bio54
# bio1 from  becomes bio55
# bio1 from  becomes bio56
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c36
# c36
# bio1 from  becomesNeither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# bio52
# bio1 from  becomes bio52
# bio1 from  becomes bio57
# bio1 from  becomes bio55
# bio1 from  becomes bio58
# created atp hydrolysis reaction rxn00062_c36 for
# Making biomass drain reaction for species:
# bio1 from  becomes bio53
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++
# bio1 from  becomes bio56
#  biomass compound: cpd11416_c37
# c37
# bio1 from  becomes bio59
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# bio1 from  becomes bio54
#  biomass compound: cpd11416_c38
# c38
# bio1 from  becomes bio60
# created atp hydrolysis reaction rxn00062_c37 for
# Making biomass drain reaction for species:
# bio1 from  becomes bio61
# bio1 from  becomes bio57
# created atp hydrolysis reaction rxn00062_c38 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++
# bio1 from bio1  becomesfrom  bio58
# becomes bio55
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# bio1 from  becomes bio62
# bio1 from  becomes bio59
# bio1 from  becomes bio56
# bio1 from  becomes bio63
# bio1 from  becomes bio57
# bio1 from  becomes bio64
# bio1 from  becomes bio60
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c38
# c38
# bio1 from  becomes bio58
# bio1 from  becomes bio61
# bio1 from  becomes bio65
# bio1 from  becomes bio59
# created atp hydrolysis reaction rxn00062_c38 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# bio1 from  becomes bio66
# bio1 from  becomes bio62
# bio1 from  becomes bio60
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++
# bio1 from  becomes bio63
# bio1 from  becomes bio61
# bio1 from  becomes bio64
# bio1 from  becomes bio62
# bio1 from  becomes bio65
# bio1 from  becomes bio63
# bio1 from  becomes bio66
# bio1 from  becomes bio64
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c44
# c44
# created atp hydrolysis reaction rxn00062_c44 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c46
# c46
# created atp hydrolysis reaction rxn00062_c46 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c47
# c47
# created atp hydrolysis reaction rxn00062_c47 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c51
# c51
# created atp hydrolysis reaction rxn00062_c51 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c54
# c54
# created atp hydrolysis reaction rxn00062_c54 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in +++++++++++++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c65
# c65
# created atp hydrolysis reaction rxn00062_c65 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c65
# c65
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  biomass compound: cpd11416_c63
# c63
# created atp hydrolysis reaction rxn00062_c65 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# created atp hydrolysis reaction rxn00062_c63 for
# Making biomass drain reaction for species:
# Neither carbon consumption nor oxygen consumption are defined in ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 67
#      64     pool = Pool(cpus)
#      65     outputs = pool.map(create_comm, args)
# ---> 67     print(f"missing iterativeIDs", missing_iterativeIDs)
#      68     print(f"missing IDs", missing_IDs)
#      69 else:
#
# NameError: name 'missing_iterativeIDs' is not defined

# %% [markdown]
# # Conduct community modeling
