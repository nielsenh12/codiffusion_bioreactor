# %%
import os
print(os.system("python -V"))
# Out:
# Python 3.12.3
# 0

# %%
import os

# Check environment variables
print(os.environ.get('ILOG_LICENSE_FILE'))
print(os.environ.get('CPLEX_STUDIO_DIR'))

# Print all CPLEX/ILOG related environment variables
for key, value in os.environ.items():
    if 'cplex' in key.lower() or 'ilog' in key.lower() or 'ibm' in key.lower():
        print(f"{key}={value}")
# Out:
# None
# None

# %%
import cplex
c = cplex.Cplex()
print(c.get_version())

# Some installations store info here
import os
print(os.path.dirname(cplex.__file__))
# Out:
# 22.1.1.0
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/cplex-22.1.1.0-py3.10.egg/cplex

# %%
import subprocess

# Search within the virtual environment
result = subprocess.run(['find', '/opt/env/modelseed_cplex', '-name', 'access.ilm'], capture_output=True, text=True)
print(result.stdout)

# Also check for any .ilm files
result = subprocess.run(['find', '/opt/env/modelseed_cplex', '-name', '*.ilm'], capture_output=True, text=True)
print(result.stdout)

# %%
import subprocess

result = subprocess.run(['find', '/opt', '-name', 'access.ilm'], capture_output=True, text=True, timeout=120)
print(result.stdout)

# %% [markdown]
# # create models from ASVset genome objects

# %%
from load_genomes_to_modelseedpy import GenomeLoader
from cobra.io import write_sbml_model
# from glob import glob
from tqdm import tqdm
import os

loader = GenomeLoader()
# genome_ids = loader.list_available_genomes()#[:10]

def write_model(gID):
    model = loader.build_model(gID, printing=False)
    write_sbml_model(model, f'models/{gID}.xml')

# for genome_id in tqdm(genome_ids):
#     model_path = f'models/{genome_id}.xml'
#     if os.path.exists(model_path):  continue
#     try:
#         model = loader.build_model(genome_id, printing=False)
#         write_sbml_model(model, model_path)
#         # print(f"✓ {genome_id}") 
#     except Exception as e:
#         print(f"✗ {genome_id}: {e}")


# parallelize the effort
args = [gID for gID in loader.list_available_genomes() if not os.path.exists(f'models/{gID}.xml')]#[:2]
print(len(args), "will be processed")
parallelize = False
if parallelize:
    from multiprocess import Pool
    from os import cpu_count
    
    cpus = int(cpu_count()/8)
    print(f"{cpus} cores are being used.  The first argument is {args[0]}")
    pool = Pool(cpus)
    outputs = pool.map(write_model, args)
    
    print(f"missing iterativeIDs", missing_iterativeIDs)
    print(f"missing IDs", missing_IDs)
else:
    for arg in args:
        # print(arg)
        write_model(arg)
# Out:
# 100%|██████████| 1698/1698 [1:21:00<00:00,  2.86s/it]

# %% [markdown]
# ## Gapfill the models in minimal media

# %% [markdown]
# ### ATP Correction

# %%
from cobra.io import read_sbml_model
from glob import glob

member_models = {}
num_models = 5
for model in glob('models/*.xml')[:num_models]:
    ID = model.split("/")[0].split(".")[0]
    member_models[ID] = read_sbml_model(model)
# Out:
# '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.

# %%
# from modelseedpy.core.msatpcorrection import load_default_medias
from modelseedpy.core.mstemplate import MSTemplateBuilder
from modelseedpy import MSATPCorrection
from json import load

with open('../ModelSEEDpy/modelseedpy/data/templates/template_core.json') as fh:
    template_core = MSTemplateBuilder.from_dict(load(fh)).build()
    
ATPcorrection_tests = {}
for ID, model in member_models.items():
    atp_correction = MSATPCorrection(model, #.util.model,
                                     template_core, #default_medias,
                                     compartment='c0', atp_hydrolysis_id='ATPM_c0',
                                     load_default_medias=True)

    print("correction done")
    media_eval = atp_correction.evaluate_growth_media()
    print("evaluation done")
    atp_correction.determine_growth_media()
    print("growth media done")
    atp_correction.apply_growth_media_gapfilling()
    print("applying growth media done")
    atp_correction.expand_model_to_genome_scale()
    print("expanding model done")
    ATPcorrection_tests[ID] = atp_correction.build_tests()
# Out:
# modelseedpy 0.3.3
# Neither carbon consumption nor oxygen consumption are defined in
# c0
# correction done
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found before filtering for Ac.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Ac.O2
# No gapfilling solution found before filtering for Pyr.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr.O2
# No gapfilling solution found before filtering for Akg.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Akg.O2
# No gapfilling solution found before filtering for Dlac.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Dlac.O2
# No gapfilling solution found before filtering for Ac activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Ac
# No gapfilling solution found before filtering for Pyr activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr
# No gapfilling solution found before filtering for Succ activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Succ
# No gapfilling solution found before filtering for Dlac activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Dlac
# No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media mal-L
# No gapfilling solution found before filtering for For.NO3 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media For.NO3
# No gapfilling solution found before filtering for Pyr.NO2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr.NO2
# No gapfilling solution found before filtering for Pyr.NO activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr.NO
# No gapfilling solution found before filtering for Ac.NO3 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Ac.NO3
# No gapfilling solution found before filtering for Pyr.DMSO activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr.DMSO
# No gapfilling solution found before filtering for Pyr.SO4 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Pyr.SO4
# No gapfilling solution found before filtering for H2.CO2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media H2.CO2
# No gapfilling solution found before filtering for For.SO4.H2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media For.SO4.H2
# No gapfilling solution found before filtering for For.SO4 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media For.SO4
# No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media H2.SO4
# No gapfilling solution found before filtering for Light activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Light
# No gapfilling solution found before filtering for Methane activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Methane
# No gapfilling solution found before filtering for Methanol.H2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Methanol.H2
# No gapfilling solution found before filtering for Dimethylamine.H2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Removing ungapfillable media Dimethylamine.H2
# Adding gapfilling {'reversed': {}, 'new': {'rxn01476_c0': '>', 'rxn03884_c0': '>', 'rxn01477_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705900266110>, 'target': 'rxn00062_c0', 'minobjective': 5, 'binary_check': False}
# No gapfilling solution found for Etho.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {'rxn00250_c0': '<'}, 'new': {'EX_cpd00029_e0': '>', 'rxn05581_c0': '<', 'rxn05938_c0': '<', 'rxn05488_c0': '<', 'rxn07191_c0': '<', 'rxn00935_c0': '<', 'rxn14422_c0': '>', 'rxn14421_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x70590191f460>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False}
# Adding gapfilling {'reversed': {'rxn05319_c0': '>', 'rxn00250_c0': '<'}, 'new': {}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x70590191f640>, 'target': 'rxn00062_c0', 'minobjective': 3, 'binary_check': False}
# Adding gapfilling {'reversed': {'rxn00250_c0': '<'}, 'new': {'EX_cpd00029_e0': '>', 'rxn05938_c0': '<', 'rxn05488_c0': '<', 'rxn07191_c0': '<', 'rxn14422_c0': '>', 'rxn09269_c0': '>', 'rxn14421_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908037d00>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False}
# Adding gapfilling {'reversed': {}, 'new': {'EX_cpd00029_e0': '>', 'rxn05938_c0': '<', 'rxn05488_c0': '<', 'rxn07191_c0': '<', 'rxn14422_c0': '>', 'rxn14421_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908037880>, 'target': 'rxn00062_c0', 'minobjective': 2, 'binary_check': False}
# No gapfilling solution found for For.O2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {}, 'new': {'rxn01476_c0': '>', 'rxn03884_c0': '>', 'rxn01477_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908037100>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# No gapfilling solution found for Etho activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {'rxn00250_c0': '<'}, 'new': {'EX_cpd00363_e0': '>', 'rxn05581_c0': '<', 'rxn00935_c0': '<', 'rxn00157_c0': '<', 'rxn05553_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908036920>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# Adding gapfilling {'reversed': {'rxn05319_c0': '>', 'rxn00250_c0': '<'}, 'new': {}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908036770>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# No gapfilling solution found for Akg activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {}, 'new': {'EX_cpd00363_e0': '>', 'rxn05938_c0': '<', 'rxn07191_c0': '<', 'rxn05553_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908036140>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# No gapfilling solution found for For activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for For.NO2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for For.NO activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Pyr.NO3 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Ac.NO2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Ac.NO activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {}, 'new': {'rxn01476_c0': '>', 'rxn03884_c0': '>', 'rxn01477_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908034400>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# Adding gapfilling {'reversed': {}, 'new': {'rxn01476_c0': '>', 'rxn03884_c0': '>', 'rxn01477_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908034190>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# No gapfilling solution found for Pyr.TMAO activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Pyr.SO3 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for H2.Ac activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# Adding gapfilling {'reversed': {}, 'new': {'EX_cpd00363_e0': '>', 'rxn05938_c0': '<', 'rxn07191_c0': '<', 'rxn05553_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908004ee0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# Adding gapfilling {'reversed': {}, 'new': {'EX_cpd00363_e0': '>', 'rxn05938_c0': '<', 'rxn07191_c0': '<', 'rxn05553_c0': '>'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x705908005390>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# No gapfilling solution found for empty activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for ANME activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Methanol activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Methanamine.H2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# No gapfilling solution found for Trimethylamine.H2 activating rxn00062_c0
# Neither carbon consumption nor oxygen consumption are defined in
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 17
#      11 atp_correction = MSATPCorrection(model, #.util.model,
#      12                                  template_core, #default_medias,
#      13                                  compartment='c0', atp_hydrolysis_id='ATPM_c0',
#      14                                  load_default_medias=True)
#      16 print("correction done")
# ---> 17 media_eval = atp_correction.evaluate_growth_media()
#      18 print("evaluation done")
#      19 atp_correction.determine_growth_media()
#
# File ~/repos/ModelSEEDpy/modelseedpy/core/msatpcorrection.py:337, in MSATPCorrection.evaluate_growth_media(self, no_gapfilling)
#     335 # Now running gapfilling on all conditions where initially there was no growth
#     336 if not no_gapfilling:
# --> 337     all_solutions = self.get_msgapfill().run_multi_gapfill(
#     338         media_list,
#     339         target=self.atp_hydrolysis.id,
#     340         minimum_objectives=min_objectives,
#     341         prefilter=False,
#     342         check_for_growth=False,
#     343         gapfilling_mode="Independent",
#     344         run_sensitivity_analysis=False,
#     345         integrate_solutions=False,
#     346     )
#     347     print(str(all_solutions))
#     348     # Adding the new solutions to the media gapfill stats
#
# File ~/repos/ModelSEEDpy/modelseedpy/core/msgapfill.py:552, in MSGapfill.run_multi_gapfill(self, media_list, target, target_hash, minimum_objectives, default_minimum_objective, binary_check, prefilter, check_for_growth, gapfilling_mode, run_sensitivity_analysis, integrate_solutions, remove_unneeded_reactions)
#     550     self.gfpkgmgr.getpkg("GapfillingPkg").build_gapfilling_objective_function()
#     551 #Running sensitivity analysis once on the cumulative solution for all media
# --> 552 with open("datacache/solutions.json", 'w') as f:
#     553     json.dump(solution_dictionary,f,indent=4,skipkeys=True)
#     554 if run_sensitivity_analysis:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datacache/solutions.json'

# %%
# %run util.py
from json import load
from numpy import mean

# microbiome_path = "/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor"
microbiome_path = "../MicrobiomeNotebooks"
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
metaboliteIDs = list(metabolites.keys())

media_nar = 207617
metabolites = util.msrecon.get_media(f"{media_nar}/Wolfe").mediacompounds
auxo_media = util.msrecon.get_media(f"{media_nar}/AuxoMedia")
anaerobicPyruvate = util.msrecon.get_media(f"{media_nar}/PyruateMinimalAnaerobic")
# metabolites
metaboliteIDs = [cpd['id'] for cpd in metabolites] + ["cpd00011", "cpd11640", "cpd01024"]  # experimental media + CO2,H2,CH4

#TODO:  Why is growth only performed for the non-base media and uptake/excretion only performed for the base media?
uptake_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="uptake")
excretion_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="excretion")
agrowth_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=anaerobicPyruvate, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="agrowth")
# growth_phenoset = util.create_phenotypeset_from_compounds(
#     metabolites, base_media=gmm_base_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="growth")
phenotypes = {"uptake": uptake_phenoset, "excretion": excretion_phenoset, "agrowth": agrowth_phenoset}
# Out:
# python version 3.10.19
# ['/home/afreiburger/repos/cobrakbase',
#  '/home/afreiburger/repos/KBBaseModules',
#  '/home/afreiburger/repos/chenry_utility_module/lib',
#  '/home/afreiburger/repos/cb_annotation_ontology_api/lib',
#  '/home/afreiburger/repos/KB-ModelSEEDReconstruction/lib',
#  '/home/afreiburger/repos/MergeMetabolicAnnotations/lib',
#  '/home/afreiburger/repos/codiffusion_bioreactor',
#  '/home/afreiburger/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python310.zip',
#  '/home/afreiburger/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10',
#  '/home/afreiburger/.local/share/uv/python/cpython-3.10.19-linux-x86_64-gnu/lib/python3.10/lib-dynload',
#  '',
#  '/home/afreiburger/repos/.venv2/lib/python3.10/site-packages',
#  '/home/afreiburger/repos/.venv2/lib/python3.10/site-packages/cplex-22.1.1.0-py3.10.egg',
#  '/home/afreiburger/repos/.venv2/lib/python3.10/site-packages/libsbml',
#  '/home/afreiburger/repos']
# KBBaseModules 0.0.1
# cobrakbase 0.3.1
# Output files printed to:/home/afreiburger/repos/codiffusion_bioreactor/Sludge/nboutput when using KBDevUtils.output_dir

# %%
from modelseedpy.core.msmodel import get_reaction_constraints_from_direction
from cobra.io import write_sbml_model
from modelseedpy import MSBuilder
from modelseedpy import MSGapfill
from modelseedpy.core.mspredict import MSPredict

def _integrate_solution(template, model, gap_fill_solution):
    added_reactions = []
    for rxn_id, (lb, ub) in gap_fill_solution.items():
        template_reaction = template.reactions.get_by_id(rxn_id)
        model_reaction = template_reaction.to_reaction(model)
        model_reaction.lower_bound = lb
        model_reaction.upper_bound = ub
        _str = model_reaction.build_reaction_string(True)
        #print(f'{model.id} add {model_reaction.id}: {_str}')
        added_reactions.append(model_reaction)
    model.add_reactions(added_reactions)
    add_exchanges = MSBuilder.add_exchanges_to_model(model)

    return added_reactions, add_exchanges

with open('~/repos/ModelSEEDpy/modelseedpy/data/templates/template_gram_neg.json') as fh:
    template_gramneg = MSTemplateBuilder.from_dict(json.load(fh)).build()
    
for ID, model in member_models:
    predict = MSPredict()
    genome_klass = predict.predict(genome)
    
    gapfill = MSGapfill(model, default_gapfill_templates=[template_gramneg],
                        test_conditions=ATPcorrection_tests[ID],
                        default_target='bio1')

    for media in [auxo_media, anaerobicPyruvate]:
        gapfill_res = gapfill.run_gapfilling(auxo_media)
        gap_sol = {}
        for rxn_id, d in gapfill_res['new'].items():
            if rxn_id[:-1] in template_gramneg.reactions:
                gap_sol[rxn_id[:-1]] = get_reaction_constraints_from_direction(d)
        print(gap_sol)
        _integrate_solution(template_gramneg, model, gap_sol)

    write_sbml_model(model, f'models/{gID}.xml')

# %%
# Cell 1: Imports and setup                                                                                                                
                                                                                                                                         
import os, json                                                                                                                            
                                                                                                                                         
from glob import glob                                                                                                                      
from tqdm import tqdm                                                                                                                      
from collections import Counter                                                                                                            
from modelseedpy.core.msgenome import MSGenome, MSFeature                                                                                  
                                                                                                                                         
from modelseedpy.core.mspredict import MSPredict                                                                                           
                                                                                                                                         
from gapfill_models import (                                                                                                               
get_template_for_genome_class, create_auxo_media,                                                                                          
create_pyruvate_minimal_anaerobic, gapfill_model, list_models                                                                              
)                                                                                                                                          
                                                                                                                                         
                                                                                                                                         
models_dir = "models"                                                                                                                      
genome_objects_dir = "genome_objects"                                                                                                      
output_dir = "gapfilled_models2"                                                                                                           
                                                                                                                                         
# Initialize MSPredict classifier                                                                                                          
predictor = MSPredict()                                                                                                                    
def load_genome_from_genome_object(genome_id):                                                                                             
  """Load MSGenome with RAST annotations from genome_objects JSON."""                                                                    
  obj_path = os.path.join(genome_objects_dir, f"{genome_id}.json")                                                                       
  if not os.path.exists(obj_path):                                                                                                       
      return None                                                                                                                        
                                                                                                                                         
  genome = MSGenome()                                                                                                                    
  with open(obj_path) as f:                                                                                                              
      data = json.load(f)                                                                                                                
  genome.id = data.get('id', genome_id)                                                                                                  
  features = data.get('features', [])                                                                                                    
  for feat in features:                                                                                                                  
      if not isinstance(feat, dict):                                                                                                     
          continue                                                                                                                       
                                                                                                                                         
      # Check for CDS type and has functions or ontology_terms                                                                           
      if feat.get('type') == 'CDS':
          feat_id = feat.get('id', '')                                                                                                   
          ms_feat = MSFeature(feat_id, "")                                                                                               
          # Use ontology_terms if available, otherwise use functions                                                                     
          ontology = feat.get('ontology_terms', {})                                                                                      
          if 'RAST' in ontology and ontology['RAST']:                                                                                    
              for term in ontology['RAST']:                                                                                              
                  ms_feat.add_ontology_term('RAST', term)                                                                                
              genome.features.append(ms_feat)                                                                                            
          elif feat.get('functions'):                                                                                                    
              for func in feat['functions']:                                                                                             
                  ms_feat.add_ontology_term('RAST', func)                                                                                
              genome.features.append(ms_feat)                                                                                            
  return genome                                                                                                                          
                                                                                                                                         
# Get genome IDs from genome_objects directory                                                                                             
genome_ids = [os.path.splitext(os.path.basename(f))[0] for f in glob(f"{genome_objects_dir}/*.json")]                                      
genome_classifications = {}
print("classifying the genomes")                                                                                                           
for gid in tqdm(genome_ids):                                                                                                               
  genome = load_genome_from_genome_object(gid)                                                                                           
  if genome and len(genome.features) > 0:
      try:                                                                                                                               
          genome_classifications[gid] = predictor.predict(genome).value                                                                  
      except Exception as e:
          print(f"Could not classify {gid}: {e}")                                                                                        
                                                                                                                                         
json.dump(genome_classifications, open("member_classifications.json", 'w'), indent=3)                                                      
counts = Counter(list(genome_classifications.values())).most_common()                                                                      
print(f"Classified {len(genome_classifications)} genomes: {counts}")
# Out:
# /home/afreiburger/repos/.venv2/lib/python3.10/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# classifying the genomes
# 100%|██████████| 1698/1698 [08:15<00:00,  3.43it/s]
# Classified 1698 genomes: [('Gram Negative', 890), ('Gram Positive', 736), ('Archaea', 64), ('Cyano', 8)]

# %%
list(genome_classifications.items())[:2]
# Out:
# [('Angelakisella.1', 'Gram Positive'), ('midas_g_399.4', 'Gram Positive')]

# %%
# Build model -> genome mapping   
genome_classifications = json.load(open("member_classifications.json", 'r'))
# ASVgIDs = {json.load(open("model_inputs/ASV_genomeIDs.json", 'r'))

# iterativeIDs = json.load(open("model_inputs/iterativeIDs.json", 'r'))

print("ID mapping")
model_genome_mapping = {}                                                                                                                  
for model_path in tqdm(list_models(models_dir)):
    model_id = os.path.splitext(os.path.basename(model_path))[0]
    # print(model_path, model_id)
    if model_id in genome_classifications:                                                                                                 
        model_genome_mapping[model_id] = model_id
        # print("here")
    else:                                                                                                                                  
        base_id = '.'.join(model_id.split('.')[:2])                                                                                        
        if base_id in genome_classifications:                                                                                              
            model_genome_mapping[model_id] = base_id    
        # print("here2")
    # break
    
print(f"Mapped {len(model_genome_mapping)} models to genomes")
# Out:
# ID mapping
# 100%|██████████| 1698/1698 [00:00<00:00, 311859.18it/s]
# Mapped 1698 models to genomes

# %%
print("Gapfilling")                                                                                   
from cobra.io import read_sbml_model, write_sbml_model                                                                                     
from modelseedpy.core.msatpcorrection import MSATPCorrection                                                                               
from modelseedpy.core.mspredict import MSGenomeClass                                                                                       
                                                                                                                                         
media_list = [create_auxo_media(), create_pyruvate_minimal_anaerobic()]                                                                    
atp_correction_tests = {}                                                                                                                  
results = {}                                                                                                                               
                                                                                                                                         
# Map string values back to MSGenomeClass enum                                                                                             
genome_class_map = {                                                                                                                       
  "Gram Positive": MSGenomeClass.P,                                                                                                      
  "Gram Negative": MSGenomeClass.N,                                                                                                      
  "Cyano": MSGenomeClass.C,                                                                                                              
  "Archaea": MSGenomeClass.A,                                                                                                            
}                                                                                                                                          
                                                                                                                                         
def gapfilling(model_path):                                                                                                                
  model_id = os.path.splitext(os.path.basename(model_path))[0]                                                                           
  genome_id = model_genome_mapping.get(model_id)                                                                                         
  genome_class_str = genome_classifications.get(genome_id) if genome_id else None                                                        
                                                                                                                                         
  # Convert string to MSGenomeClass enum                                                                                                 
  genome_class = genome_class_map.get(genome_class_str) if genome_class_str else None                                                    
                                                                                                                                         
  # Get template using MSPredict classification                                                                                          
  core_template = None                                                                                                                   
  genome_template = None                                                                                                                 
  if genome_class:                                                                                                                       
      core_template, genome_template = predictor.auto_select_template(genome_class)                                                      
                                                                                                                                         
  output_path = gapfill_model(                                                                                                           
      model_path=model_path,                                                                                                             
      media_list=media_list,                                                                                                             
      output_dir=output_dir,                                                                                                             
      gapfilling_mode="Sequential",                                                                                                      
      atp_safe=True,                                                                                                                     
      genome_class=genome_class                                                                                                          
  )                                                                                                                                      
                                                                                                                                         
  result = None                                                                                                                          
  if output_path:                                                                                                                        
      # Load gapfilled model for ATP correction                                                                                          
      model = read_sbml_model(output_path)                                                                                               
                                                                                                                                         
      # ATP Correction                                                                                                                   
      if core_template:                                                                                                                  
          atp_correction = MSATPCorrection(                                                                                              
              model,                                                                                                                     
              core_template,  # Fixed: was core_tmpl                                                                                     
              compartment='c0',                                                                                                          
              atp_hydrolysis_id='ATPM_c0',                                                                                               
              load_default_medias=True                                                                                                   
          )                                                                                                                              
          atp_correction.evaluate_growth_media()                                                                                         
          atp_correction.determine_growth_media()                                                                                        
          atp_correction.apply_growth_media_gapfilling()                                                                                 
          atp_correction.expand_model_to_genome_scale()                                                                                  
          tests = atp_correction.build_tests()                                                                                           
                                                                                                                                         
          # Save corrected model                                                                                                         
          write_sbml_model(model, output_path)                                                                                           
          result = (model_id, output_path, tests)                                                                                        
      else:                                                                                                                              
          result = (model_id, output_path, None)                                                                                         
      print(f"Completed: {model_id}")                                                                                                    
  else:                                                                                                                                  
      result = (model_id, None, None)                                                                                                    
                                                                                                                                         
  return result                                                                                                                          
                                                                                                                                         
                                                                                                                                         
# parallelize the effort                                                                                                                   
args = list_models(models_dir)
print(len(args), "will be processed")
parallelize = True
if parallelize:
    from multiprocess import Pool
    from os import cpu_count
    
    cpus = min(len(args), int(cpu_count()/8))
    print(f"{cpus} cores are being used.  The first argument is {args[0]}")
    pool = Pool(cpus)
    outputs = pool.map(gapfilling, args)                                                                                                   
    pool.close()                                                                                                                           
    pool.join()                                                                                                                            
                                                                                                                                         
    # Collect results from parallel execution                                                                                              
    for model_id, output_path, tests in outputs:                                                                                           
      results[model_id] = output_path                                                                                                    
      if tests:                                                                                                                          
          atp_correction_tests[model_id] = tests                                                                                         
else:                                                                                                                                      
  for arg in args:                                                                                                                       
      model_id, output_path, tests = gapfilling(arg)  # Fixed: was create_comm                                                           
      results[model_id] = output_path                                                                                                    
      if tests:                                                                                                                          
          atp_correction_tests[model_id] = tests

                                                                                                                                         
print(f"Completed: {sum(1 for v in results.values() if v)}/{len(results)} successful")
# Out:
# Gapfilling
# 1698 will be processed
# 42 cores are being used.  The first argument is models/AAP99.1.xml
# 2026-01-13 19:31:51,403 - INFO - Loading model: Comamonadaceae.19
# 2026-01-13 19:31:51,404 - INFO - Loading model: Clostridia.7
# 2026-01-13 19:31:51,433 - INFO - Loading model: Desulfobacca.1
# 2026-01-13 19:31:51,434 - INFO - Loading model: Christensenellaceae_R-7_group.36
# 2026-01-13 19:31:51,434 - INFO - Loading model: DMER64.1
# 2026-01-13 19:31:51,435 - INFO - Loading model: Bacillus.2
# 2026-01-13 19:31:51,437 - INFO - Loading model: Clostridium_sensu_stricto_1.2
# 2026-01-13 19:31:51,437 - INFO - Loading model: AAP99.1
# 2026-01-13 19:31:51,437 - INFO - Loading model: Eoetvoesia.1
# 2026-01-13 19:31:51,443 - INFO - Loading model: Dehalobacter.1
# 2026-01-13 19:31:51,444 - INFO - Loading model: Christensenellaceae_R-7_group.57
# 2026-01-13 19:31:51,445 - INFO - Loading model: Erysipelothrix.8
# 2026-01-13 19:31:51,445 - INFO - Loading model: Desulfovibrio.3
# 2026-01-13 19:31:51,448 - INFO - Loading model: Ca_Alysiosphaera.2
# 2026-01-13 19:31:51,450 - INFO - Loading model: Ca_Competibacter.1
# 2026-01-13 19:31:51,454 - INFO - Loading model: Clostridium_sensu_stricto_13.3
# 2026-01-13 19:31:51,459 - INFO - Loading model: Christensenellaceae_R-7_group.11
# 2026-01-13 19:31:51,459 - INFO - Loading model: Colidextribacter.5
# 2026-01-13 19:31:51,441 - INFO - Loading model: EBM-39.5
# 2026-01-13 19:31:51,492 - INFO - Loading model: Comamonas.5
# 2026-01-13 19:31:51,517 - INFO - Loading model: Fastidiosipila.1
# 2026-01-13 19:31:51,521 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,522 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,537 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,538 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,539 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,540 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,541 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,551 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,552 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,593 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,596 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,608 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,609 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,611 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,612 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,615 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,615 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,617 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,621 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,624 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,624 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,629 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,630 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,630 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,632 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,632 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,632 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,634 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,634 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,636 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,637 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,638 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,639 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,639 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,641 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,641 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,640 - INFO - Loading model: Dethiobacter.9
# 2026-01-13 19:31:51,643 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,644 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,646 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,649 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,650 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,653 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,653 - INFO - Loading model: Acholeplasma.3
# 2026-01-13 19:31:51,654 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,659 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,660 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,661 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,661 - INFO - Loading model: Actinobacteria.1
# 2026-01-13 19:31:51,669 - INFO - Loading model: Brevundimonas.3
# 2026-01-13 19:31:51,671 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,673 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,674 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,677 - INFO - Loading model: Aquamicrobium.7
# 2026-01-13 19:31:51,678 - INFO - Loading model: Alphaproteobacteria.2
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,684 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,686 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,685 - INFO - Loading model: Ca_Phosphoribacter.1
# 2026-01-13 19:31:51,684 - INFO - Loading model: Aeromonas.1
# 2026-01-13 19:31:51,686 - INFO - Loading model: Bacilli.3
# 2026-01-13 19:31:51,695 - INFO - Loading model: Caldicoprobacteraceae.1
# 2026-01-13 19:31:51,696 - INFO - Loading model: Azoarcus.4
# 2026-01-13 19:31:51,697 - INFO - Loading model: Bauldia.2
# 2026-01-13 19:31:51,697 - INFO - Loading model: Alcaligenes.14
# 2026-01-13 19:31:51,699 - INFO - Loading model: Christensenellaceae_R-7_group.76
# 2026-01-13 19:31:51,699 - INFO - Loading model: Anaeromyxobacteraceae.2
# 2026-01-13 19:31:51,683 - INFO - Loading model: Devosia.9
# 2026-01-13 19:31:51,708 - INFO - Loading model: Blvii28_wastewater-sludge_group.3
# 2026-01-13 19:31:51,711 - INFO - Loading model: Anaerovorax.4
# 2026-01-13 19:31:51,713 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,728 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,730 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,729 - INFO - Loading model: Chelatococcus.1
# 2026-01-13 19:31:51,730 - INFO -   Loading template...
# 2026-01-13 19:31:51,755 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,761 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,773 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,775 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,777 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,779 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,778 - INFO -   Loading template...
# 2026-01-13 19:31:51,788 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,797 - INFO -   Loading template...
# 2026-01-13 19:31:51,803 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,805 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,816 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,821 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,831 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,832 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,832 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,837 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,838 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,841 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,842 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,847 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,849 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,853 - INFO - Loading model: Chryseobacterium.1
# 2026-01-13 19:31:51,855 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,857 - INFO - Set parameter TSPort to value 27070
# Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,859 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,859 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,861 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,870 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,872 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,895 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,908 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,910 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,912 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,922 - INFO -   Loading template...
# 2026-01-13 19:31:51,921 - INFO - Loading model: Aminivibrio.8
# 2026-01-13 19:31:51,923 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,925 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,926 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,926 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,934 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,941 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,942 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,943 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,944 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,944 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,948 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,950 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,958 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,960 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,960 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,961 - INFO -   Loading template...
# 2026-01-13 19:31:51,964 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:51,966 - INFO -   Loading template...
# 2026-01-13 19:31:51,972 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,976 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,978 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,979 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,981 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:51,987 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,989 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:51,995 - INFO -   Loading template...
# 2026-01-13 19:31:52,000 - INFO -   Loading template...
# 2026-01-13 19:31:52,002 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,017 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,019 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,030 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:52,031 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:52,032 - INFO -   Loading template...
# 2026-01-13 19:31:52,002 - INFO -   Loading template...
# 2026-01-13 19:31:52,037 - INFO -   Loading template...
# 2026-01-13 19:31:52,039 - INFO -   Loading template...
# 2026-01-13 19:31:52,033 - INFO -   Loading template...
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,047 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,050 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,050 - INFO - Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,051 - INFO -   Loading template...
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,053 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,053 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,068 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,070 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,073 - ERROR - '' is not a valid SBML 'SId'.
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,088 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,089 - INFO -   Loading template...
# 2026-01-13 19:31:52,090 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,091 - INFO -   Loading template...
# 2026-01-13 19:31:52,154 - INFO -   Loading template...
# 2026-01-13 19:31:52,167 - INFO -   Loading template...
# 2026-01-13 19:31:52,173 - INFO -   Loading template...
# 2026-01-13 19:31:52,175 - INFO -   Loading template...
# 2026-01-13 19:31:52,180 - INFO -   Loading template...
# 2026-01-13 19:31:52,198 - INFO -   Loading template...
# 2026-01-13 19:31:52,280 - ERROR - '' is not a valid SBML 'SId'.
# 2026-01-13 19:31:52,286 - INFO -   Loading template...
# Set parameter TSPort to value 27070
# 2026-01-13 19:31:52,296 - INFO - Set parameter TSPort to value 27070
# Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,298 - INFO - Set parameter TokenServer to value "lic-vmw-01.cels.anl.gov"
# 2026-01-13 19:31:52,349 - INFO -   Loading template...
# 2026-01-13 19:31:52,382 - INFO -   Loading template...
# 2026-01-13 19:31:52,387 - INFO -   Loading template...
# 2026-01-13 19:31:52,389 - INFO -   Loading template...
# 2026-01-13 19:31:52,407 - INFO -   Loading template...
# 2026-01-13 19:31:52,415 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,428 - INFO -   Loading template...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,450 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,477 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,480 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,489 - INFO -   Loading template...
# 2026-01-13 19:31:52,498 - INFO -   Loading template...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,509 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,514 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,529 - INFO -   Loading template...
# 2026-01-13 19:31:52,542 - INFO -   Loading template...
# 2026-01-13 19:31:52,553 - INFO -   Loading template...
# 2026-01-13 19:31:52,596 - INFO -   Loading template...
# 2026-01-13 19:31:52,605 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,614 - INFO -   Loading template...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,640 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,670 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,675 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,690 - INFO -   Loading template...
# 2026-01-13 19:31:52,701 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,702 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,721 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,732 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,734 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,740 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,768 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,793 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,804 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,824 - INFO -   Loading template...
# 2026-01-13 19:31:52,827 - INFO -   Loading template...
# 2026-01-13 19:31:52,837 - INFO -   Loading template...
# 2026-01-13 19:31:52,840 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,873 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,879 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,903 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,910 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,925 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:52,933 - INFO -   Loading template...
# 2026-01-13 19:31:52,934 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:52,965 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:52,976 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,003 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,007 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,026 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,038 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,038 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,059 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,073 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,074 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,094 - INFO -   Loading template...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,102 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,107 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,115 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,152 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,156 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,175 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,184 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,208 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,239 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,244 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,274 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,278 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,297 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,351 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,374 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,384 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,427 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,462 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,475 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,510 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,543 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,549 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,570 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,598 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,600 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,603 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,629 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,632 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,633 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,660 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,682 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,718 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,720 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,759 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,795 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,830 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,911 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:53,917 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,944 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:53,949 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:53,984 - INFO -   Using template: GramNegative.modeltemplate
# 2026-01-13 19:31:54,016 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:54,020 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:54,051 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:54,223 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:54,258 - INFO -   Gapfilling with AuxoMedia...
# 2026-01-13 19:31:54,332 - INFO -   Using template: GramNegative.modeltemplate
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:31:54,368 - INFO -   Gapfilling with AuxoMedia...
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:32:19,256 - INFO - Objective with gapfill database:137.21706849317312; min objective:0.01
# 2026-01-13 19:32:20,096 - INFO - Objective with gapfill database:137.21706849317223; min objective:0.01
# 2026-01-13 19:32:20,942 - INFO - Objective with gapfill database:137.2170684931731; min objective:0.01
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 19:32:21,879 - INFO - Objective with gapfill database:137.21706849317312; min objective:0.01
# 2026-01-13 19:32:22,020 - INFO - Objective with gapfill database:137.21706849317516; min objective:0.01
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 20:09:22,537 - WARNING - No gapfilling solution found for Glyc activating rxn00062_c0
# 2026-01-13 20:09:23,386 - WARNING - No gapfilling solution found for Methanamine.H2 activating rxn00062_c0
# 2026-01-13 20:09:23,733 - INFO - Objective with gapfill database:2.0; min objective:0.01
# 2026-01-13 20:09:24,295 - INFO - Objective with gapfill database:0.0; min objective:0.01
# 2026-01-13 20:09:24,331 - INFO - Initial solution: {'reversed': {'rxn00250_c0': '<', 'rxn05319_c0': '>'}, 'new': {'rxn00799_c0': '<'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x79fa04d319c0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# 2026-01-13 20:09:24,333 - INFO - integrating rxn: rxn00799_c0
# 2026-01-13 20:09:24,335 - INFO - integrating rxn: rxn00250_c0
# 2026-01-13 20:09:24,336 - INFO - integrating rxn: rxn05319_c0
# 2026-01-13 20:09:24,337 - INFO - Full solution: [['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['rxn09269_c0', '>', 'new'], ['rxn05319_c0', '>', 'reversed']]
# 2026-01-13 20:09:24,442 - INFO - Fum/rxn00062_c0:rxn00799_c0< needed:0.0 with min obj:0.01
# 2026-01-13 20:09:24,490 - INFO - Fum/rxn00062_c0:rxn00250_c0< needed:0.0 with min obj:0.01
# 2026-01-13 20:09:24,492 - INFO - Fum/rxn00062_c0:rxn05319_c0> needed:0.0 with min obj:0.01
# 2026-01-13 20:09:24,587 - INFO - Cumulative media target solution: {'growth': 0, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x79fa04d319c0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False, 'new': {'rxn00799_c0': '<'}, 'reversed': {'rxn00250_c0': '<', 'rxn05319_c0': '>'}}
# 2026-01-13 20:09:25,226 - INFO - Unneeded: []
# Adding gapfilling {'reversed': {'rxn00250_c0': '<', 'rxn05319_c0': '>'}, 'new': {'rxn00799_c0': '<'}, 'media': <modelseedpy.core.msmedia.MSMedia object at 0x79fa04d319c0>, 'target': 'rxn00062_c0', 'minobjective': 0.01, 'binary_check': False}
# 2026-01-13 20:09:25,256 - INFO - Cumulative: [['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['rxn09269_c0', '>', 'new'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['rxn09269_c0', '>', 'new'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['rxn09269_c0', '>', 'new'], ['EX_cpd00027_e0', '<', 'new'], ['rxn00336_c0', '>', 'new'], ['rxn00330_c0', '<', 'new'], ['rxn07191_c0', '<', 'new'], ['rxn08527_c0', '<', 'new'], ['rxn05226_c0', '>', 'new'], ['rxn00799_c0', '<', 'new'], ['rxn00250_c0', '<', 'reversed'], ['EX_cpd00100_e0', '<', 'new'], ['rxn05581_c0', '<', 'new'], ['rxn09269_c0', '>', 'new'], ['rxn05319_c0', '>', 'reversed']]
# 2026-01-13 20:09:25,952 - INFO - Objective with gapfill database:0.0; min objective:0.01
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 20:09:32,448 - WARNING - No gapfilling solution found before filtering for Ac activating rxn00062_c0
# Removing ungapfillable media Ac
# 2026-01-13 20:09:41,460 - INFO - Objective with gapfill database:0.0; min objective:0.01
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 20:10:48,035 - WARNING - No gapfilling solution found for For.NO2 activating rxn00062_c0
# 2026-01-13 20:10:49,088 - INFO - Objective with gapfill database:0.0; min objective:0.01
# Neither carbon consumption nor oxygen consumption are defined in
# 2026-01-13 20:10:51,673 - WARNING - No gapfilling solution found before filtering for Dimethylamine.H2 activating rxn00062_c0

# %% [markdown]
# ## Define the metabolite-centered phenotypes

# %% [markdown]
# # create community models from the member models and abundances

# %%
from cobra.io import read_sbml_model, write_sbml_model
from pandas import read_csv, Series
from mscommunity import build_from_species_models
from tqdm import tqdm
from json import load
import os

iterativeIDs = load(open("model_inputs/iterativeIDs.json", 'r'))
ASV_sets = load(open("modeling_files/ASV_sets.json", 'r'))
redunant_asvs = {v:k for k,vs in ASV_sets.items() for v in vs}
abundances = load(open("modeling_files/ASVset_abundances.json", 'r'))
abundances = {sample: {iterativeIDs.get(ASV): abund for ASV, abund in content.items()}
              for sample, content in abundances.items()}
abundances_new = {sample: {iterativeIDs.get(ASV): {"abundance": abund} for ASV, abund in content.items()}
              for sample, content in abundances.items()}

def create_comm(item):
    sample, abundances = item
    models = []
    for ASVset, abun in abundances.items():
        # ASVset = iterativeIDs[redunant_asvs.get(ASV, ASV)]
        # print(ASVset)
        model_path = f"gapfilled_models/{ASVset}_gf.xml"
        #TODO:  investigate why these ASVs did not have any genomeIDs
        if not os.path.exists(model_path):  # some ASVs have no genomeIDs
            continue
            
        model = read_sbml_model(model_path)
        model.id = ASVset
        models.append(model)
    modelID = f"{sample}_comm"
    modelName = f"{sample}_comm"
    print(len(models))
    comm_model = build_from_species_models(models, modelID, modelName, printing=True) #abundances_new, printing=True)
    write_sbml_model(comm_model, f"comm_models/{modelID}.xml")

# parallelize the effort
args = [item for item in abundances.items() if not os.path.exists(f"comm_models/{item[0]}_comm.xml")]
print(len(args), "will be processed")
parallelize = False
if parallelize:
    from multiprocess import Pool
    from os import cpu_count
    
    cpus = min(len(args), int(cpu_count()/8))
    print(f"{cpus} cores are being used.  The first argument is {args[0]}")
    pool = Pool(cpus)
    outputs = pool.map(create_comm, args)
    
    print(f"missing iterativeIDs", missing_iterativeIDs)
    print(f"missing IDs", missing_IDs)
else:
    for arg in args:
        # print(arg)
        create_comm(arg)
        # break
# Out:
# modelseedpy 0.3.3
# /home/afreiburger/repos/MSCommunity/mscommunity/commhelper.py:25: SyntaxWarning: invalid escape sequence '\_'
#   return re.sub("(\_\w\d)", "", ID)
# /home/afreiburger/repos/MSCommunity/mscommunity/commhelper.py:111: SyntaxWarning: invalid escape sequence '\d'
#   if re.search('^(bio)(\d+)$', rxn.id) or "biomass" in rxn.id:
# 19 will be processed
# 156
# 156 models are being processed
# 1058 metabolites of midas_g_4042.3 are being processed
# midas_g_4042.3 biomass metabolite captured cpd11416_c1
# 1048 reactions of midas_g_4042.3 are being processed
# bio1 from midas_g_4042.3 becomes bio2
# 987 metabolites of midas_g_269.4 are being processed
# midas_g_269.4 biomass metabolite captured cpd11416_c2
# 986 reactions of midas_g_269.4 are being processed
# bio1 from midas_g_269.4 becomes bio3
# 941 metabolites of midas_g_52.2 are being processed
# midas_g_52.2 biomass metabolite captured cpd11416_c3
# 950 reactions of midas_g_52.2 are being processed
# bio1 from midas_g_52.2 becomes bio4
# 796 metabolites of OPB41.1 are being processed
# OPB41.1 biomass metabolite captured cpd11416_c4
# 812 reactions of OPB41.1 are being processed
# bio1 from OPB41.1 becomes bio5
# 787 metabolites of midas_g_531.1 are being processed
# midas_g_531.1 biomass metabolite captured cpd11416_c5
# 784 reactions of midas_g_531.1 are being processed
# bio1 from midas_g_531.1 becomes bio6
# 1073 metabolites of IMCC26207.3 are being processed
# IMCC26207.3 biomass metabolite captured cpd11416_c6
# 1100 reactions of IMCC26207.3 are being processed
# bio1 from IMCC26207.3 becomes bio7
# 1751 metabolites of Brooklawnia.1 are being processed
# Brooklawnia.1 biomass metabolite captured cpd11416_c7
# 2139 reactions of Brooklawnia.1 are being processed
# bio1 from Brooklawnia.1 becomes bio8
# 1751 metabolites of Propionicicella.4 are being processed
# Propionicicella.4 biomass metabolite captured cpd11416_c8
# 2103 reactions of Propionicicella.4 are being processed
# bio1 from Propionicicella.4 becomes bio9
# 1452 metabolites of Mycobacterium.6 are being processed
# Mycobacterium.6 biomass metabolite captured cpd11416_c9
# 1654 reactions of Mycobacterium.6 are being processed
# bio1 from Mycobacterium.6 becomes bio10
# 1547 metabolites of Mycobacterium.13 are being processed
# Mycobacterium.13 biomass metabolite captured cpd11416_c10
# 1797 reactions of Mycobacterium.13 are being processed
# bio1 from Mycobacterium.13 becomes bio11
# 1224 metabolites of Mycobacterium.14 are being processed
# Mycobacterium.14 biomass metabolite captured cpd11416_c11
# 1375 reactions of Mycobacterium.14 are being processed
# bio1 from Mycobacterium.14 becomes bio12
# 1157 metabolites of Gordonia.6 are being processed
# Gordonia.6 biomass metabolite captured cpd11416_c12
# 1235 reactions of Gordonia.6 are being processed
# bio1 from Gordonia.6 becomes bio13
# 1075 metabolites of Leucobacter.3 are being processed
# Leucobacter.3 biomass metabolite captured cpd11416_c13
# 1160 reactions of Leucobacter.3 are being processed
# bio1 from Leucobacter.3 becomes bio14
# 1065 metabolites of Microbacterium.10 are being processed
# Microbacterium.10 biomass metabolite captured cpd11416_c14
# 1178 reactions of Microbacterium.10 are being processed
# bio1 from Microbacterium.10 becomes bio15
# 985 metabolites of midas_g_399.2 are being processed
# midas_g_399.2 biomass metabolite captured cpd11416_c15
# 1024 reactions of midas_g_399.2 are being processed
# bio1 from midas_g_399.2 becomes bio16
# 884 metabolites of midas_g_399.4 are being processed
# midas_g_399.4 biomass metabolite captured cpd11416_c16
# 914 reactions of midas_g_399.4 are being processed
# bio1 from midas_g_399.4 becomes bio17
# 896 metabolites of midas_g_399.5 are being processed
# midas_g_399.5 biomass metabolite captured cpd11416_c17
# 935 reactions of midas_g_399.5 are being processed
# bio1 from midas_g_399.5 becomes bio18
# 853 metabolites of midas_g_497.1 are being processed
# midas_g_497.1 biomass metabolite captured cpd11416_c18
# 874 reactions of midas_g_497.1 are being processed
# bio1 from midas_g_497.1 becomes bio19
# 828 metabolites of Methanobacterium.6 are being processed
# Methanobacterium.6 biomass metabolite captured cpd11416_c19
# 792 reactions of Methanobacterium.6 are being processed
# bio1 from Methanobacterium.6 becomes bio20
# 749 metabolites of Methanobacteriaceae.1 are being processed
# Methanobacteriaceae.1 biomass metabolite captured cpd11416_c20
# 732 reactions of Methanobacteriaceae.1 are being processed
# bio1 from Methanobacteriaceae.1 becomes bio21
# 819 metabolites of Methanobacterium.5 are being processed
# Methanobacterium.5 biomass metabolite captured cpd11416_c21
# 788 reactions of Methanobacterium.5 are being processed
# bio1 from Methanobacterium.5 becomes bio22
# 723 metabolites of Methanobacterium.90 are being processed
# Methanobacterium.90 biomass metabolite captured cpd11416_c22
# 712 reactions of Methanobacterium.90 are being processed
# bio1 from Methanobacterium.90 becomes bio23
# 878 metabolites of midas_g_5426.1 are being processed
# midas_g_5426.1 biomass metabolite captured cpd11416_c23
# 874 reactions of midas_g_5426.1 are being processed
# bio1 from midas_g_5426.1 becomes bio24
# 1218 metabolites of Syner-01.1 are being processed
# Syner-01.1 biomass metabolite captured cpd11416_c24
# 1316 reactions of Syner-01.1 are being processed
# bio1 from Syner-01.1 becomes bio25
# 1249 metabolites of Syner-01.2 are being processed
# Syner-01.2 biomass metabolite captured cpd11416_c25
# 1346 reactions of Syner-01.2 are being processed
# bio1 from Syner-01.2 becomes bio26
# 1065 metabolites of Aminivibrio.1 are being processed
# Aminivibrio.1 biomass metabolite captured cpd11416_c26
# 1111 reactions of Aminivibrio.1 are being processed
# bio1 from Aminivibrio.1 becomes bio27
# 818 metabolites of Ca_Cloacimonas.2 are being processed
# Ca_Cloacimonas.2 biomass metabolite captured cpd11416_c27
# 843 reactions of Ca_Cloacimonas.2 are being processed
# bio1 from Ca_Cloacimonas.2 becomes bio28
# 988 metabolites of LNR_A2-18.1 are being processed
# LNR_A2-18.1 biomass metabolite captured cpd11416_c28
# 985 reactions of LNR_A2-18.1 are being processed
# bio1 from LNR_A2-18.1 becomes bio29
# 864 metabolites of Ca_Cloacimonas.4 are being processed
# Ca_Cloacimonas.4 biomass metabolite captured cpd11416_c29
# 900 reactions of Ca_Cloacimonas.4 are being processed
# bio1 from Ca_Cloacimonas.4 becomes bio30
# 1387 metabolites of midas_g_25828.1 are being processed
# midas_g_25828.1 biomass metabolite captured cpd11416_c30
# 1675 reactions of midas_g_25828.1 are being processed
# bio1 from midas_g_25828.1 becomes bio31
# 1159 metabolites of Marinilabiliaceae.1 are being processed
# Marinilabiliaceae.1 biomass metabolite captured cpd11416_c31
# 1215 reactions of Marinilabiliaceae.1 are being processed
# bio1 from Marinilabiliaceae.1 becomes bio32
# 1032 metabolites of midas_g_19.2 are being processed
# midas_g_19.2 biomass metabolite captured cpd11416_c32
# 1080 reactions of midas_g_19.2 are being processed
# bio1 from midas_g_19.2 becomes bio33
# 1440 metabolites of midas_g_36215.1 are being processed
# midas_g_36215.1 biomass metabolite captured cpd11416_c33
# 1736 reactions of midas_g_36215.1 are being processed
# bio1 from midas_g_36215.1 becomes bio34
# 876 metabolites of midas_g_36215.6 are being processed
# midas_g_36215.6 biomass metabolite captured cpd11416_c34
# 862 reactions of midas_g_36215.6 are being processed
# bio1 from midas_g_36215.6 becomes bio35
# 854 metabolites of DMER64.3 are being processed
# DMER64.3 biomass metabolite captured cpd11416_c35
# 888 reactions of DMER64.3 are being processed
# bio1 from DMER64.3 becomes bio36
# 1581 metabolites of Fermentimonas.6 are being processed
# Fermentimonas.6 biomass metabolite captured cpd11416_c36
# 1878 reactions of Fermentimonas.6 are being processed
# bio1 from Fermentimonas.6 becomes bio37
# 1077 metabolites of Proteiniphilum.1 are being processed
# Proteiniphilum.1 biomass metabolite captured cpd11416_c37
# 1118 reactions of Proteiniphilum.1 are being processed
# bio1 from Proteiniphilum.1 becomes bio38
# 1080 metabolites of Fermentimonas.1 are being processed
# Fermentimonas.1 biomass metabolite captured cpd11416_c38
# 1113 reactions of Fermentimonas.1 are being processed
# bio1 from Fermentimonas.1 becomes bio39
# 852 metabolites of Proteiniphilum.22 are being processed
# Proteiniphilum.22 biomass metabolite captured cpd11416_c39
# 901 reactions of Proteiniphilum.22 are being processed
# bio1 from Proteiniphilum.22 becomes bio40
# 570 metabolites of midas_g_9269.1 are being processed
# midas_g_9269.1 biomass metabolite captured cpd11416_c40
# 599 reactions of midas_g_9269.1 are being processed
# bio1 from midas_g_9269.1 becomes bio41
# 1050 metabolites of midas_g_83754.1 are being processed
# midas_g_83754.1 biomass metabolite captured cpd11416_c41
# 1073 reactions of midas_g_83754.1 are being processed
# bio1 from midas_g_83754.1 becomes bio42
# 1485 metabolites of Thermovirga.2 are being processed
# Thermovirga.2 biomass metabolite captured cpd11416_c42
# 1772 reactions of Thermovirga.2 are being processed
# bio1 from Thermovirga.2 becomes bio43
# 1026 metabolites of Bacteria.21 are being processed
# Bacteria.21 biomass metabolite captured cpd11416_c43
# 1029 reactions of Bacteria.21 are being processed
# bio1 from Bacteria.21 becomes bio44
# 986 metabolites of Thiopseudomonas.1 are being processed
# Thiopseudomonas.1 biomass metabolite captured cpd11416_c44
# 1023 reactions of Thiopseudomonas.1 are being processed
# bio1 from Thiopseudomonas.1 becomes bio45
# 1116 metabolites of Pseudomonas.5 are being processed
# Pseudomonas.5 biomass metabolite captured cpd11416_c45
# 1174 reactions of Pseudomonas.5 are being processed
# bio1 from Pseudomonas.5 becomes bio46
# 1156 metabolites of Pseudomonas.7 are being processed
# Pseudomonas.7 biomass metabolite captured cpd11416_c46
# 1203 reactions of Pseudomonas.7 are being processed
# bio1 from Pseudomonas.7 becomes bio47
# 1399 metabolites of Rhodanobacter.5 are being processed
# Rhodanobacter.5 biomass metabolite captured cpd11416_c47
# 1627 reactions of Rhodanobacter.5 are being processed
# bio1 from Rhodanobacter.5 becomes bio48
# 1349 metabolites of Rhodanobacter.2 are being processed
# Rhodanobacter.2 biomass metabolite captured cpd11416_c48
# 1482 reactions of Rhodanobacter.2 are being processed
# bio1 from Rhodanobacter.2 becomes bio49
# 1101 metabolites of Rheinheimera.1 are being processed
# Rheinheimera.1 biomass metabolite captured cpd11416_c49
# 1193 reactions of Rheinheimera.1 are being processed
# bio1 from Rheinheimera.1 becomes bio50
# 1067 metabolites of midas_g_70.1 are being processed
# midas_g_70.1 biomass metabolite captured cpd11416_c50
# 1086 reactions of midas_g_70.1 are being processed
# bio1 from midas_g_70.1 becomes bio51
# 1346 metabolites of Alcaligenaceae.6 are being processed
# Alcaligenaceae.6 biomass metabolite captured cpd11416_c51
# 1459 reactions of Alcaligenaceae.6 are being processed
# bio1 from Alcaligenaceae.6 becomes bio52
# 1050 metabolites of Pusillimonas.2 are being processed
# Pusillimonas.2 biomass metabolite captured cpd11416_c52
# 1078 reactions of Pusillimonas.2 are being processed
# bio1 from Pusillimonas.2 becomes bio53
# 1295 metabolites of Comamonas.3 are being processed
# Comamonas.3 biomass metabolite captured cpd11416_c53
# 1538 reactions of Comamonas.3 are being processed
# bio1 from Comamonas.3 becomes bio54
# 1153 metabolites of Rhodocyclaceae.5 are being processed
# Rhodocyclaceae.5 biomass metabolite captured cpd11416_c54
# 1209 reactions of Rhodocyclaceae.5 are being processed
# bio1 from Rhodocyclaceae.5 becomes bio55
# 1618 metabolites of Azoarcus.4 are being processed
# Azoarcus.4 biomass metabolite captured cpd11416_c55
# 1940 reactions of Azoarcus.4 are being processed
# bio1 from Azoarcus.4 becomes bio56
# 1438 metabolites of Thauera.2 are being processed
# Thauera.2 biomass metabolite captured cpd11416_c56
# 1613 reactions of Thauera.2 are being processed
# bio1 from Thauera.2 becomes bio57
# 987 metabolites of Desulfococcaceae.1 are being processed
# Desulfococcaceae.1 biomass metabolite captured cpd11416_c57
# 993 reactions of Desulfococcaceae.1 are being processed
# bio1 from Desulfococcaceae.1 becomes bio58
# 1137 metabolites of Desulfovibrio.3 are being processed
# Desulfovibrio.3 biomass metabolite captured cpd11416_c58
# 1190 reactions of Desulfovibrio.3 are being processed
# bio1 from Desulfovibrio.3 becomes bio59
# 1040 metabolites of Desulfomicrobium.1 are being processed
# Desulfomicrobium.1 biomass metabolite captured cpd11416_c59
# 1058 reactions of Desulfomicrobium.1 are being processed
# bio1 from Desulfomicrobium.1 becomes bio60
# 1279 metabolites of Desulfovibrionaceae.2 are being processed
# Desulfovibrionaceae.2 biomass metabolite captured cpd11416_c60
# 1422 reactions of Desulfovibrionaceae.2 are being processed
# bio1 from Desulfovibrionaceae.2 becomes bio61
# 1097 metabolites of Parvibaculum.1 are being processed
# Parvibaculum.1 biomass metabolite captured cpd11416_c61
# 1085 reactions of Parvibaculum.1 are being processed
# bio1 from Parvibaculum.1 becomes bio62
# 1310 metabolites of Amaricoccus.1 are being processed
# Amaricoccus.1 biomass metabolite captured cpd11416_c62
# 1388 reactions of Amaricoccus.1 are being processed
# bio1 from Amaricoccus.1 becomes bio63
# 1386 metabolites of Amaricoccus.3 are being processed
# Amaricoccus.3 biomass metabolite captured cpd11416_c63
# 1515 reactions of Amaricoccus.3 are being processed
# bio1 from Amaricoccus.3 becomes bio64
# 1653 metabolites of Rhodobacter.5 are being processed
# Rhodobacter.5 biomass metabolite captured cpd11416_c64
# 1987 reactions of Rhodobacter.5 are being processed
# bio1 from Rhodobacter.5 becomes bio65
# 1086 metabolites of Caulobacteraceae.1 are being processed
# Caulobacteraceae.1 biomass metabolite captured cpd11416_c65
# 1159 reactions of Caulobacteraceae.1 are being processed
# bio1 from Caulobacteraceae.1 becomes bio66
# 1124 metabolites of Hyphomonas.1 are being processed
# Hyphomonas.1 biomass metabolite captured cpd11416_c66
# 1157 reactions of Hyphomonas.1 are being processed
# bio1 from Hyphomonas.1 becomes bio67
# 1137 metabolites of Rhizobiaceae.1 are being processed
# Rhizobiaceae.1 biomass metabolite captured cpd11416_c67
# 1178 reactions of Rhizobiaceae.1 are being processed
# bio1 from Rhizobiaceae.1 becomes bio68
# 1429 metabolites of Aquamicrobium.1 are being processed
# Aquamicrobium.1 biomass metabolite captured cpd11416_c68
# 1556 reactions of Aquamicrobium.1 are being processed
# bio1 from Aquamicrobium.1 becomes bio69
# 1346 metabolites of Aquamicrobium.5 are being processed
# Aquamicrobium.5 biomass metabolite captured cpd11416_c69
# 1419 reactions of Aquamicrobium.5 are being processed
# bio1 from Aquamicrobium.5 becomes bio70
# 1247 metabolites of Aquamicrobium.7 are being processed
# Aquamicrobium.7 biomass metabolite captured cpd11416_c70
# 1296 reactions of Aquamicrobium.7 are being processed
# bio1 from Aquamicrobium.7 becomes bio71
# 1306 metabolites of Devosia.1 are being processed
# Devosia.1 biomass metabolite captured cpd11416_c71
# 1442 reactions of Devosia.1 are being processed
# bio1 from Devosia.1 becomes bio72
# 1127 metabolites of Devosia.7 are being processed
# Devosia.7 biomass metabolite captured cpd11416_c72
# 1221 reactions of Devosia.7 are being processed
# bio1 from Devosia.7 becomes bio73
# 1452 metabolites of Stappia.1 are being processed
# Stappia.1 biomass metabolite captured cpd11416_c73
# 1625 reactions of Stappia.1 are being processed
# bio1 from Stappia.1 becomes bio74
# 1156 metabolites of Hyphomicrobium.2 are being processed
# Hyphomicrobium.2 biomass metabolite captured cpd11416_c74
# 1189 reactions of Hyphomicrobium.2 are being processed
# bio1 from Hyphomicrobium.2 becomes bio75
# 1324 metabolites of Hyphomicrobium.10 are being processed
# Hyphomicrobium.10 biomass metabolite captured cpd11416_c75
# 1415 reactions of Hyphomicrobium.10 are being processed
# bio1 from Hyphomicrobium.10 becomes bio76
# 1104 metabolites of Rhodobacteraceae.6 are being processed
# Rhodobacteraceae.6 biomass metabolite captured cpd11416_c76
# 1118 reactions of Rhodobacteraceae.6 are being processed
# bio1 from Rhodobacteraceae.6 becomes bio77
# 514 metabolites of midas_g_57.2 are being processed
# midas_g_57.2 biomass metabolite captured cpd11416_c77
# 561 reactions of midas_g_57.2 are being processed
# bio1 from midas_g_57.2 becomes bio78
# 1189 metabolites of Xanthobacteraceae.1 are being processed
# Xanthobacteraceae.1 biomass metabolite captured cpd11416_c78
# 1244 reactions of Xanthobacteraceae.1 are being processed
# bio1 from Xanthobacteraceae.1 becomes bio79
# 1082 metabolites of Pseudochelatococcus.1 are being processed
# Pseudochelatococcus.1 biomass metabolite captured cpd11416_c79
# 1142 reactions of Pseudochelatococcus.1 are being processed
# bio1 from Pseudochelatococcus.1 becomes bio80
# 1331 metabolites of Afipia.1 are being processed
# Afipia.1 biomass metabolite captured cpd11416_c80
# 1416 reactions of Afipia.1 are being processed
# bio1 from Afipia.1 becomes bio81
# 1204 metabolites of Alphaproteobacteria.4 are being processed
# Alphaproteobacteria.4 biomass metabolite captured cpd11416_c81
# 1220 reactions of Alphaproteobacteria.4 are being processed
# bio1 from Alphaproteobacteria.4 becomes bio82
# 906 metabolites of Smithella.2 are being processed
# Smithella.2 biomass metabolite captured cpd11416_c82
# 893 reactions of Smithella.2 are being processed
# bio1 from Smithella.2 becomes bio83
# 1214 metabolites of Syntrophobacter.1 are being processed
# Syntrophobacter.1 biomass metabolite captured cpd11416_c83
# 1270 reactions of Syntrophobacter.1 are being processed
# bio1 from Syntrophobacter.1 becomes bio84
# 1083 metabolites of Syntrophobacter.7 are being processed
# Syntrophobacter.7 biomass metabolite captured cpd11416_c84
# 1093 reactions of Syntrophobacter.7 are being processed
# bio1 from Syntrophobacter.7 becomes bio85
# 998 metabolites of Desulfuromonadaceae.1 are being processed
# Desulfuromonadaceae.1 biomass metabolite captured cpd11416_c85
# 994 reactions of Desulfuromonadaceae.1 are being processed
# bio1 from Desulfuromonadaceae.1 becomes bio86
# 826 metabolites of RBG-16-49-21.1 are being processed
# RBG-16-49-21.1 biomass metabolite captured cpd11416_c86
# 808 reactions of RBG-16-49-21.1 are being processed
# bio1 from RBG-16-49-21.1 becomes bio87
# 818 metabolites of midas_g_1408.1 are being processed
# midas_g_1408.1 biomass metabolite captured cpd11416_c87
# 842 reactions of midas_g_1408.1 are being processed
# bio1 from midas_g_1408.1 becomes bio88
# 1407 metabolites of Hydrogenedensaceae.1 are being processed
# Hydrogenedensaceae.1 biomass metabolite captured cpd11416_c88
# 1567 reactions of Hydrogenedensaceae.1 are being processed
# bio1 from Hydrogenedensaceae.1 becomes bio89
# 1059 metabolites of Pir4_lineage.7 are being processed
# Pir4_lineage.7 biomass metabolite captured cpd11416_c89
# 1059 reactions of Pir4_lineage.7 are being processed
# bio1 from Pir4_lineage.7 becomes bio90
# 1269 metabolites of midas_g_5834.2 are being processed
# midas_g_5834.2 biomass metabolite captured cpd11416_c90
# 1362 reactions of midas_g_5834.2 are being processed
# bio1 from midas_g_5834.2 becomes bio91
# 710 metabolites of Leptolinea.3 are being processed
# Leptolinea.3 biomass metabolite captured cpd11416_c91
# 774 reactions of Leptolinea.3 are being processed
# bio1 from Leptolinea.3 becomes bio92
# 987 metabolites of midas_g_156.1 are being processed
# midas_g_156.1 biomass metabolite captured cpd11416_c92
# 1053 reactions of midas_g_156.1 are being processed
# bio1 from midas_g_156.1 becomes bio93
# 1010 metabolites of Ca_Caldatribacterium.1 are being processed
# Ca_Caldatribacterium.1 biomass metabolite captured cpd11416_c93
# 1082 reactions of Ca_Caldatribacterium.1 are being processed
# bio1 from Ca_Caldatribacterium.1 becomes bio94
# 1253 metabolites of midas_g_3409.1 are being processed
# midas_g_3409.1 biomass metabolite captured cpd11416_c94
# 1335 reactions of midas_g_3409.1 are being processed
# bio1 from midas_g_3409.1 becomes bio95
# 897 metabolites of midas_g_249.4 are being processed
# midas_g_249.4 biomass metabolite captured cpd11416_c95
# 902 reactions of midas_g_249.4 are being processed
# bio1 from midas_g_249.4 becomes bio96
# 897 metabolites of Thermovirga.6 are being processed
# Thermovirga.6 biomass metabolite captured cpd11416_c96
# 935 reactions of Thermovirga.6 are being processed
# bio1 from Thermovirga.6 becomes bio97
# 1024 metabolites of midas_g_515.1 are being processed
# midas_g_515.1 biomass metabolite captured cpd11416_c97
# 1051 reactions of midas_g_515.1 are being processed
# bio1 from midas_g_515.1 becomes bio98
# 790 metabolites of midas_g_4306.1 are being processed
# midas_g_4306.1 biomass metabolite captured cpd11416_c98
# 850 reactions of midas_g_4306.1 are being processed
# bio1 from midas_g_4306.1 becomes bio99
# 1408 metabolites of midas_f_8126.2 are being processed
# midas_f_8126.2 biomass metabolite captured cpd11416_c99
# 1552 reactions of midas_f_8126.2 are being processed
# bio1 from midas_f_8126.2 becomes bio100
# 1153 metabolites of midas_g_1799.7 are being processed
# midas_g_1799.7 biomass metabolite captured cpd11416_c100
# 1291 reactions of midas_g_1799.7 are being processed
# bio1 from midas_g_1799.7 becomes bio101
# 1543 metabolites of midas_f_112.13 are being processed
# midas_f_112.13 biomass metabolite captured cpd11416_c101
# 1783 reactions of midas_f_112.13 are being processed
# bio1 from midas_f_112.13 becomes bio102
# 1151 metabolites of midas_f_112.15 are being processed
# midas_f_112.15 biomass metabolite captured cpd11416_c102
# 1237 reactions of midas_f_112.15 are being processed
# bio1 from midas_f_112.15 becomes bio103
# 904 metabolites of midas_g_109803.1 are being processed
# midas_g_109803.1 biomass metabolite captured cpd11416_c103
# 958 reactions of midas_g_109803.1 are being processed
# bio1 from midas_g_109803.1 becomes bio104
# 843 metabolites of midas_g_1799.1 are being processed
# midas_g_1799.1 biomass metabolite captured cpd11416_c104
# 901 reactions of midas_g_1799.1 are being processed
# bio1 from midas_g_1799.1 becomes bio105
# 1299 metabolites of Dethiobacteraceae.4 are being processed
# Dethiobacteraceae.4 biomass metabolite captured cpd11416_c105
# 1396 reactions of Dethiobacteraceae.4 are being processed
# bio1 from Dethiobacteraceae.4 becomes bio106
# 955 metabolites of midas_g_101467.1 are being processed
# midas_g_101467.1 biomass metabolite captured cpd11416_c106
# 941 reactions of midas_g_101467.1 are being processed
# bio1 from midas_g_101467.1 becomes bio107
# 1290 metabolites of Dethiobacteraceae.9 are being processed
# Dethiobacteraceae.9 biomass metabolite captured cpd11416_c107
# 1375 reactions of Dethiobacteraceae.9 are being processed
# bio1 from Dethiobacteraceae.9 becomes bio108
# 999 metabolites of Dethiobacter.7 are being processed
# Dethiobacter.7 biomass metabolite captured cpd11416_c108
# 1043 reactions of Dethiobacter.7 are being processed
# bio1 from Dethiobacter.7 becomes bio109
# 805 metabolites of Dethiobacter.9 are being processed
# Dethiobacter.9 biomass metabolite captured cpd11416_c109
# 816 reactions of Dethiobacter.9 are being processed
# bio1 from Dethiobacter.9 becomes bio110
# 1704 metabolites of Firmicutes.10 are being processed
# Firmicutes.10 biomass metabolite captured cpd11416_c110
# 2056 reactions of Firmicutes.10 are being processed
# bio1 from Firmicutes.10 becomes bio111
# 1332 metabolites of midas_g_109927.1 are being processed
# midas_g_109927.1 biomass metabolite captured cpd11416_c111
# 1479 reactions of midas_g_109927.1 are being processed
# bio1 from midas_g_109927.1 becomes bio112
# 1591 metabolites of Caldicoprobacter.4 are being processed
# Caldicoprobacter.4 biomass metabolite captured cpd11416_c112
# 1821 reactions of Caldicoprobacter.4 are being processed
# bio1 from Caldicoprobacter.4 becomes bio113
# 1614 metabolites of Desulfosporosinus.8 are being processed
# Desulfosporosinus.8 biomass metabolite captured cpd11416_c113
# 1862 reactions of Desulfosporosinus.8 are being processed
# bio1 from Desulfosporosinus.8 becomes bio114
# 1273 metabolites of Firmicutes.19 are being processed
# Firmicutes.19 biomass metabolite captured cpd11416_c114
# 1412 reactions of Firmicutes.19 are being processed
# bio1 from Firmicutes.19 becomes bio115
# 1523 metabolites of midas_g_97954.2 are being processed
# midas_g_97954.2 biomass metabolite captured cpd11416_c115
# 1746 reactions of midas_g_97954.2 are being processed
# bio1 from midas_g_97954.2 becomes bio116
# 1463 metabolites of midas_g_97954.3 are being processed
# midas_g_97954.3 biomass metabolite captured cpd11416_c116
# 1633 reactions of midas_g_97954.3 are being processed
# bio1 from midas_g_97954.3 becomes bio117
# 1584 metabolites of Desulfitibacter.1 are being processed
# Desulfitibacter.1 biomass metabolite captured cpd11416_c117
# 1833 reactions of Desulfitibacter.1 are being processed
# bio1 from Desulfitibacter.1 becomes bio118
# 994 metabolites of Desulfitibacter.9 are being processed
# Desulfitibacter.9 biomass metabolite captured cpd11416_c118
# 1046 reactions of Desulfitibacter.9 are being processed
# bio1 from Desulfitibacter.9 becomes bio119
# 973 metabolites of Clostridia.8 are being processed
# Clostridia.8 biomass metabolite captured cpd11416_c119
# 1025 reactions of Clostridia.8 are being processed
# bio1 from Clostridia.8 becomes bio120
# 924 metabolites of Firmicutes.23 are being processed
# Firmicutes.23 biomass metabolite captured cpd11416_c120
# 996 reactions of Firmicutes.23 are being processed
# bio1 from Firmicutes.23 becomes bio121
# 1434 metabolites of Firmicutes.1 are being processed
# Firmicutes.1 biomass metabolite captured cpd11416_c121
# 1644 reactions of Firmicutes.1 are being processed
# bio1 from Firmicutes.1 becomes bio122
# 850 metabolites of Christensenellaceae_R-7_group.5 are being processed
# Christensenellaceae_R-7_group.5 biomass metabolite captured cpd11416_c122
# 898 reactions of Christensenellaceae_R-7_group.5 are being processed
# bio1 from Christensenellaceae_R-7_group.5 becomes bio123
# 1352 metabolites of Christensenellaceae_R-7_group.37 are being processed
# Christensenellaceae_R-7_group.37 biomass metabolite captured cpd11416_c123
# 1499 reactions of Christensenellaceae_R-7_group.37 are being processed
# bio1 from Christensenellaceae_R-7_group.37 becomes bio124
# 917 metabolites of midas_g_94288.1 are being processed
# midas_g_94288.1 biomass metabolite captured cpd11416_c124
# 969 reactions of midas_g_94288.1 are being processed
# bio1 from midas_g_94288.1 becomes bio125
# 1615 metabolites of midas_g_76594.1 are being processed
# midas_g_76594.1 biomass metabolite captured cpd11416_c125
# 1941 reactions of midas_g_76594.1 are being processed
# bio1 from midas_g_76594.1 becomes bio126
# 1027 metabolites of Hungateiclostridiaceae.11 are being processed
# Hungateiclostridiaceae.11 biomass metabolite captured cpd11416_c126
# 1124 reactions of Hungateiclostridiaceae.11 are being processed
# bio1 from Hungateiclostridiaceae.11 becomes bio127
# 1038 metabolites of Hungateiclostridiaceae.12 are being processed
# Hungateiclostridiaceae.12 biomass metabolite captured cpd11416_c127
# 1132 reactions of Hungateiclostridiaceae.12 are being processed
# bio1 from Hungateiclostridiaceae.12 becomes bio128
# 981 metabolites of midas_g_55650.1 are being processed
# midas_g_55650.1 biomass metabolite captured cpd11416_c128
# 1022 reactions of midas_g_55650.1 are being processed
# bio1 from midas_g_55650.1 becomes bio129
# 919 metabolites of Ercella.13 are being processed
# Ercella.13 biomass metabolite captured cpd11416_c129
# 941 reactions of Ercella.13 are being processed
# bio1 from Ercella.13 becomes bio130
# 1037 metabolites of Ercella.2 are being processed
# Ercella.2 biomass metabolite captured cpd11416_c130
# 1096 reactions of Ercella.2 are being processed
# bio1 from Ercella.2 becomes bio131
# 864 metabolites of Fastidiosipila.6 are being processed
# Fastidiosipila.6 biomass metabolite captured cpd11416_c131
# 891 reactions of Fastidiosipila.6 are being processed
# bio1 from Fastidiosipila.6 becomes bio132
# 1589 metabolites of Monoglobus.14 are being processed
# Monoglobus.14 biomass metabolite captured cpd11416_c132
# 1933 reactions of Monoglobus.14 are being processed
# bio1 from Monoglobus.14 becomes bio133
# 786 metabolites of midas_g_93451.1 are being processed
# midas_g_93451.1 biomass metabolite captured cpd11416_c133
# 826 reactions of midas_g_93451.1 are being processed
# bio1 from midas_g_93451.1 becomes bio134
# 765 metabolites of Christensenellaceae_R-7_group.79 are being processed
# Christensenellaceae_R-7_group.79 biomass metabolite captured cpd11416_c134
# 796 reactions of Christensenellaceae_R-7_group.79 are being processed
# bio1 from Christensenellaceae_R-7_group.79 becomes bio135
# 1438 metabolites of Thermobrachium.1 are being processed
# Thermobrachium.1 biomass metabolite captured cpd11416_c135
# 1654 reactions of Thermobrachium.1 are being processed
# bio1 from Thermobrachium.1 becomes bio136
# 1050 metabolites of Proteiniclasticum.6 are being processed
# Proteiniclasticum.6 biomass metabolite captured cpd11416_c136
# 1123 reactions of Proteiniclasticum.6 are being processed
# bio1 from Proteiniclasticum.6 becomes bio137
# 1364 metabolites of Clostridium_sensu_stricto_1.4 are being processed
# Clostridium_sensu_stricto_1.4 biomass metabolite captured cpd11416_c137
# 1559 reactions of Clostridium_sensu_stricto_1.4 are being processed
# bio1 from Clostridium_sensu_stricto_1.4 becomes bio138
# 1023 metabolites of Clostridium_sensu_stricto_1.5 are being processed
# Clostridium_sensu_stricto_1.5 biomass metabolite captured cpd11416_c138
# 1130 reactions of Clostridium_sensu_stricto_1.5 are being processed
# bio1 from Clostridium_sensu_stricto_1.5 becomes bio139
# 1307 metabolites of Bacillus.4 are being processed
# Bacillus.4 biomass metabolite captured cpd11416_c139
# 1408 reactions of Bacillus.4 are being processed
# bio1 from Bacillus.4 becomes bio140
# 1049 metabolites of Turicibacter.1 are being processed
# Turicibacter.1 biomass metabolite captured cpd11416_c140
# 1108 reactions of Turicibacter.1 are being processed
# bio1 from Turicibacter.1 becomes bio141
# 1056 metabolites of Soehngenia.2 are being processed
# Soehngenia.2 biomass metabolite captured cpd11416_c141
# 1121 reactions of Soehngenia.2 are being processed
# bio1 from Soehngenia.2 becomes bio142
# 1170 metabolites of Romboutsia.3 are being processed
# Romboutsia.3 biomass metabolite captured cpd11416_c142
# 1255 reactions of Romboutsia.3 are being processed
# bio1 from Romboutsia.3 becomes bio143
# 1490 metabolites of Terrisporobacter.3 are being processed
# Terrisporobacter.3 biomass metabolite captured cpd11416_c143
# 1683 reactions of Terrisporobacter.3 are being processed
# bio1 from Terrisporobacter.3 becomes bio144
# 815 metabolites of Peptoclostridium.2 are being processed
# Peptoclostridium.2 biomass metabolite captured cpd11416_c144
# 873 reactions of Peptoclostridium.2 are being processed
# bio1 from Peptoclostridium.2 becomes bio145
# 915 metabolites of midas_g_75908.4 are being processed
# midas_g_75908.4 biomass metabolite captured cpd11416_c145
# 927 reactions of midas_g_75908.4 are being processed
# bio1 from midas_g_75908.4 becomes bio146
# 1221 metabolites of midas_g_75908.7 are being processed
# midas_g_75908.7 biomass metabolite captured cpd11416_c146
# 1316 reactions of midas_g_75908.7 are being processed
# bio1 from midas_g_75908.7 becomes bio147
# 931 metabolites of midas_g_75908.12 are being processed
# midas_g_75908.12 biomass metabolite captured cpd11416_c147
# 974 reactions of midas_g_75908.12 are being processed
# bio1 from midas_g_75908.12 becomes bio148
# 1002 metabolites of midas_g_75908.13 are being processed
# midas_g_75908.13 biomass metabolite captured cpd11416_c148
# 1023 reactions of midas_g_75908.13 are being processed
# bio1 from midas_g_75908.13 becomes bio149
# 939 metabolites of Acetoanaerobium.1 are being processed
# Acetoanaerobium.1 biomass metabolite captured cpd11416_c149
# 904 reactions of Acetoanaerobium.1 are being processed
# bio1 from Acetoanaerobium.1 becomes bio150
# 1173 metabolites of Peptostreptococcales-Tissierellales.6 are being processed
# Peptostreptococcales-Tissierellales.6 biomass metabolite captured cpd11416_c150
# 1195 reactions of Peptostreptococcales-Tissierellales.6 are being processed
# bio1 from Peptostreptococcales-Tissierellales.6 becomes bio151
# 1349 metabolites of Erysipelothrix.7 are being processed
# Erysipelothrix.7 biomass metabolite captured cpd11416_c151
# 1537 reactions of Erysipelothrix.7 are being processed
# bio1 from Erysipelothrix.7 becomes bio152
# 833 metabolites of Erysipelothrix.4 are being processed
# Erysipelothrix.4 biomass metabolite captured cpd11416_c152
# 852 reactions of Erysipelothrix.4 are being processed
# bio1 from Erysipelothrix.4 becomes bio153
# 955 metabolites of Haloplasmataceae.1 are being processed
# Haloplasmataceae.1 biomass metabolite captured cpd11416_c153
# 1029 reactions of Haloplasmataceae.1 are being processed
# bio1 from Haloplasmataceae.1 becomes bio154
# 1145 metabolites of midas_g_33659.2 are being processed
# midas_g_33659.2 biomass metabolite captured cpd11416_c154
# 1271 reactions of midas_g_33659.2 are being processed
# bio1 from midas_g_33659.2 becomes bio155
# 741 metabolites of midas_g_31962.1 are being processed
# midas_g_31962.1 biomass metabolite captured cpd11416_c155
# 782 reactions of midas_g_31962.1 are being processed
# bio1 from midas_g_31962.1 becomes bio156
# 965 metabolites of Christensenellaceae.17 are being processed
# Christensenellaceae.17 biomass metabolite captured cpd11416_c156
# 976 reactions of Christensenellaceae.17 are being processed
# bio1 from Christensenellaceae.17 becomes bio157
# Neither carbon consumption nor oxygen consumption are defined in 10AB_comm
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# 72
# 72 models are being processed
# 838 metabolites of midas_g_5574.2 are being processed
# midas_g_5574.2 biomass metabolite captured cpd11416_c1
# 865 reactions of midas_g_5574.2 are being processed
# bio1 from midas_g_5574.2 becomes bio2
# 1328 metabolites of Methanobacterium.1 are being processed
# Methanobacterium.1 biomass metabolite captured cpd11416_c2
# 1413 reactions of Methanobacterium.1 are being processed
# bio1 from Methanobacterium.1 becomes bio3
# 828 metabolites of Methanobacterium.6 are being processed
# Methanobacterium.6 biomass metabolite captured cpd11416_c3
# 792 reactions of Methanobacterium.6 are being processed
# bio1 from Methanobacterium.6 becomes bio4
# 749 metabolites of Methanobacteriaceae.1 are being processed
# Methanobacteriaceae.1 biomass metabolite captured cpd11416_c4
# 732 reactions of Methanobacteriaceae.1 are being processed
# bio1 from Methanobacteriaceae.1 becomes bio5
# 1218 metabolites of Syner-01.1 are being processed
# Syner-01.1 biomass metabolite captured cpd11416_c5
# 1316 reactions of Syner-01.1 are being processed
# bio1 from Syner-01.1 becomes bio6
# 1065 metabolites of Aminivibrio.1 are being processed
# Aminivibrio.1 biomass metabolite captured cpd11416_c6
# 1111 reactions of Aminivibrio.1 are being processed
# bio1 from Aminivibrio.1 becomes bio7
# 1387 metabolites of midas_g_25828.1 are being processed
# midas_g_25828.1 biomass metabolite captured cpd11416_c7
# 1675 reactions of midas_g_25828.1 are being processed
# bio1 from midas_g_25828.1 becomes bio8
# 1078 metabolites of Lentimicrobium.1 are being processed
# Lentimicrobium.1 biomass metabolite captured cpd11416_c8
# 1099 reactions of Lentimicrobium.1 are being processed
# bio1 from Lentimicrobium.1 becomes bio9
# 1289 metabolites of Lentimicrobium.8 are being processed
# Lentimicrobium.8 biomass metabolite captured cpd11416_c9
# 1533 reactions of Lentimicrobium.8 are being processed
# bio1 from Lentimicrobium.8 becomes bio10
# 876 metabolites of midas_g_36215.6 are being processed
# midas_g_36215.6 biomass metabolite captured cpd11416_c10
# 862 reactions of midas_g_36215.6 are being processed
# bio1 from midas_g_36215.6 becomes bio11
# 894 metabolites of Dysgonomonas.1 are being processed
# Dysgonomonas.1 biomass metabolite captured cpd11416_c11
# 932 reactions of Dysgonomonas.1 are being processed
# bio1 from Dysgonomonas.1 becomes bio12
# 975 metabolites of Petrimonas.1 are being processed
# Petrimonas.1 biomass metabolite captured cpd11416_c12
# 1019 reactions of Petrimonas.1 are being processed
# bio1 from Petrimonas.1 becomes bio13
# 921 metabolites of Proteiniphilum.2 are being processed
# Proteiniphilum.2 biomass metabolite captured cpd11416_c13
# 933 reactions of Proteiniphilum.2 are being processed
# bio1 from Proteiniphilum.2 becomes bio14
# 1077 metabolites of Proteiniphilum.1 are being processed
# Proteiniphilum.1 biomass metabolite captured cpd11416_c14
# 1118 reactions of Proteiniphilum.1 are being processed
# bio1 from Proteiniphilum.1 becomes bio15
# 949 metabolites of Proteiniphilum.3 are being processed
# Proteiniphilum.3 biomass metabolite captured cpd11416_c15
# 983 reactions of Proteiniphilum.3 are being processed
# bio1 from Proteiniphilum.3 becomes bio16
# 570 metabolites of midas_g_9269.1 are being processed
# midas_g_9269.1 biomass metabolite captured cpd11416_c16
# 599 reactions of midas_g_9269.1 are being processed
# bio1 from midas_g_9269.1 becomes bio17
# 618 metabolites of Bacteroides.1 are being processed
# Bacteroides.1 biomass metabolite captured cpd11416_c17
# 631 reactions of Bacteroides.1 are being processed
# bio1 from Bacteroides.1 becomes bio18
# 1505 metabolites of Enterobacteriaceae.1 are being processed
# Enterobacteriaceae.1 biomass metabolite captured cpd11416_c18
# 1815 reactions of Enterobacteriaceae.1 are being processed
# bio1 from Enterobacteriaceae.1 becomes bio19
# 1371 metabolites of Alcaligenes.14 are being processed
# Alcaligenes.14 biomass metabolite captured cpd11416_c19
# 1485 reactions of Alcaligenes.14 are being processed
# bio1 from Alcaligenes.14 becomes bio20
# 1095 metabolites of Desulfovibrio.1 are being processed
# Desulfovibrio.1 biomass metabolite captured cpd11416_c20
# 1107 reactions of Desulfovibrio.1 are being processed
# bio1 from Desulfovibrio.1 becomes bio21
# 1531 metabolites of Brevundimonas.2 are being processed
# Brevundimonas.2 biomass metabolite captured cpd11416_c21
# 1887 reactions of Brevundimonas.2 are being processed
# bio1 from Brevundimonas.2 becomes bio22
# 1373 metabolites of Sphaerochaeta.5 are being processed
# Sphaerochaeta.5 biomass metabolite captured cpd11416_c22
# 1628 reactions of Sphaerochaeta.5 are being processed
# bio1 from Sphaerochaeta.5 becomes bio23
# 1568 metabolites of Terrisporobacter.2 are being processed
# Terrisporobacter.2 biomass metabolite captured cpd11416_c23
# 1820 reactions of Terrisporobacter.2 are being processed
# bio1 from Terrisporobacter.2 becomes bio24
# 1464 metabolites of EBM-39.1 are being processed
# EBM-39.1 biomass metabolite captured cpd11416_c24
# 1748 reactions of EBM-39.1 are being processed
# bio1 from EBM-39.1 becomes bio25
# 1022 metabolites of Desulfosporosinus.3 are being processed
# Desulfosporosinus.3 biomass metabolite captured cpd11416_c25
# 1040 reactions of Desulfosporosinus.3 are being processed
# bio1 from Desulfosporosinus.3 becomes bio26
# 1614 metabolites of Desulfosporosinus.8 are being processed
# Desulfosporosinus.8 biomass metabolite captured cpd11416_c26
# 1862 reactions of Desulfosporosinus.8 are being processed
# bio1 from Desulfosporosinus.8 becomes bio27
# 1414 metabolites of Desulfosporosinus.10 are being processed
# Desulfosporosinus.10 biomass metabolite captured cpd11416_c27
# 1578 reactions of Desulfosporosinus.10 are being processed
# bio1 from Desulfosporosinus.10 becomes bio28
# 1622 metabolites of midas_g_97954.1 are being processed
# midas_g_97954.1 biomass metabolite captured cpd11416_c28
# 1888 reactions of midas_g_97954.1 are being processed
# bio1 from midas_g_97954.1 becomes bio29
# 1434 metabolites of Firmicutes.1 are being processed
# Firmicutes.1 biomass metabolite captured cpd11416_c29
# 1644 reactions of Firmicutes.1 are being processed
# bio1 from Firmicutes.1 becomes bio30
# 1201 metabolites of midas_g_110683.1 are being processed
# midas_g_110683.1 biomass metabolite captured cpd11416_c30
# 1293 reactions of midas_g_110683.1 are being processed
# bio1 from midas_g_110683.1 becomes bio31
# 1182 metabolites of Christensenellaceae_R-7_group.20 are being processed
# Christensenellaceae_R-7_group.20 biomass metabolite captured cpd11416_c31
# 1277 reactions of Christensenellaceae_R-7_group.20 are being processed
# bio1 from Christensenellaceae_R-7_group.20 becomes bio32
# 850 metabolites of Christensenellaceae_R-7_group.5 are being processed
# Christensenellaceae_R-7_group.5 biomass metabolite captured cpd11416_c32
# 898 reactions of Christensenellaceae_R-7_group.5 are being processed
# bio1 from Christensenellaceae_R-7_group.5 becomes bio33
# 767 metabolites of Christensenellaceae_R-7_group.48 are being processed
# Christensenellaceae_R-7_group.48 biomass metabolite captured cpd11416_c33
# 803 reactions of Christensenellaceae_R-7_group.48 are being processed
# bio1 from Christensenellaceae_R-7_group.48 becomes bio34
# 917 metabolites of midas_g_94288.1 are being processed
# midas_g_94288.1 biomass metabolite captured cpd11416_c34
# 969 reactions of midas_g_94288.1 are being processed
# bio1 from midas_g_94288.1 becomes bio35
# 1479 metabolites of Ruminiclostridium.1 are being processed
# Ruminiclostridium.1 biomass metabolite captured cpd11416_c35
# 1755 reactions of Ruminiclostridium.1 are being processed
# bio1 from Ruminiclostridium.1 becomes bio36
# 1016 metabolites of midas_g_98017.1 are being processed
# midas_g_98017.1 biomass metabolite captured cpd11416_c36
# 1058 reactions of midas_g_98017.1 are being processed
# bio1 from midas_g_98017.1 becomes bio37
# 1216 metabolites of Intestinimonas.5 are being processed
# Intestinimonas.5 biomass metabolite captured cpd11416_c37
# 1317 reactions of Intestinimonas.5 are being processed
# bio1 from Intestinimonas.5 becomes bio38
# 1022 metabolites of Colidextribacter.6 are being processed
# Colidextribacter.6 biomass metabolite captured cpd11416_c38
# 1074 reactions of Colidextribacter.6 are being processed
# bio1 from Colidextribacter.6 becomes bio39
# 868 metabolites of UCG-009.4 are being processed
# UCG-009.4 biomass metabolite captured cpd11416_c39
# 875 reactions of UCG-009.4 are being processed
# bio1 from UCG-009.4 becomes bio40
# 1017 metabolites of Colidextribacter.5 are being processed
# Colidextribacter.5 biomass metabolite captured cpd11416_c40
# 1074 reactions of Colidextribacter.5 are being processed
# bio1 from Colidextribacter.5 becomes bio41
# 1076 metabolites of Intestinimonas.2 are being processed
# Intestinimonas.2 biomass metabolite captured cpd11416_c41
# 1150 reactions of Intestinimonas.2 are being processed
# bio1 from Intestinimonas.2 becomes bio42
# 931 metabolites of Oscillospiraceae.4 are being processed
# Oscillospiraceae.4 biomass metabolite captured cpd11416_c42
# 955 reactions of Oscillospiraceae.4 are being processed
# bio1 from Oscillospiraceae.4 becomes bio43
# 1270 metabolites of midas_g_82137.2 are being processed
# midas_g_82137.2 biomass metabolite captured cpd11416_c43
# 1423 reactions of midas_g_82137.2 are being processed
# bio1 from midas_g_82137.2 becomes bio44
# 788 metabolites of midas_g_9023.1 are being processed
# midas_g_9023.1 biomass metabolite captured cpd11416_c44
# 830 reactions of midas_g_9023.1 are being processed
# bio1 from midas_g_9023.1 becomes bio45
# 1015 metabolites of Oscillibacter.2 are being processed
# Oscillibacter.2 biomass metabolite captured cpd11416_c45
# 1042 reactions of Oscillibacter.2 are being processed
# bio1 from Oscillibacter.2 becomes bio46
# 1036 metabolites of Oscillibacter.6 are being processed
# Oscillibacter.6 biomass metabolite captured cpd11416_c46
# 1111 reactions of Oscillibacter.6 are being processed
# bio1 from Oscillibacter.6 becomes bio47
# 837 metabolites of Christensenellaceae_R-7_group.65 are being processed
# Christensenellaceae_R-7_group.65 biomass metabolite captured cpd11416_c47
# 901 reactions of Christensenellaceae_R-7_group.65 are being processed
# bio1 from Christensenellaceae_R-7_group.65 becomes bio48
# 1205 metabolites of Clostridium_sensu_stricto_7.4 are being processed
# Clostridium_sensu_stricto_7.4 biomass metabolite captured cpd11416_c48
# 1330 reactions of Clostridium_sensu_stricto_7.4 are being processed
# bio1 from Clostridium_sensu_stricto_7.4 becomes bio49
# 1122 metabolites of Clostridium_sensu_stricto_13.1 are being processed
# Clostridium_sensu_stricto_13.1 biomass metabolite captured cpd11416_c49
# 1207 reactions of Clostridium_sensu_stricto_13.1 are being processed
# bio1 from Clostridium_sensu_stricto_13.1 becomes bio50
# 1050 metabolites of Proteiniclasticum.6 are being processed
# Proteiniclasticum.6 biomass metabolite captured cpd11416_c50
# 1123 reactions of Proteiniclasticum.6 are being processed
# bio1 from Proteiniclasticum.6 becomes bio51
# 1076 metabolites of Clostridium_sensu_stricto_5.1 are being processed
# Clostridium_sensu_stricto_5.1 biomass metabolite captured cpd11416_c51
# 1141 reactions of Clostridium_sensu_stricto_5.1 are being processed
# bio1 from Clostridium_sensu_stricto_5.1 becomes bio52
# 982 metabolites of Bacillus.10 are being processed
# Bacillus.10 biomass metabolite captured cpd11416_c52
# 997 reactions of Bacillus.10 are being processed
# bio1 from Bacillus.10 becomes bio53
# 1232 metabolites of Enterococcus.1 are being processed
# Enterococcus.1 biomass metabolite captured cpd11416_c53
# 1363 reactions of Enterococcus.1 are being processed
# bio1 from Enterococcus.1 becomes bio54
# 1284 metabolites of Rummeliibacillus.2 are being processed
# Rummeliibacillus.2 biomass metabolite captured cpd11416_c54
# 1392 reactions of Rummeliibacillus.2 are being processed
# bio1 from Rummeliibacillus.2 becomes bio55
# 1021 metabolites of Bacillaceae.4 are being processed
# Bacillaceae.4 biomass metabolite captured cpd11416_c55
# 1042 reactions of Bacillaceae.4 are being processed
# bio1 from Bacillaceae.4 becomes bio56
# 1056 metabolites of Soehngenia.2 are being processed
# Soehngenia.2 biomass metabolite captured cpd11416_c56
# 1121 reactions of Soehngenia.2 are being processed
# bio1 from Soehngenia.2 becomes bio57
# 879 metabolites of Soehngenia.4 are being processed
# Soehngenia.4 biomass metabolite captured cpd11416_c57
# 916 reactions of Soehngenia.4 are being processed
# bio1 from Soehngenia.4 becomes bio58
# 880 metabolites of Anaerosalibacter.1 are being processed
# Anaerosalibacter.1 biomass metabolite captured cpd11416_c58
# 928 reactions of Anaerosalibacter.1 are being processed
# bio1 from Anaerosalibacter.1 becomes bio59
# 937 metabolites of Sporanaerobacter.1 are being processed
# Sporanaerobacter.1 biomass metabolite captured cpd11416_c59
# 977 reactions of Sporanaerobacter.1 are being processed
# bio1 from Sporanaerobacter.1 becomes bio60
# 1278 metabolites of Romboutsia.1 are being processed
# Romboutsia.1 biomass metabolite captured cpd11416_c60
# 1392 reactions of Romboutsia.1 are being processed
# bio1 from Romboutsia.1 becomes bio61
# 939 metabolites of Acetoanaerobium.1 are being processed
# Acetoanaerobium.1 biomass metabolite captured cpd11416_c61
# 904 reactions of Acetoanaerobium.1 are being processed
# bio1 from Acetoanaerobium.1 becomes bio62
# 979 metabolites of Proteiniborus.1 are being processed
# Proteiniborus.1 biomass metabolite captured cpd11416_c62
# 1014 reactions of Proteiniborus.1 are being processed
# bio1 from Proteiniborus.1 becomes bio63
# 1068 metabolites of Sedimentibacter.8 are being processed
# Sedimentibacter.8 biomass metabolite captured cpd11416_c63
# 1133 reactions of Sedimentibacter.8 are being processed
# bio1 from Sedimentibacter.8 becomes bio64
# 1519 metabolites of Sedimentibacter.5 are being processed
# Sedimentibacter.5 biomass metabolite captured cpd11416_c64
# 1857 reactions of Sedimentibacter.5 are being processed
# bio1 from Sedimentibacter.5 becomes bio65
# 935 metabolites of Sedimentibacter.18 are being processed
# Sedimentibacter.18 biomass metabolite captured cpd11416_c65
# 996 reactions of Sedimentibacter.18 are being processed
# bio1 from Sedimentibacter.18 becomes bio66
# 1151 metabolites of Anaerovorax.10 are being processed
# Anaerovorax.10 biomass metabolite captured cpd11416_c66
# 1220 reactions of Anaerovorax.10 are being processed
# bio1 from Anaerovorax.10 becomes bio67
# 1289 metabolites of Anaerovorax.2 are being processed
# Anaerovorax.2 biomass metabolite captured cpd11416_c67
# 1533 reactions of Anaerovorax.2 are being processed
# bio1 from Anaerovorax.2 becomes bio68
# 1031 metabolites of Acetobacterium.1 are being processed
# Acetobacterium.1 biomass metabolite captured cpd11416_c68
# 1055 reactions of Acetobacterium.1 are being processed
# bio1 from Acetobacterium.1 becomes bio69
# 1243 metabolites of Lachnoclostridium.9 are being processed
# Lachnoclostridium.9 biomass metabolite captured cpd11416_c69
# 1369 reactions of Lachnoclostridium.9 are being processed
# bio1 from Lachnoclostridium.9 becomes bio70
# 972 metabolites of Lachnospiraceae.3 are being processed
# Lachnospiraceae.3 biomass metabolite captured cpd11416_c70
# ...
# midas_g_3409.1 biomass metabolite captured cpd11416_c32
# 1335 reactions of midas_g_3409.1 are being processed
# bio1 from midas_g_3409.1 becomes bio33
# 1202 metabolites of Aminiphilus.1 are being processed
# Aminiphilus.1 biomass metabolite captured cpd11416_c33
# 1282 reactions of Aminiphilus.1 are being processed
# bio1 from Aminiphilus.1 becomes bio34
# 1464 metabolites of EBM-39.1 are being processed
# EBM-39.1 biomass metabolite captured cpd11416_c34
# 1748 reactions of EBM-39.1 are being processed
# bio1 from EBM-39.1 becomes bio35
# 917 metabolites of midas_g_94288.1 are being processed
# midas_g_94288.1 biomass metabolite captured cpd11416_c35
# 969 reactions of midas_g_94288.1 are being processed
# bio1 from midas_g_94288.1 becomes bio36
# 1195 metabolites of Christensenellaceae_R-7_group.1 are being processed
# Christensenellaceae_R-7_group.1 biomass metabolite captured cpd11416_c36
# 1297 reactions of Christensenellaceae_R-7_group.1 are being processed
# bio1 from Christensenellaceae_R-7_group.1 becomes bio37
# 1278 metabolites of Romboutsia.1 are being processed
# Romboutsia.1 biomass metabolite captured cpd11416_c37
# 1392 reactions of Romboutsia.1 are being processed
# bio1 from Romboutsia.1 becomes bio38
# 939 metabolites of Acetoanaerobium.1 are being processed
# Acetoanaerobium.1 biomass metabolite captured cpd11416_c38
# 904 reactions of Acetoanaerobium.1 are being processed
# bio1 from Acetoanaerobium.1 becomes bio39
# 962 metabolites of Erysipelothrix.1 are being processed
# Erysipelothrix.1 biomass metabolite captured cpd11416_c39
# 1002 reactions of Erysipelothrix.1 are being processed
# bio1 from Erysipelothrix.1 becomes bio40
# 1256 metabolites of Anaerovorax.1 are being processed
# Anaerovorax.1 biomass metabolite captured cpd11416_c40
# 1365 reactions of Anaerovorax.1 are being processed
# bio1 from Anaerovorax.1 becomes bio41
# 1031 metabolites of Acetobacterium.1 are being processed
# Acetobacterium.1 biomass metabolite captured cpd11416_c41
# 1055 reactions of Acetobacterium.1 are being processed
# bio1 from Acetobacterium.1 becomes bio42
# Neither carbon consumption nor oxygen consumption are defined in N12_comm
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# 36
# 36 models are being processed
# 1425 metabolites of Methanobacterium.2 are being processed
# Methanobacterium.2 biomass metabolite captured cpd11416_c1
# 1659 reactions of Methanobacterium.2 are being processed
# bio1 from Methanobacterium.2 becomes bio2
# 1054 metabolites of Methanobacterium.47 are being processed
# Methanobacterium.47 biomass metabolite captured cpd11416_c2
# 1056 reactions of Methanobacterium.47 are being processed
# bio1 from Methanobacterium.47 becomes bio3
# 1328 metabolites of Methanobacterium.1 are being processed
# Methanobacterium.1 biomass metabolite captured cpd11416_c3
# 1413 reactions of Methanobacterium.1 are being processed
# bio1 from Methanobacterium.1 becomes bio4
# 853 metabolites of Methanobacterium.3 are being processed
# Methanobacterium.3 biomass metabolite captured cpd11416_c4
# 810 reactions of Methanobacterium.3 are being processed
# bio1 from Methanobacterium.3 becomes bio5
# 749 metabolites of Methanobacteriaceae.1 are being processed
# Methanobacteriaceae.1 biomass metabolite captured cpd11416_c5
# 732 reactions of Methanobacteriaceae.1 are being processed
# bio1 from Methanobacteriaceae.1 becomes bio6
# 819 metabolites of Methanobacterium.5 are being processed
# Methanobacterium.5 biomass metabolite captured cpd11416_c6
# 788 reactions of Methanobacterium.5 are being processed
# bio1 from Methanobacterium.5 becomes bio7
# 1518 metabolites of Mesotoga.1 are being processed
# Mesotoga.1 biomass metabolite captured cpd11416_c7
# 1804 reactions of Mesotoga.1 are being processed
# bio1 from Mesotoga.1 becomes bio8
# 1218 metabolites of Syner-01.1 are being processed
# Syner-01.1 biomass metabolite captured cpd11416_c8
# 1316 reactions of Syner-01.1 are being processed
# bio1 from Syner-01.1 becomes bio9
# 1065 metabolites of Aminivibrio.1 are being processed
# Aminivibrio.1 biomass metabolite captured cpd11416_c9
# 1111 reactions of Aminivibrio.1 are being processed
# bio1 from Aminivibrio.1 becomes bio10
# 988 metabolites of LNR_A2-18.1 are being processed
# LNR_A2-18.1 biomass metabolite captured cpd11416_c10
# 985 reactions of LNR_A2-18.1 are being processed
# bio1 from LNR_A2-18.1 becomes bio11
# 1078 metabolites of Lentimicrobium.1 are being processed
# Lentimicrobium.1 biomass metabolite captured cpd11416_c11
# 1099 reactions of Lentimicrobium.1 are being processed
# bio1 from Lentimicrobium.1 becomes bio12
# 1440 metabolites of midas_g_36215.1 are being processed
# midas_g_36215.1 biomass metabolite captured cpd11416_c12
# 1736 reactions of midas_g_36215.1 are being processed
# bio1 from midas_g_36215.1 becomes bio13
# 975 metabolites of Petrimonas.1 are being processed
# Petrimonas.1 biomass metabolite captured cpd11416_c13
# 1019 reactions of Petrimonas.1 are being processed
# bio1 from Petrimonas.1 becomes bio14
# 921 metabolites of Proteiniphilum.2 are being processed
# Proteiniphilum.2 biomass metabolite captured cpd11416_c14
# 933 reactions of Proteiniphilum.2 are being processed
# bio1 from Proteiniphilum.2 becomes bio15
# 1077 metabolites of Proteiniphilum.1 are being processed
# Proteiniphilum.1 biomass metabolite captured cpd11416_c15
# 1118 reactions of Proteiniphilum.1 are being processed
# bio1 from Proteiniphilum.1 becomes bio16
# 570 metabolites of midas_g_9269.1 are being processed
# midas_g_9269.1 biomass metabolite captured cpd11416_c16
# 599 reactions of midas_g_9269.1 are being processed
# bio1 from midas_g_9269.1 becomes bio17
# 1485 metabolites of Thermovirga.2 are being processed
# Thermovirga.2 biomass metabolite captured cpd11416_c17
# 1772 reactions of Thermovirga.2 are being processed
# bio1 from Thermovirga.2 becomes bio18
# 1644 metabolites of Burkholderiales.1 are being processed
# Burkholderiales.1 biomass metabolite captured cpd11416_c18
# 1975 reactions of Burkholderiales.1 are being processed
# bio1 from Burkholderiales.1 becomes bio19
# 994 metabolites of Thiobacillus.1 are being processed
# Thiobacillus.1 biomass metabolite captured cpd11416_c19
# 1000 reactions of Thiobacillus.1 are being processed
# bio1 from Thiobacillus.1 becomes bio20
# 1094 metabolites of Hydrogenophaga.1 are being processed
# Hydrogenophaga.1 biomass metabolite captured cpd11416_c20
# 1118 reactions of Hydrogenophaga.1 are being processed
# bio1 from Hydrogenophaga.1 becomes bio21
# 1095 metabolites of Desulfovibrio.1 are being processed
# Desulfovibrio.1 biomass metabolite captured cpd11416_c21
# 1107 reactions of Desulfovibrio.1 are being processed
# bio1 from Desulfovibrio.1 becomes bio22
# 1521 metabolites of Ochrobactrum.1 are being processed
# Ochrobactrum.1 biomass metabolite captured cpd11416_c22
# 1764 reactions of Ochrobactrum.1 are being processed
# bio1 from Ochrobactrum.1 becomes bio23
# 1144 metabolites of Geobacteraceae.1 are being processed
# Geobacteraceae.1 biomass metabolite captured cpd11416_c23
# 1176 reactions of Geobacteraceae.1 are being processed
# bio1 from Geobacteraceae.1 becomes bio24
# 1131 metabolites of midas_g_30443.1 are being processed
# midas_g_30443.1 biomass metabolite captured cpd11416_c24
# 1186 reactions of midas_g_30443.1 are being processed
# bio1 from midas_g_30443.1 becomes bio25
# 1373 metabolites of Sphaerochaeta.5 are being processed
# Sphaerochaeta.5 biomass metabolite captured cpd11416_c25
# 1628 reactions of Sphaerochaeta.5 are being processed
# bio1 from Sphaerochaeta.5 becomes bio26
# 1574 metabolites of midas_g_2178.1 are being processed
# midas_g_2178.1 biomass metabolite captured cpd11416_c26
# 1901 reactions of midas_g_2178.1 are being processed
# bio1 from midas_g_2178.1 becomes bio27
# 1253 metabolites of midas_g_3409.1 are being processed
# midas_g_3409.1 biomass metabolite captured cpd11416_c27
# 1335 reactions of midas_g_3409.1 are being processed
# bio1 from midas_g_3409.1 becomes bio28
# 1202 metabolites of Aminiphilus.1 are being processed
# Aminiphilus.1 biomass metabolite captured cpd11416_c28
# 1282 reactions of Aminiphilus.1 are being processed
# bio1 from Aminiphilus.1 becomes bio29
# 1298 metabolites of Desulfurispora.1 are being processed
# Desulfurispora.1 biomass metabolite captured cpd11416_c29
# 1414 reactions of Desulfurispora.1 are being processed
# bio1 from Desulfurispora.1 becomes bio30
# 917 metabolites of midas_g_94288.1 are being processed
# midas_g_94288.1 biomass metabolite captured cpd11416_c30
# 969 reactions of midas_g_94288.1 are being processed
# bio1 from midas_g_94288.1 becomes bio31
# 1037 metabolites of Ercella.2 are being processed
# Ercella.2 biomass metabolite captured cpd11416_c31
# 1096 reactions of Ercella.2 are being processed
# bio1 from Ercella.2 becomes bio32
# 1195 metabolites of Christensenellaceae_R-7_group.1 are being processed
# Christensenellaceae_R-7_group.1 biomass metabolite captured cpd11416_c32
# 1297 reactions of Christensenellaceae_R-7_group.1 are being processed
# bio1 from Christensenellaceae_R-7_group.1 becomes bio33
# 939 metabolites of Acetoanaerobium.1 are being processed
# Acetoanaerobium.1 biomass metabolite captured cpd11416_c33
# 904 reactions of Acetoanaerobium.1 are being processed
# bio1 from Acetoanaerobium.1 becomes bio34
# 962 metabolites of Erysipelothrix.1 are being processed
# Erysipelothrix.1 biomass metabolite captured cpd11416_c34
# 1002 reactions of Erysipelothrix.1 are being processed
# bio1 from Erysipelothrix.1 becomes bio35
# 1256 metabolites of Anaerovorax.1 are being processed
# Anaerovorax.1 biomass metabolite captured cpd11416_c35
# 1365 reactions of Anaerovorax.1 are being processed
# bio1 from Anaerovorax.1 becomes bio36
# 1031 metabolites of Acetobacterium.1 are being processed
# Acetobacterium.1 biomass metabolite captured cpd11416_c36
# 1055 reactions of Acetobacterium.1 are being processed
# bio1 from Acetobacterium.1 becomes bio37
# Neither carbon consumption nor oxygen consumption are defined in P12_comm
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7
# 29
# 29 models are being processed
# 1425 metabolites of Methanobacterium.2 are being processed
# Methanobacterium.2 biomass metabolite captured cpd11416_c1
# 1659 reactions of Methanobacterium.2 are being processed
# bio1 from Methanobacterium.2 becomes bio2
# 1328 metabolites of Methanobacterium.1 are being processed
# Methanobacterium.1 biomass metabolite captured cpd11416_c2
# 1413 reactions of Methanobacterium.1 are being processed
# bio1 from Methanobacterium.1 becomes bio3
# 853 metabolites of Methanobacterium.3 are being processed
# Methanobacterium.3 biomass metabolite captured cpd11416_c3
# 810 reactions of Methanobacterium.3 are being processed
# bio1 from Methanobacterium.3 becomes bio4
# 749 metabolites of Methanobacteriaceae.1 are being processed
# Methanobacteriaceae.1 biomass metabolite captured cpd11416_c4
# 732 reactions of Methanobacteriaceae.1 are being processed
# bio1 from Methanobacteriaceae.1 becomes bio5
# 819 metabolites of Methanobacterium.5 are being processed
# Methanobacterium.5 biomass metabolite captured cpd11416_c5
# 788 reactions of Methanobacterium.5 are being processed
# bio1 from Methanobacterium.5 becomes bio6
# 1518 metabolites of Mesotoga.1 are being processed
# Mesotoga.1 biomass metabolite captured cpd11416_c6
# 1804 reactions of Mesotoga.1 are being processed
# bio1 from Mesotoga.1 becomes bio7
# 1218 metabolites of Syner-01.1 are being processed
# Syner-01.1 biomass metabolite captured cpd11416_c7
# 1316 reactions of Syner-01.1 are being processed
# bio1 from Syner-01.1 becomes bio8
# 1065 metabolites of Aminivibrio.1 are being processed
# Aminivibrio.1 biomass metabolite captured cpd11416_c8
# 1111 reactions of Aminivibrio.1 are being processed
# bio1 from Aminivibrio.1 becomes bio9
# 988 metabolites of LNR_A2-18.1 are being processed
# LNR_A2-18.1 biomass metabolite captured cpd11416_c9
# 985 reactions of LNR_A2-18.1 are being processed
# bio1 from LNR_A2-18.1 becomes bio10
# 1078 metabolites of Lentimicrobium.1 are being processed
# Lentimicrobium.1 biomass metabolite captured cpd11416_c10
# 1099 reactions of Lentimicrobium.1 are being processed
# bio1 from Lentimicrobium.1 becomes bio11
# 1440 metabolites of midas_g_36215.1 are being processed
# midas_g_36215.1 biomass metabolite captured cpd11416_c11
# 1736 reactions of midas_g_36215.1 are being processed
# bio1 from midas_g_36215.1 becomes bio12
# 975 metabolites of Petrimonas.1 are being processed
# Petrimonas.1 biomass metabolite captured cpd11416_c12
# 1019 reactions of Petrimonas.1 are being processed
# bio1 from Petrimonas.1 becomes bio13
# 1077 metabolites of Proteiniphilum.1 are being processed
# Proteiniphilum.1 biomass metabolite captured cpd11416_c13
# 1118 reactions of Proteiniphilum.1 are being processed
# bio1 from Proteiniphilum.1 becomes bio14
# 570 metabolites of midas_g_9269.1 are being processed
# midas_g_9269.1 biomass metabolite captured cpd11416_c14
# 599 reactions of midas_g_9269.1 are being processed
# bio1 from midas_g_9269.1 becomes bio15
# 1485 metabolites of Thermovirga.2 are being processed
# Thermovirga.2 biomass metabolite captured cpd11416_c15
# 1772 reactions of Thermovirga.2 are being processed
# bio1 from Thermovirga.2 becomes bio16
# 1644 metabolites of Burkholderiales.1 are being processed
# Burkholderiales.1 biomass metabolite captured cpd11416_c16
# 1975 reactions of Burkholderiales.1 are being processed
# bio1 from Burkholderiales.1 becomes bio17
# 994 metabolites of Thiobacillus.1 are being processed
# Thiobacillus.1 biomass metabolite captured cpd11416_c17
# 1000 reactions of Thiobacillus.1 are being processed
# bio1 from Thiobacillus.1 becomes bio18
# 1094 metabolites of Hydrogenophaga.1 are being processed
# Hydrogenophaga.1 biomass metabolite captured cpd11416_c18
# 1118 reactions of Hydrogenophaga.1 are being processed
# bio1 from Hydrogenophaga.1 becomes bio19
# 1095 metabolites of Desulfovibrio.1 are being processed
# Desulfovibrio.1 biomass metabolite captured cpd11416_c19
# 1107 reactions of Desulfovibrio.1 are being processed
# bio1 from Desulfovibrio.1 becomes bio20
# 1014 metabolites of midas_g_49937.1 are being processed
# midas_g_49937.1 biomass metabolite captured cpd11416_c20
# 1047 reactions of midas_g_49937.1 are being processed
# bio1 from midas_g_49937.1 becomes bio21
# 1574 metabolites of midas_g_2178.1 are being processed
# midas_g_2178.1 biomass metabolite captured cpd11416_c21
# 1901 reactions of midas_g_2178.1 are being processed
# bio1 from midas_g_2178.1 becomes bio22
# 1253 metabolites of midas_g_3409.1 are being processed
# midas_g_3409.1 biomass metabolite captured cpd11416_c22
# 1335 reactions of midas_g_3409.1 are being processed
# bio1 from midas_g_3409.1 becomes bio23
# 1202 metabolites of Aminiphilus.1 are being processed
# Aminiphilus.1 biomass metabolite captured cpd11416_c23
# 1282 reactions of Aminiphilus.1 are being processed
# bio1 from Aminiphilus.1 becomes bio24
# 1298 metabolites of Desulfurispora.1 are being processed
# Desulfurispora.1 biomass metabolite captured cpd11416_c24
# 1414 reactions of Desulfurispora.1 are being processed
# bio1 from Desulfurispora.1 becomes bio25
# 917 metabolites of midas_g_94288.1 are being processed
# midas_g_94288.1 biomass metabolite captured cpd11416_c25
# 969 reactions of midas_g_94288.1 are being processed
# bio1 from midas_g_94288.1 becomes bio26
# 1195 metabolites of Christensenellaceae_R-7_group.1 are being processed
# Christensenellaceae_R-7_group.1 biomass metabolite captured cpd11416_c26
# 1297 reactions of Christensenellaceae_R-7_group.1 are being processed
# bio1 from Christensenellaceae_R-7_group.1 becomes bio27
# 962 metabolites of Erysipelothrix.1 are being processed
# Erysipelothrix.1 biomass metabolite captured cpd11416_c27
# 1002 reactions of Erysipelothrix.1 are being processed
# bio1 from Erysipelothrix.1 becomes bio28
# 1256 metabolites of Anaerovorax.1 are being processed
# Anaerovorax.1 biomass metabolite captured cpd11416_c28
# 1365 reactions of Anaerovorax.1 are being processed
# bio1 from Anaerovorax.1 becomes bio29
# 1031 metabolites of Acetobacterium.1 are being processed
# Acetobacterium.1 biomass metabolite captured cpd11416_c29
# 1055 reactions of Acetobacterium.1 are being processed
# bio1 from Acetobacterium.1 becomes bio30
# Neither carbon consumption nor oxygen consumption are defined in Q_comm
# Community objective 1.0*bio1 - 1.0*bio1_reverse_b18f7

# %%
from json import load
abundances = load(open("modeling_files/ASVset_abundances.json", 'r'))
list(list(abundances.values())[0].values())[0]
# Out:
# 0.0035438998239284624

# %% [markdown]
# ## Test that the models are operational

# %%
from cobra.io import read_sbml_model
from glob import glob

# for path in glob("models/F34_comm.xml"):
# for path in glob("comm_models/G12_comm.xml"):
    # print(path.split("/")[-1])
model = read_sbml_model("comm_models/P12_comm.xml")
# break

# %%
print(model.objective)
display(model.summary())

# %%
model.reactions.bio1.reaction

# %%
bioReactions = []
for rxn in model.reactions:
    if "bio" in rxn.id:
        bioReactions.append(rxn.id)
bioReactions = sorted(bioReactions)
print(len(bioReactions), bioReactions)

# %%
bioCompounds = []
for cpd in model.metabolites:
    if "cpd11416" in cpd.id:
        bioCompounds.append(cpd.id)
bioCompounds = sorted(bioCompounds)
print(len(bioCompounds), bioCompounds)

# %% [markdown]
# # Community modeling

# %% [markdown]
# ## Load the community models

# %%
# %%time
from cobra.io import read_sbml_model
from tqdm import tqdm
from glob import glob

def load_models():
    models = {}
    num_models = 1
    modelID = "P12_comm"
    for model_path in tqdm(glob(f"comm_models/{modelID}.xml")[:num_models]):
        modelID = model_path.split("/")[-1].replace(".xml", '')
        print("loading", modelID)
        model = read_sbml_model(model_path)
        model.id = modelID
        models[modelID] = model
    return models

models = load_models()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# loading P12_comm
# 100%|██████████| 1/1 [01:24<00:00, 84.56s/it]
# CPU times: user 1min 22s, sys: 2.28 s, total: 1min 24s
# Wall time: 1min 24s

# %%
type(models[modelID].solver)
# Out:
# optlang.gurobi_interface.Model

# %%
# %%time
display(models)
print(models[modelID].objective)
display(models[modelID].summary())
# Out:
# {'P12_comm': <Model P12_comm at 0x7fa5adfb8070>}
# Maximize
# 1.0*bio1 - 1.0*bio1_reverse_b18f7
# <h3>Objective</h3><p>1.0 bio1 = 67.94829389738663</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>514.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00023_e0</td>
#       <td>EX_cpd00023_e0</td>
#       <td>10</td>
#       <td>5</td>
#       <td>5.26%</td>
#     </tr>
#     <tr>
#       <td>cpd00027_e0</td>
#       <td>EX_cpd00027_e0</td>
#       <td>10</td>
#       <td>6</td>
#       <td>6.32%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>0.1906</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00033_e0</td>
#       <td>EX_cpd00033_e0</td>
#       <td>10</td>
#       <td>2</td>
#       <td>2.11%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
#       <td>0.1906</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00035_e0</td>
#       <td>EX_cpd00035_e0</td>
#       <td>10</td>
#       <td>3</td>
#       <td>3.16%</td>
#     </tr>
#     <tr>
#       <td>cpd00039_e0</td>
#       <td>EX_cpd00039_e0</td>
#       <td>10</td>
#       <td>6</td>
#       <td>6.32%</td>
#     </tr>
#     <tr>
#       <td>cpd00041_e0</td>
#       <td>EX_cpd00041_e0</td>
#       <td>10</td>
#       <td>4</td>
#       <td>4.21%</td>
#     </tr>
#     <tr>
#       <td>cpd00051_e0</td>
#       <td>EX_cpd00051_e0</td>
#       <td>10</td>
#       <td>6</td>
#       <td>6.32%</td>
#     </tr>
#     <tr>
#       <td>cpd00053_e0</td>
#       <td>EX_cpd00053_e0</td>
#       <td>10</td>
#       <td>5</td>
#       <td>5.26%</td>
#     </tr>
#     <tr>
#       <td>cpd00054_e0</td>
#       <td>EX_cpd00054_e0</td>
#       <td>10</td>
#       <td>3</td>
#       <td>3.16%</td>
#     </tr>
#     <tr>
#       <td>cpd00058_e0</td>
#       <td>EX_cpd00058_e0</td>
#       <td>0.1906</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00060_e0</td>
#       <td>EX_cpd00060_e0</td>
#       <td>10</td>
#       <td>5</td>
#       <td>5.26%</td>
#     </tr>
#     <tr>
#       <td>cpd00063_e0</td>
#       <td>EX_cpd00063_e0</td>
#       <td>0.1906</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00065_e0</td>
#       <td>EX_cpd00065_e0</td>
#       <td>1.817</td>
#       <td>11</td>
#       <td>2.10%</td>
#     </tr>
#     <tr>
#       <td>cpd00066_e0</td>
#       <td>EX_cpd00066_e0</td>
#       <td>5.194</td>
#       <td>9</td>
#       <td>4.92%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td
td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 1min 10s, sys: 340 ms, total: 1min 10s
# Wall time: 1min 10s

# %% [markdown]
# ## Constraints

# %% [markdown]
# ### Process data

# %% [markdown]
# #### convert measurements into MSIDs

# %%
from collections import Counter
from pandas import read_csv, set_option
from json import dump

set_option("display.max_columns", None)

mapping = {"Media Acetate (mol/L)": "cpd00029_in", "Media Propionate (mol/L)": "cpd00141_in",
           "Media Butyrate (mol/L)": "cpd00211_in", "Waste Effluent Acetate (mol/L)": "cpd00029_out",
           "Waste Effluent Propionate (mol/L)": "cpd00141_out", "Waste Effluent Butyrate (mol/L)": "cpd00211_out",
           "Approximate Total Influent C (mol/min) based on Media recipe": "media_carbon_in",
           # "Media Total COD (mg/L) Hach": "media_cpd00007",
           "Measured Total Influent C (mol/min)": "carbon_in",
           "Gas Composition (% CH4)": "%cpd01024", "Gas Composition (% H2)": "%cpd11640", "Gas Composition (% CO2)": "%cpd00011",
           "CH4 breakthrough (mol/min)": "cpd01024_out", "H2 breakthrough (mol/min)": "cpd11640_out", "CO2 breakthrough (mol/min)": "cpd00011_out",
           "Accounted C (%) based on MT sensors": "accounted_C"}


data = read_csv("model_inputs/measurements/Summary_interpolated.csv")
data["Media Total COD (mg/L) Hach"] /= 32000
data["carbon_out"] = data["Waste Effluent Dissolved Inorganic Carbon (mol C/L)"] + data["Waste Effluent Dissolved Organic Carbon (mol C/L)"
                        ] + data["Effluent C as measured (mol/min)"]
data.rename(columns=mapping, inplace=True)
data = data[data["Biomass Sample ID"].notna()].set_index("Biomass Sample ID")
# print(Counter(data.columns))
data_df = data.T.to_dict()
dump(data_df, open("model_inputs/measurements/Summer_interpolated_MSDB.json", 'w'), indent=2)
data
# Out:
#                    Days of Operation  \
# Biomass Sample ID
# 10AB                             0.0
# A34                             21.5
# B34                             34.9
# C3                              68.5
# D34                             82.5
# E34                             90.9
# F34                            104.9
# G12                            125.9
# H34                            139.9
# I34                            149.1
# J12                            161.1
# K12                            181.9
# L12                            189.1
# M12                            209.9
# N12                            238.0
# P12                            283.1
# Q                              300.0
#
#                                                    Media description  \
# Biomass Sample ID
# 10AB                          DSMZ v1: Using DSMZ 120 without NaHCO3
# A34                            DSMZ v1.5: Using DSMZ 120 with NaHCO3
# B34                            DSMZ v1.5: Using DSMZ 120 with NaHCO3
# C3                      DSMZ v2: Dropped Na-Ac out of DSMZ 120 media
# D34                     DSMZ v2: Dropped Na-Ac out of DSMZ 120 media
# E34                     DSMZ v2: Dropped Na-Ac out of DSMZ 120 media
# F34                DSMZ v3: dropped yeast, casitone, and bicarb o...
# G12                Speece: put in Speece media + EDTA + cysteine ...
# H34                          Wolfe v1: put in modified wolfe + EDTA
# I34                Wolfe v2: put in KILLER wolfe + EDTA + switch ...
# J12                Wolfe v3: went back to modified wolfe + EDTA a...
# K12                Wolfe v3: went back to modified wolfe + EDTA a...
# L12                Wolfe v3: went back to modified wolfe + EDTA a...
# M12                Wolfe v3: went back to modified wolfe + EDTA a...
# N12                Wolfe v3: went back to modified wolfe + EDTA a...
# P12                Wolfe v3: went back to modified wolfe + EDTA a...
# Q                  Wolfe v3: went back to modified wolfe + EDTA a...
#
#                    Media changes  \
# Biomass Sample ID
# 10AB                         1.0
# A34                          1.0
# B34                          1.0
# C3                           1.0
# D34                          1.0
# E34                          1.0
# F34                          1.0
# G12                          1.0
# H34                          1.0
# I34                          1.0
# J12                          1.0
# K12                          NaN
# L12                          NaN
# M12                          NaN
# N12                          NaN
# P12                          NaN
# Q                            NaN
#
#                    Media Influent Flow Rate (mL/min) based on scales linear projection  \
# Biomass Sample ID
# 10AB                                                        0.059222
# A34                                                         0.059222
# B34                                                         2.079047
# C3                                                          0.059222
# D34                                                         0.059222
# E34                                                         0.059222
# F34                                                         0.059222
# G12                                                         0.059222
# H34                                                         0.053483
# I34                                                         0.053483
# J12                                                         0.059222
# K12                                                         0.059222
# L12                                                         0.059222
# M12                                                         0.059222
# N12                                                         0.059222
# P12                                                         0.059222
# Q                                                           0.059222
#
#                    pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH  \
# Biomass Sample ID
# 10AB                                                        0.000000
# A34                                                         0.000000
# B34                                                         0.000000
# C3                                                          0.000000
# D34                                                         0.040306
# E34                                                         0.071624
# F34                                                         0.000000
# G12                                                         0.018644
# H34                                                         0.032527
# I34                                                         0.043154
# J12                                                         0.042525
# K12                                                         0.044113
# L12                                                         0.031534
# M12                                                         0.023921
# N12                                                         0.033133
# P12                                                         0.026911
# Q                                                           0.046536
#
#                    cpd00029_in   cpd00141_in   cpd00211_in  \
# Biomass Sample ID
# 10AB                  0.035427  2.248985e-03           NaN
# A34                   0.028778  2.748583e-03           NaN
# B34                   0.018355  3.433353e-03           NaN
# C3                    0.016016  2.804749e-03           NaN
# D34                   0.013610  3.413268e-03           NaN
# E34                   0.018102  2.251129e-03           NaN
# F34                   0.000202  1.930381e-05           NaN
# G12                   0.000131  2.931436e-05           NaN
# H34                   0.000611  2.150906e-05           NaN
# I34                   0.001474  1.368551e-15  1.000000e-10
# J12                   0.001089  2.691276e-05  2.703467e+00
# K12                   0.000943  1.368551e-15  1.000000e-10
# L12                   0.001308  1.368551e-15  1.000000e-10
# M12                   0.000898  4.763960e-06  1.000000e-10
# N12                   0.001174  6.085343e-06  1.000000e-10
# P12                   0.000034  4.910360e-06  4.740000e-01
# Q                     0.000133  2.294375e-05  1.949500e+00
#
#                    Media Total VFA (mg COD/L)  Media Total COD (mg/L) Hach  \
# Biomass Sample ID
# 10AB                              2480.559207                     0.548295
# A34                               2116.936358                     0.548295
# B34                               1536.108186                     0.548295
# C3                                1319.241036                     0.488125
# D34                               1234.989138                     0.488125
# E34                               1389.354987                     0.488125
# F34                                 14.891589                     0.370312
# G12                                 11.469914                     0.010905
# H34                                 40.855168                     0.020750
# I34                                 92.856137                     0.013994
# J12                                 76.484166                     0.011773
# K12                                 59.380287                     0.020030
# L12                                 82.369556                     0.013680
# M12                                 57.082584                     0.023345
# N12                                 74.630767                     0.020585
# P12                                  3.546537                     0.023844
# Q                                   14.463519                     0.027502
#
#                    Media Ammonia (mol/L)  \
# Biomass Sample ID
# 10AB                                 NaN
# A34                                  NaN
# B34                                  NaN
# C3                              0.025907
# D34                             0.025907
# E34                             0.008510
# F34                             0.008139
# G12                             0.009413
# H34                             0.018967
# I34                             0.015972
# J12                             0.018837
# K12                             0.015866
# L12                             0.016066
# M12                             0.016665
# N12                             0.016195
# P12                             0.016348
# Q                               0.016817
#
#                    Media Dissolved Inorganic Carbon (mol C/L)  \
# Biomass Sample ID
# 10AB                                                      NaN
# A34                                                  0.051964
# B34                                                  0.040055
# C3                                                   0.020676
# D34                                                  0.005913
# E34                                                  0.013771
# F34                                                  0.000000
# G12                                                  0.000000
# H34                                                  0.000073
# I34                                                  0.000626
# J12                                                  0.000004
# K12                                                  0.000000
# L12                                                  0.000146
# M12                                                  0.001270
# N12                                                  0.000075
# P12                                                  0.001611
# Q                                                         NaN
#
#                    Media Dissolved Organic Carbon (mol C/L)  media_carbon_in  \
# Biomass Sample ID
# 10AB                                                    NaN     2.670566e-05
# A34                                                0.410238     2.811553e-05
# B34                                                0.352996     2.811553e-05
# C3                                                 0.427532     2.129103e-05
# D34                                                0.477081     2.129103e-05
# E34                                                0.475770     2.129103e-05
# F34                                                0.316970     1.493987e-05
# G12                                                0.035153     1.972551e-07
# H34                                                0.020854     4.467830e-07
# I34                                                0.015456     3.847735e-07
# J12                                                0.021145     4.034930e-07
# K12                                                0.019662     6.494302e-07
# L12                                                0.015957     6.494302e-07
# M12                                                0.018259     6.494302e-07
# N12                                                0.017718     6.494302e-07
# P12                                                0.013381     6.494302e-07
# Q                                                  0.016068     6.494302e-07
#
#                    H2 delivery rate setpoint (mL/min)  \
# Biomass Sample ID
# 10AB                                         1.091525
# A34                                          0.545762
# B34                                          1.091525
# C3                                           0.988000
# D34                                          1.200000
# E34                                          1.200000
# F34                                          1.000000
# G12                                          1.200000
# H34                                          1.200000
# I34                                          0.600000
# J12                                          1.200000
# K12                                          1.250000
# L12                                          1.331000
# M12                                          1.480000
# N12                                          1.583000
# P12                                          2.775000
# Q                                            2.770000
#
#                    CO2 delivery rate setpoint (mL/min)  \
# Biomass Sample ID
# 10AB                                             0.250
# A34                                              0.250
# B34                                              0.250
# C3                                               0.344
# D34                                              0.300
# E34                                              0.300
# F34                                              0.250
# G12                                              0.300
# H34                                              0.300
# I34                                              0.300
# J12                                              0.400
# K12                                              0.337
# L12                                              0.337
# M12                                              0.379
# N12                                              0.397
# P12                                              0.701
# Q                                                0.701
#
#                    H2 delivery rate (mol/min)  H2 delivery rate (e-eq/min)  \
# Biomass Sample ID
# 10AB                                 0.000049                     0.000268
# A34                                  0.000024                     0.000134
# B34                                  0.000049                     0.000268
# C3                                   0.000044                     0.000243
# D34                                  0.000054                     0.000295
# E34                                  0.000054                     0.000295
# F34                                  0.000045                     0.000246
# G12                                  0.000054                     0.000295
# H34                                  0.000054                     0.000295
# I34                                  0.000027                     0.000147
# J12                                  0.000054                     0.000295
# K12                                  0.000056                     0.000307
# L12                                  0.000059                     0.000327
# M12                                  0.000066                     0.000363
# N12                                  0.000071                     0.000389
# P12                                  0.000124                     0.000681
# Q                                    0.000124                     0.000680
#
#                    H2 delivery (g COD/min)  CO2 delivery rate (mol/min)  \
# Biomass Sample ID
# 10AB                              0.012475                     0.000011
# A34                               0.006237                     0.000011
# B34                               0.012475                     0.000011
# C3                                0.011291                     0.000015
# D34                               0.013714                     0.000013
# E34                               0.013714                     0.000013
# F34                               0.011429                     0.000011
# G12                               0.013714                     0.000013
# H34                               0.013714                     0.000013
# I34                               0.006857                     0.000013
# J12                               0.013714                     0.000018
# K12                               0.014286                     0.000015
# L12                               0.015211                     0.000015
# M12                               0.016914                     0.000017
# N12                               0.018091                     0.000018
# P12                               0.031714                     0.000031
# Q                                 0.031657                     0.000031
#
#                    H2:CO2 ratio  carbon_in  \
# Biomass Sample ID
# 10AB                   4.366099   0.000011
# A34                    2.183050   0.000011
# B34                    4.366099   0.000011
# C3                     2.872093   0.000015
# D34                    4.000000   0.000042
# E34                    4.000000   0.000013
# F34                    4.000000   0.000011
# G12                    4.000000   0.000013
# H34                    4.000000   0.000013
# I34                    2.000000   0.000013
# J12                    3.000000   0.000018
# K12                    3.709199   0.000015
# L12                    3.949555   0.000015
# M12                    3.905013   0.000017
# N12                    3.987406   0.000018
# P12                    3.958631   0.000031
# Q                      3.951498   0.000031
#
#                    Approximate Total Influent C (mol/min) based on Media recipe + gas  \
# Biomass Sample ID
# 10AB                                                        0.000038
# A34                                                         0.000039
# B34                                                         0.000039
# C3                                                          0.000037
# D34                                                         0.000035
# E34                                                         0.000035
# F34                                                         0.000026
# G12                                                         0.000014
# H34                                                         0.000014
# I34                                                         0.000014
# J12                                                         0.000018
# K12                                                         0.000016
# L12                                                         0.000016
# M12                                                         0.000018
# N12                                                         0.000018
# P12                                                         0.000032
# Q                                                           0.000032
#
#                    Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1  \
# Biomass Sample ID
# 10AB                                                        0.059222
# A34                                                         0.059222
# B34                                                         2.079047
# C3                                                          0.059222
# D34                                                         0.099527
# E34                                                         0.130845
# F34                                                         0.059222
# G12                                                         0.077866
# H34                                                         0.086011
# I34                                                         0.096638
# J12                                                         0.101746
# K12                                                         0.103335
# L12                                                         0.090756
# M12                                                         0.083142
# N12                                                         0.092355
# P12                                                         0.086132
# Q                                                           0.105758
#
#                    cpd00029_out  cpd00141_out  cpd00211_out  \
# Biomass Sample ID
# 10AB                   0.035564      0.035564           NaN
# A34                    0.026992      0.026992           NaN
# B34                    0.014906      0.014906           NaN
# C3                     0.000792      0.000792           NaN
# D34                    0.000798      0.000798           NaN
# E34                    0.000307      0.000307           NaN
# F34                    0.002661      0.002661           NaN
# G12                    0.000414      0.000414           NaN
# H34                    0.000207      0.000207           NaN
# I34                    0.000230      0.000230           NaN
# J12                    0.000128      0.000128           NaN
# K12                    0.000164      0.000164           NaN
# L12                    0.000120      0.000120           NaN
# M12                    0.000074      0.000074           NaN
# N12                    0.000051      0.000051           NaN
# P12                    0.000051      0.000051           NaN
# Q                      0.000091      0.000091           NaN
#
#                    Waste Effluent Total VFA (mg COD/L)  \
# Biomass Sample ID
# 10AB                                       2446.060693
# A34                                        1794.152069
# B34                                        1212.358448
# C3                                          778.987585
# D34                                         724.186390
# E34                                         343.357172
# F34                                         257.536549
# G12                                          33.548757
# H34                                          15.916565
# I34                                          30.771788
# J12                                          23.724205
# K12                                          31.171463
# L12                                          16.787406
# M12                                           6.052282
# N12                                           5.659541
# P12                                           4.727244
# Q                                            12.391541
#
#                    Waste Effluent Total COD (mg/L) Hach  \
# Biomass Sample ID
# 10AB                                                NaN
# A34                                                 NaN
# B34                                                 NaN
# C3                                                  NaN
# D34                                                 NaN
# E34                                                 NaN
# F34                                         4005.714286
# G12                                          130.250000
# H34                                          754.000000
# I34                                          258.400000
# J12                                          279.818182
# K12                                          354.173913
# L12                                          277.937500
# M12                                          503.741935
# N12                                          552.129032
# P12                                          542.600000
# Q                                            711.032258
#
#                    Waste Effluent Ammonia (mol/L)  \
# Biomass Sample ID
# 10AB                                          NaN
# A34                                           NaN
# B34                                           NaN
# C3                                       0.019082
# D34                                      0.027727
# E34                                      0.029437
# F34                                      0.016401
# G12                                      0.008280
# H34                                      0.009518
# I34                                      0.016025
# J12                                      0.017458
# K12                                      0.017256
# L12                                      0.017273
# M12                                      0.015989
# N12                                      0.017044
# P12                                      0.015220
# Q                                        0.015521
#
#                    Waste Effluent Dissolved Inorganic Carbon (mol C/L)  \
# Biomass Sample ID
# 10AB                                                        0.035417
# A34                                                         0.000800
# B34                                                         0.002331
# C3                                                          0.016326
# D34                                                         0.027365
# E34                                                         0.022573
# F34                                                         0.017713
# G12                                                         0.001838
# H34                                                         0.003420
# I34                                                         0.000149
# J12                                                         0.006254
# K12                                                         0.005630
# L12                                                         0.002036
# M12                                                         0.002338
# N12                                                         0.002584
# P12                                                         0.001592
# Q                                                                NaN
#
#                    Waste Effluent Dissolved Organic Carbon (mol C/L)  \
# Biomass Sample ID
# 10AB                                                        0.468748
# A34                                                         0.030954
# B34                                                         0.057877
# C3                                                          0.031968
# D34                                                         0.083942
# E34                                                         0.065969
# F34                                                         0.043139
# G12                                                         0.011108
# H34                                                         0.027700
# I34                                                         0.009506
# J12                                                         0.018868
# K12                                                         0.023745
# L12                                                         0.015809
# M12                                                         0.013102
# N12                                                         0.014787
# P12                                                         0.012646
# Q                                                           0.016659
#
#                    Gas Flow Out (mL/min at STP)  %cpd01024  %cpd11640  \
# Biomass Sample ID
# 10AB                                   1.027461   0.000000   0.875885
# A34                                    0.507551   0.404956   0.587181
# B34                                    0.552281   0.270950   0.722636
# C3                                     0.848818   0.775053   0.003683
# D34                                    0.817240   0.755987   0.036939
# E34                                    0.934852   0.805937   0.053865
# F34                                    0.509447   0.908542   0.011945
# G12                                    0.237228   0.953264   0.039489
# H34                                    0.262430   0.982670   0.009917
# I34                                    0.351816   0.716158   0.240375
# J12                                    0.293182   0.912006   0.051939
# K12                                    0.303513   0.919604   0.049340
# L12                                    0.303482   0.948323   0.035070
# M12                                    0.358940   0.946802   0.039671
# N12                                    0.383665   0.951829   0.043160
# P12                                    0.724067   0.888664   0.110011
# Q                                      0.689144   0.929637   0.038145
#
#                    %cpd00011  CH4 Production (mol/min)  cpd11640_out  \
# Biomass Sample ID
# 10AB                0.124115                  0.000000  4.017581e-05
# A34                 0.007863                  0.000009  1.330465e-05
# B34                 0.006414                  0.000007  1.781687e-05
# A34                                            NaN
# B34                                            NaN
# C3                                    4.594952e-07
# D34                                   4.107741e-07
# E34                                   7.199523e-08
# F34                                   2.322803e-07
# G12                                   3.136280e-07
# H34                                   1.556660e-07
# I34                                   5.651073e-07
# J12                                   5.889675e-07
# K12                                   2.698194e-07
# L12                                   2.996437e-07
# M12                                   2.213928e-07
# N12                                   1.188528e-06
# P12                                   4.673642e-07
# Q                                     9.493365e-07
#
#                    Total Effluent C (mol/min) based on MT sensors  \
# Biomass Sample ID
# 10AB                                                     0.000006
# A34                                                      0.000010
# B34                                                      0.000007
# C3                                                       0.000038
# D34                                                      0.000036
# E34                                                      0.000040
# F34                                                      0.000023
# G12                                                      0.000010
# H34                                                      0.000012
# I34                                                      0.000012
# J12                                                      0.000013
# K12                                                      0.000013
# L12                                                      0.000014
# M12                                                      0.000016
# N12                                                      0.000017
# P12                                                      0.000030
# Q                                                        0.000031
#
#                    H2 Conversion to CH4 Efficiency (%)  \
# Biomass Sample ID
# 10AB                                          0.000000
# A34                                           1.506413
# B34                                           0.548372
# C3                                            2.663479
# D34                                           2.059409
# E34                                           2.511439
# F34                                           1.851416
# G12                                           0.753802
# H34                                           0.859607
# I34                                           1.679706
# J12                                           0.891277
# K12                                           0.893159
# L12                                           0.864911
# M12                                           0.918500
# N12                                           0.922763
# P12                                           0.927498
# Q                                             0.925131
#
#                    H2 conversion to CH4 efficiency (30-day rolling average)  \
# Biomass Sample ID
# 10AB                                                             NaN
# A34                                                              NaN
# B34                                                         1.413849
# C3                                                          1.775951
# D34                                                         2.073412
# E34                                                         2.258250
# F34                                                         1.945535
# G12                                                         1.368538
# H34                                                         1.013967
# I34                                                         0.963561
# J12                                                         1.016219
# K12                                                         0.889548
# L12                                                         0.899564
# M12                                                         0.886350
# N12                                                         0.890604
# P12                                                         0.906312
# Q                                                           0.904294
#
#                    Accounted H2 (%)  Unaccounted H2 (%)  \
# Biomass Sample ID
# 10AB                       0.824478            0.175522
# A34                        2.052482           -1.052482
# B34                        0.914005            0.085995
# C3                         2.666644           -1.666644
# D34                        2.084566           -1.084566
# E34                        2.553402           -1.553402
# F34                        1.857502           -0.857502
# G12                        0.761608            0.238392
# H34                        0.861776            0.138224
# I34                        1.820652           -0.820652
# J12                        0.903967            0.096033
# K12                        0.905139            0.094861
# L12                        0.872907            0.127093
# M12                        0.928121            0.071879
# N12                        0.933224            0.066776
# P12                        0.956203            0.043797
# Q                          0.934621            0.065379
#
#                    C gas only Conversion Efficiency to CH4 (%)  \
# Biomass Sample ID
# 10AB                                                  0.000000
# A34                                                   0.822143
# B34                                                   0.598562
# C3                                                    1.912440
# D34                                                   2.059409
# E34                                                   2.511439
# F34                                                   1.851416
# G12                                                   0.753802
# H34                                                   0.859607
# I34                                                   0.839853
# J12                                                   0.668458
# K12                                                   0.828226
# L12                                                   0.854003
# M12                                                   0.896689
# N12                                                   0.919858
# P12                                                   0.917905
# Q                                                     0.913913
#
#                    CO2 conversion to CH4 efficiency (30-day rolling average)  \
# Biomass Sample ID
# 10AB                                                             NaN

#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0,
#   'cpd00029_in': 0.0354271680216802,
#   'cpd00141_in': 0.0022489849915606,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 2480.559206666667,
#   'Media Total COD (mg/L) Hach': 0.5482945644886017,
#   'Media Ammonia (mol/L)': nan,
#   'Media Dissolved Inorganic Carbon (mol C/L)': nan,
#   'Media Dissolved Organic Carbon (mol C/L)': nan,
#   'media_carbon_in': 2.6705660146199203e-05,
#   'H2 delivery rate setpoint (mL/min)': 1.0915248032216731,
#   'CO2 delivery rate setpoint (mL/min)': 0.25,
#   'H2 delivery rate (mol/min)': 4.872878585811041e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002680083222196,
#   'H2 delivery (g COD/min)': 0.0124745691796762,
#   'CO2 delivery rate (mol/min)': 1.1160714285714286e-05,
#   'H2:CO2 ratio': 4.3660992128866924,
#   'carbon_in': 1.1160714285714286e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.786637443191349e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0592216175,
#   'cpd00029_out': 0.0355636856368563,
#   'cpd00141_out': 0.0355636856368563,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 2446.060693333333,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': nan,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0354169990878835,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.4687478609344043,
#   'Gas Flow Out (mL/min at STP)': 1.027461111051305,
#   '%cpd01024': 0.0,
#   '%cpd11640': 0.8758853333333333,
#   '%cpd00011': 0.1241146666666666,
#   'CH4 Production (mol/min)': 0.0,
#   'cpd11640_out': 4.017580882768791e-05,
#   'cpd00011_out': 5.692990772816772e-06,
#   'Specific CH4 production Rate (m3/m3d) .155': 0.0,
#   'Specific CH4 production Rate (L/m2d)': 0.0,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 2.444631971134612e-07,
#   'Effluent C as measured (mol/min)': 2.776000652420049e-05,
#   'Effluent C as biomass (mol/min)': nan,
#   'Total Effluent C (mol/min) based on MT sensors': 5.937453969930233e-06,
#   'H2 Conversion to CH4 Efficiency (%)': 0.0,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': nan,
#   'Accounted H2 (%)': 0.824477936812806,
#   'Unaccounted H2 (%)': 0.175522063187194,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.0,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': nan,
#   'C Conversion to CH4 Efficiency (%)': 0.0,
#   'accounted_C': 0.1568001705736632,
#   'Unaccounted C (%) based on MT sensors': 0.8431998294263368,
#   'Projected Cell Yield (g/min)': 0.0009979655343741,
#   'R-TSS': nan,
#   'W-TSS': nan,
#   'R-VSS': nan,
#   'W-VSS': nan,
#   'SRT': nan,
#   'HRT': nan,
#   'pH': 6.902,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.05,
#   'ORP (mV)': -305.292,
#   'Temp ©': 30.647,
#   '[H]': 1.2531411749414145e-07,
#   '[CO2aq]': 0.0009327637528687,
#   'pKa1': 6.367441674074073,
#   'pKa2': 10.323184679629628,
#   '[HCO3-]': 0.003193963781083,
#   '[CO3-2]': 1.2110032464186114e-06,
#   'TIC': 0.0041279385371981,
#   'carbon_out': 0.5041926200288119},
#  'A34': {'Days of Operation': 21.5,
#   'Media description': 'DSMZ v1.5: Using DSMZ 120 with NaHCO3',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0,
#   'cpd00029_in': 0.0287776266905861,
#   'cpd00141_in': 0.002748583100262,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 2116.9363584037555,
#   'Media Total COD (mg/L) Hach': 0.5482945644886017,
#   'Media Ammonia (mol/L)': nan,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0519639129903411,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.4102378796138061,
#   'media_carbon_in': 2.8115530835320275e-05,
#   'H2 delivery rate setpoint (mL/min)': 0.5457624016108366,
#   'CO2 delivery rate setpoint (mL/min)': 0.25,
#   'H2 delivery rate (mol/min)': 2.4364392929055205e-05,
#   'H2 delivery rate (e-eq/min)': 0.0001340041611098,
#   'H2 delivery (g COD/min)': 0.0062372845898381,
#   'CO2 delivery rate (mol/min)': 1.1160714285714286e-05,
#   'H2:CO2 ratio': 2.1830496064433462,
#   'carbon_in': 1.1160714285714286e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.927624512103456e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0592216175,
#   'cpd00029_out': 0.0269917907938203,
#   'cpd00141_out': 0.0269917907938203,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 1794.152069002546,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': nan,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0007997889837332,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0309541390457628,
#   'Gas Flow Out (mL/min at STP)': 0.5075506548787121,
#   '%cpd01024': 0.4049563333333333,
#   '%cpd11640': 0.587181,
#   '%cpd00011': 0.0078633333333333,
#   'CH4 Production (mol/min)': 9.175707686634614e-06,
#   'cpd11640_out': 1.3304647369747188e-05,
#   'cpd00011_out': 1.7817142780638124e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 1.9094943686457173,
#   'Specific CH4 production Rate (L/m2d)': 2.039776892764205,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 3.321555679862964e-07,
#   'Effluent C as measured (mol/min)': 1.8331541826099869e-06,
#   'Effluent C as biomass (mol/min)': nan,
#   'Total Effluent C (mol/min) based on MT sensors': 9.686034682427291e-06,
#   'H2 Conversion to CH4 Efficiency (%)': 1.5064126922189522,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': nan,
#   'Accounted H2 (%)': 2.052482007735574,
#   'Unaccounted H2 (%)': -1.052482007735574,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.8221434087224614,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': nan,
#   'C Conversion to CH4 Efficiency (%)': 0.2336197785291986,
#   'accounted_C': 0.2466130520516558,
#   'Unaccounted C (%) based on MT sensors': 0.7533869479483442,
#   'Projected Cell Yield (g/min)': 0.000498982767187,
#   'R-TSS': nan,
#   'W-TSS': nan,
#   'R-VSS': nan,
#   'W-VSS': nan,
#   'SRT': nan,
#   'HRT': nan,
#   'pH': 7.04,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.036,
#   'ORP (mV)': -519.691,
#   'Temp ©': 36.422,
#   '[H]': 9.120108393559096e-08,
#   '[CO2aq]': 0.0009324456361198,
#   'pKa1': 6.33997834074074,
#   'pKa2': 10.276567596296296,
#   '[HCO3-]': 0.0046735315626451,
#   '[CO3-2]': 2.7106758323604203e-06,
#   'TIC': 0.0056086878745974,
#   'carbon_out': 0.03175576118367861},
#  'B34': {'Days of Operation': 34.9,
#   'Media description': 'DSMZ v1.5: Using DSMZ 120 with NaHCO3',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 2.0790472319,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0,
#   'cpd00029_in': 0.0183549622600098,
#   'cpd00141_in': 0.0034333525444441,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 1536.1081855633802,
#   'Media Total COD (mg/L) Hach': 0.5482945644886017,
#   'Media Ammonia (mol/L)': nan,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0400550617528344,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.3529959262580938,
#   'media_carbon_in': 2.8115530835320275e-05,
#   'H2 delivery rate setpoint (mL/min)': 1.0915248032216731,
#   'CO2 delivery rate setpoint (mL/min)': 0.25,
#   'H2 delivery rate (mol/min)': 4.872878585811041e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002680083222196,
#   'H2 delivery (g COD/min)': 0.0124745691796762,
#   'CO2 delivery rate (mol/min)': 1.1160714285714286e-05,
#   'H2:CO2 ratio': 4.3660992128866924,
#   'carbon_in': 1.1160714285714286e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.927624512103456e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 2.0790472319,
#   'cpd00029_out': 0.0149064138132256,
#   'cpd00141_out': 0.0149064138132256,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 1212.3584476642725,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': nan,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0023308136097369,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0578773518234808,
#   'Gas Flow Out (mL/min at STP)': 0.5522805951970167,
#   '%cpd01024': 0.2709499999999999,
#   '%cpd11640': 0.722636,
#   '%cpd00011': 0.0064139999999999,
#   'CH4 Production (mol/min)': 6.680376217349626e-06,
#   'cpd11640_out': 1.7816867865660325e-05,
#   'cpd00011_out': 1.581396311425743e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 1.3902078404311586,
#   'Specific CH4 production Rate (L/m2d)': 1.4850600638651246,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 4.810819712499789e-07,
#   'Effluent C as measured (mol/min)': 3.4275903916031133e-06,
#   'Effluent C as biomass (mol/min)': nan,
#   'Total Effluent C (mol/min) based on MT sensors': 7.31959781974218e-06,
#   'H2 Conversion to CH4 Efficiency (%)': 0.5483720638393658,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.4138487840094751,
#   'Accounted H2 (%)': 0.9140053861540216,
#   'Unaccounted H2 (%)': 0.0859946138459785,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.5985617090745265,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.6692968559840901,
#   'C Conversion to CH4 Efficiency (%)': 0.170086936690695,
#   'accounted_C': 0.1863619548453764,
#   'Unaccounted C (%) based on MT sensors': 0.8136380451546236,
#   'Projected Cell Yield (g/min)': 0.0009979655343741,
#   'R-TSS': nan,
#   'W-TSS': nan,
#   'R-VSS': nan,
#   'W-VSS': nan,
#   'SRT': nan,
#   'HRT': nan,
#   'pH': 7.044,
#   'CO2 (mg/L, aqueous dissolved CO2)': 1.675,
#   'ORP (mV)': -520.272,
#   'Temp ©': 36.75,
#   '[H]': 9.03649473722302e-08,
#   '[CO2aq]': 3.806039673703106e-05,
#   'pKa1': 6.338418518518518,
#   'pKa2': 10.273919907407407,
#   '[HCO3-]': 0.000193221207796,
#   '[CO3-2]': 1.1379806699638713e-07,
#   'TIC': 0.0002313954026,
#   'carbon_out': 0.0602115930236093},
#  'C3': {'Days of Operation': 68.5,
#   'Media description': 'DSMZ v2: Dropped Na-Ac out of DSMZ 120 media',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0,
#   'cpd00029_in': 0.0160162940379402,
#   'cpd00141_in': 0.0028047488709456,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 1319.241036,
#   'Media Total COD (mg/L) Hach': 0.488125,
#   'Media Ammonia (mol/L)': 0.0259072225484439,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0206764647728977,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.4275322017964478,
#   'media_carbon_in': 2.1291029790152428e-05,
#   'H2 delivery rate setpoint (mL/min)': 0.988,
#   'CO2 delivery rate setpoint (mL/min)': 0.344,
#   'H2 delivery rate (mol/min)': 4.410714285714286e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002425892857142,
#   'H2 delivery (g COD/min)': 0.0112914285714285,
#   'CO2 delivery rate (mol/min)': 1.5357142857142855e-05,
#   'H2:CO2 ratio': 2.872093023255814,
#   'carbon_in': 1.5357142857142855e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.664817264729528e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0592216175,
#   'cpd00029_out': 0.0007915869599871,
#   'cpd00141_out': 0.0007915869599871,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 778.9875847058823,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': 0.0190816206694068,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0163263794445784,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0319680284400371,
#   'Gas Flow Out (mL/min at STP)': 0.8488182513554042,
#   '%cpd01024': 0.7750533183227921,
#   '%cpd11640': 0.003683388715973,
#   '%cpd00011': 0.221264232960907,
#   'CH4 Production (mol/min)': 2.93696161770516e-05,
#   'cpd11640_out': 1.3957712361403798e-07,
#   'cpd00011_out': 8.384514254882672e-06,
#   'Specific CH4 production Rate (m3/m3d) .155': 6.111911867141784,
#   'Specific CH4 production Rate (L/m2d)': 6.528920326719343,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 3.3476809521220176e-07,
#   'Effluent C as measured (mol/min)': 1.922889999154512e-06,
#   'Effluent C as biomass (mol/min)': 4.594951599511141e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 3.808889852714648e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 2.6634793618054893,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.775950748523209,
#   'Accounted H2 (%)': 2.6666438633935,
#   'Unaccounted H2 (%)': -1.6666438633935,
#   'C gas only Conversion Efficiency to CH4 (%)': 1.9124401231568489,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.510110219642912,
#   'C Conversion to CH4 Efficiency (%)': 0.8013937409569354,
#   'accounted_C': 1.039312352452518,
#   'Unaccounted C (%) based on MT sensors': -0.0393123524525178,
#   'Projected Cell Yield (g/min)': 0.0009033142857142,
#   'R-TSS': 382.5571428571429,
#   'W-TSS': 216.0857142857143,
#   'R-VSS': 298.01428571428573,
#   'W-VSS': 153.97142857142856,
#   'SRT': 5.7498878705738665,
#   'HRT': 5.382529650437885,
#   'pH': 7.045,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.037,
#   'ORP (mV)': -513.338,
#   'Temp ©': 36.225,
#   '[H]': 9.015711376059569e-08,
#   '[CO2aq]': 0.0009324683587448,
#   'pKa1': 6.340915185185184,
#   'pKa2': 10.278157824074071,
#   '[HCO3-]': 0.0047175761450964,
#   '[CO3-2]': 2.757789378800108e-06,
#   'TIC': 0.00565280229322,
#   'carbon_out': 0.048296330774614656},
#  'D34': {'Days of Operation': 82.5,
#   'Media description': 'DSMZ v2: Dropped Na-Ac out of DSMZ 120 media',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0403056158300799,
#   'cpd00029_in': 0.0136102377625338,
#   'cpd00141_in': 0.003413268099083,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 1234.9891378125,
#   'Media Total COD (mg/L) Hach': 0.488125,
#   'Media Ammonia (mol/L)': 0.0259072225484439,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0059134822031471,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.4770806908133806,
#   'media_carbon_in': 2.1291029790152428e-05,
#   'H2 delivery rate setpoint (mL/min)': 1.2,
#   'CO2 delivery rate setpoint (mL/min)': 0.3,
#   'H2 delivery rate (mol/min)': 5.357142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002946428571428,
#   'H2 delivery (g COD/min)': 0.0137142857142857,
#   'CO2 delivery rate (mol/min)': 1.3392857142857142e-05,
#   'H2:CO2 ratio': 4.0,
#   'carbon_in': 4.164634733084293e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.468388693300957e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0995272333300799,
#   'cpd00029_out': 0.0007984851113754,
#   'cpd00141_out': 0.0007984851113754,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 724.1863898780489,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': 0.0277271481698962,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0273647017416292,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0839424442933829,
#   'Gas Flow Out (mL/min at STP)': 0.8172403486690635,
#   '%cpd01024': 0.7559866666666666,
#   '%cpd11640': 0.0369386666666666,
#   '%cpd00011': 0.207075,
#   'CH4 Production (mol/min)': 2.75813753149924e-05,
#   'cpd11640_out': 1.3476682511623654e-06,
#   'cpd00011_out': 7.554912732171711e-06,
#   'Specific CH4 production Rate (m3/m3d) .155': 5.739773175228352,
#   'Specific CH4 production Rate (L/m2d)': 6.131391055550618,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 5.304873742311574e-07,
#   'Effluent C as measured (mol/min)': 8.354559239484763e-06,
#   'Effluent C as biomass (mol/min)': 4.1077414684514594e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 3.5666775421395266e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 2.059409356852766,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 2.07341231286011,
#   'Accounted H2 (%)': 2.0845658308744635,
#   'Unaccounted H2 (%)': -1.0845658308744637,
#   'C gas only Conversion Efficiency to CH4 (%)': 2.059409356852766,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.660528492612951,
#   'C Conversion to CH4 Efficiency (%)': 0.7952215784887268,
#   'accounted_C': 1.028338475739011,
#   'Unaccounted C (%) based on MT sensors': -0.028338475739011,
#   'Projected Cell Yield (g/min)': 0.0010971428571428,
#   'R-TSS': 2499.718309859155,
#   'W-TSS': 175.3661971830986,
#   'R-VSS': 2344.0704225352115,
#   'W-VSS': 87.47887323943661,
#   'SRT': 21.80503939094516,
#   'HRT': 2.860746879981554,
#   'pH': 7.023,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.037,
#   'ORP (mV)': -508.645,
#   'Temp ©': 34.388,
#   '[H]': 9.484184633008949e-08,
#   '[CO2aq]': 0.0009324683587448,
#   'pKa1': 6.3496511407407406,
#   'pKa2': 10.292986496296296,
#   '[HCO3-]': 0.0043952437310301,
#   '[CO3-2]': 2.360459029979337e-06,
#   'TIC': 0.0053300725488048,
#   'carbon_out': 0.11131550059425159},
#  'E34': {'Days of Operation': 90.9,
#   'Media description': 'DSMZ v2: Dropped Na-Ac out of DSMZ 120 media',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0716236617882009,
#   'cpd00029_in': 0.0181015130984642,
#   'cpd00141_in': 0.0022511290543314,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 1389.3549866666665,
#   'Media Total COD (mg/L) Hach': 0.488125,
#   'Media Ammonia (mol/L)': 0.0085096887844979,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0137705174951625,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.4757696354615245,
#   'media_carbon_in': 2.1291029790152428e-05,
#   'H2 delivery rate setpoint (mL/min)': 1.2,
#   'CO2 delivery rate setpoint (mL/min)': 0.3,
#   'H2 delivery rate (mol/min)': 5.357142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002946428571428,
#   'H2 delivery (g COD/min)': 0.0137142857142857,
#   'CO2 delivery rate (mol/min)': 1.3392857142857142e-05,
#   'H2:CO2 ratio': 4.0,
#   'carbon_in': 1.3392857142857142e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.468388693300957e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.1308452792882009,
#   'cpd00029_out': 0.0003072210930442,
#   'cpd00141_out': 0.0003072210930442,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 343.3571716666667,
#   'Waste Effluent Total COD (mg/L) Hach': nan,
#   'Waste Effluent Ammonia (mol/L)': 0.0294371277577384,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0225733565821271,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0659685606832525,
#   'Gas Flow Out (mL/min at STP)': 0.9348519628354282,
#   '%cpd01024': 0.805937,
#   '%cpd11640': 0.0538646666666666,
#   '%cpd00011': 0.1401986666666666,
#   'CH4 Production (mol/min)': 3.363534760587931e-05,
#   'cpd11640_out': 2.2480129178932768e-06,
#   'cpd00011_out': 5.851116014296573e-06,
#   'Specific CH4 production Rate (m3/m3d) .155': 6.999624337904793,
#   'Specific CH4 production Rate (L/m2d)': 7.477200360959634,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 7.407089160417432e-07,
#   'Effluent C as measured (mol/min)': 7.012262506106897e-06,
#   'Effluent C as biomass (mol/min)': 7.199522815829334e-08,
#   'Total Effluent C (mol/min) based on MT sensors': 4.0227172536217626e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 2.511439287905655,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 2.2582499798922826,
#   'Accounted H2 (%)': 2.55340219570633,
#   'Unaccounted H2 (%)': -1.55340219570633,
#   'C gas only Conversion Efficiency to CH4 (%)': 2.511439287905655,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.9355598931369409,
#   'C Conversion to CH4 Efficiency (%)': 0.9697686903098413,
#   'accounted_C': 1.159823079054394,
#   'Unaccounted C (%) based on MT sensors': -0.1598230790543939,
#   'Projected Cell Yield (g/min)': 0.0010971428571428,
#   'R-TSS': 1273.9154929577464,
#   'W-TSS': 95.7887323943662,
#   'R-VSS': 1070.5211267605634,
#   'W-VSS': 13.661971830985916,
#   'SRT': 10.000833423432011,
#   'HRT': 2.1760221214789923,
#   'pH': 7.047,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.037,
#   'ORP (mV)': -502.448,
#   'Temp ©': 35.962,
#   '[H]': 8.97428794500747e-08,
#   '[CO2aq]': 0.0009324683587448,
#   'pKa1': 6.342165896296296,
#   'pKa2': 10.280280818518518,
#   '[HCO3-]': 0.004725722411308,
#   '[CO3-2]': 2.7617692455117003e-06,
#   'TIC': 0.0056609525392983,
#   'carbon_out': 0.0885489295278857},
#  'F34': {'Days of Operation': 104.9,
#   'Media description': 'DSMZ v3: dropped yeast, casitone, and bicarb out of DSMZ 120',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0,
#   'cpd00029_in': 0.0002024908337318,
#   'cpd00141_in': 1.9303810206168135e-05,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 14.891589294117647,
#   'Media Total COD (mg/L) Hach': 0.3703125,
#   'Media Ammonia (mol/L)': 0.0081385789782736,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.3169697317910822,
#   'media_carbon_in': 1.493986877496066e-05,
#   'H2 delivery rate setpoint (mL/min)': 1.0,
#   'CO2 delivery rate setpoint (mL/min)': 0.25,
#   'H2 delivery rate (mol/min)': 4.464285714285714e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002455357142857,
#   'H2 delivery (g COD/min)': 0.0114285714285714,
#   'CO2 delivery rate (mol/min)': 1.1160714285714286e-05,
#   'H2:CO2 ratio': 4.0,
#   'carbon_in': 1.1160714285714286e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 2.6100583060674948e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0592216175,
#   'cpd00029_out': 0.0026612217041287,
#   'cpd00141_out': 0.0026612217041287,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 257.5365491176471,
#   'Waste Effluent Total COD (mg/L) Hach': 4005.714285714285,
#   'Waste Effluent Ammonia (mol/L)': 0.0164008367586611,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0177127689779322,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0431393183098499,
#   'Gas Flow Out (mL/min at STP)': 0.5094471032742331,
#   '%cpd01024': 0.908542,
#   '%cpd11640': 0.0119449999999999,
#   '%cpd00011': 0.079513,
#   'CH4 Production (mol/min)': 2.0663129022454387e-05,
#   'cpd11640_out': 2.7166721645583545e-07,
#   'cpd00011_out': 1.8083780144037543e-06,
#   'Specific CH4 production Rate (m3/m3d) .155': 4.300063804827669,
#   'Specific CH4 production Rate (L/m2d)': 4.59345203134589,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 2.903749350607919e-07,
#   'Effluent C as measured (mol/min)': 2.554780208156684e-06,
#   'Effluent C as biomass (mol/min)': 2.3228034419444445e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 2.276188197191893e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 1.8514163604119127,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.945535466931224,
#   'Accounted H2 (%)': 1.857501706060524,
#   'Unaccounted H2 (%)': -0.8575017060605237,
#   'C gas only Conversion Efficiency to CH4 (%)': 1.8514163604119127,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.9363155283066744,
#   'C Conversion to CH4 Efficiency (%)': 0.7916730815713835,
#   'accounted_C': 0.8720832756496407,
#   'Unaccounted C (%) based on MT sensors': 0.1279167243503592,
#   'Projected Cell Yield (g/min)': 0.0009142857142857,
#   'R-TSS': 1520.111111111111,
#   'W-TSS': 110.88888888888889,
#   'R-VSS': 1310.6666666666667,
#   'W-VSS': 78.44444444444444,
#   'SRT': 25.53418542377168,
#   'HRT': 8.780074074071598,
#   'pH': 6.969,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.037,
#   'ORP (mV)': -496.706,
#   'Temp ©': 36.422,
#   '[H]': 1.073989412341241e-07,
#   '[CO2aq]': 0.0009324683587448,
#   'pKa1': 6.33997834074074,
#   'pKa2': 10.276567596296296,
#   '[HCO3-]': 0.0039687684644184,
#   '[CO3-2]': 1.954736249863008e-06,
#   'TIC': 0.0049031915594131,
#   'carbon_out': 0.06085464206799026},
#  'G12': {'Days of Operation': 125.9,
#   'Media description': 'Speece: put in Speece media + EDTA + cysteine + vitamins as in DSMZ 120',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0186443874628241,
#   'cpd00029_in': 0.000130595076784,
#   'cpd00141_in': 2.931435609734957e-05,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 11.469913666717131,
#   'Media Total COD (mg/L) Hach': 0.010904605263157894,
#   'Media Ammonia (mol/L)': 0.0094128009395184,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0351529120753415,
#   'media_carbon_in': 1.9725506746091253e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.2,
#   'CO2 delivery rate setpoint (mL/min)': 0.3,
#   'H2 delivery rate (mol/min)': 5.357142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002946428571428,
#   'H2 delivery (g COD/min)': 0.0137142857142857,
#   'CO2 delivery rate (mol/min)': 1.3392857142857142e-05,
#   'H2:CO2 ratio': 4.0,
#   'carbon_in': 1.3392857142857142e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.3590112210318056e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0778660049628241,
#   'cpd00029_out': 0.0004144083107497,
#   'cpd00141_out': 0.0004144083107497,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 33.548757333333334,
#   'Waste Effluent Total COD (mg/L) Hach': 130.25,
#   'Waste Effluent Ammonia (mol/L)': 0.0082795067527891,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0018380407435203,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.011107754643862,
#   'Gas Flow Out (mL/min at STP)': 0.2372275854110487,
#   '%cpd01024': 0.953264,
#   '%cpd11640': 0.0394893333333333,
#   '%cpd00011': 0.0070663333333333,
#   'CH4 Production (mol/min)': 1.0095558793717763e-05,
#   'cpd11640_out': 4.1821246411422803e-07,
#   'cpd00011_out': 7.483612474894081e-08,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.1009183512913565,
#   'Specific CH4 production Rate (L/m2d)': 2.2442615055145434,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 2.356924018220355e-07,
#   'Effluent C as measured (mol/min)': 8.237075244309911e-07,
#   'Effluent C as biomass (mol/min)': 3.136280096238724e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.040608732028874e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.7538017232642599,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.3685377293390648,
#   'Accounted H2 (%)': 0.7616083559277255,
#   'Unaccounted H2 (%)': 0.2383916440722745,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.7538017232642599,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.3685377293390648,
#   'C Conversion to CH4 Efficiency (%)': 0.7428605913976846,
#   'accounted_C': 0.7657101839371202,
#   'Unaccounted C (%) based on MT sensors': 0.2342898160628798,
#   'Projected Cell Yield (g/min)': 0.0010971428571428,
#   'R-TSS': 437.1714285714286,
#   'W-TSS': 121.97142857142858,
#   'R-VSS': 333.1142857142857,
#   'W-VSS': 90.64285714285714,
#   'SRT': 20.390606451593428,
#   'HRT': 3.6565664612966624,
#   'pH': 6.983,
#   'CO2 (mg/L, aqueous dissolved CO2)': 24.635,
#   'ORP (mV)': -498.385,
#   'Temp ©': 36.619,
#   '[H]': 1.0399201658290601e-07,
#   '[CO2aq]': 0.0005597718648458,
#   'pKa1': 6.339041496296296,
#   'pKa2': 10.274977368518517,
#   '[HCO3-]': 0.0024658665533882,
#   '[CO3-2]': 1.2589028056407203e-06,
#   'TIC': 0.0030268973210396,
#   'carbon_out': 0.01294661909490673},
#  'H34': {'Days of Operation': 139.9,
#   'Media description': 'Wolfe v1: put in modified wolfe + EDTA ',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.05348347655,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0325273983882204,
#   'cpd00029_in': 0.0006107667118337,
#   'cpd00141_in': 2.1509055243830117e-05,
#   'cpd00211_in': nan,
#   'Media Total VFA (mg COD/L)': 40.85516766666665,
#   'Media Total COD (mg/L) Hach': 0.02075,
#   'Media Ammonia (mol/L)': 0.0189665296535525,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 7.282342954873334e-05,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0208544401231721,
#   'media_carbon_in': 4.467829839324625e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.2,
#   'CO2 delivery rate setpoint (mL/min)': 0.3,
#   'H2 delivery rate (mol/min)': 5.357142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002946428571428,
#   'H2 delivery (g COD/min)': 0.0137142857142857,
#   'CO2 delivery rate (mol/min)': 1.3392857142857142e-05,
#   'H2:CO2 ratio': 4.0,
#   'carbon_in': 1.3392857142857142e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.3839640126789604e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0860108749382204,
#   'cpd00029_out': 0.0002074864498644,
#   'cpd00141_out': 0.0002074864498644,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 15.916565333333333,
#   'Waste Effluent Total COD (mg/L) Hach': 754.0,
#   'Waste Effluent Ammonia (mol/L)': 0.0095176579146044,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0034198543078143,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.02769970605024,
#   'Gas Flow Out (mL/min at STP)': 0.2624302126679306,
#   '%cpd01024': 0.9826696666666668,
#   '%cpd11640': 0.0099173333333333,
#   '%cpd00011': 0.0074129999999999,
#   'CH4 Production (mol/min)': 1.1512598643109726e-05,
#   'cpd11640_out': 1.161878524895279e-07,
#   'cpd00011_out': 8.68479985047933e-08,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.3958089150461124,
#   'Specific CH4 production Rate (L/m2d)': 2.559272100841815,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 0.0,
#   'Effluent C as measured (mol/min)': 2.356916918532116e-06,
#   'Effluent C as biomass (mol/min)': 1.556659513638773e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.159944664161452e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.859607365352193,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.0139668799096424,
#   'Accounted H2 (%)': 0.8617762052653308,
#   'Unaccounted H2 (%)': 0.1382237947346691,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.859607365352193,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 1.0139668799096424,
#   'C Conversion to CH4 Efficiency (%)': 0.8318567923471226,
#   'accounted_C': 0.8381320999208131,
#   'Unaccounted C (%) based on MT sensors': 0.1618679000791869,
#   'Projected Cell Yield (g/min)': 0.0010971428571428,
#   'R-TSS': 296.27142857142854,
#   'W-TSS': 47.785714285714285,
#   'R-VSS': 218.5857142857143,
#   'W-VSS': 36.6,
#   'SRT': 8.426770069292017,
#   'HRT': 3.3103049169855705,
#   'pH': 7.024454545454545,
#   'CO2 (mg/L, aqueous dissolved CO2)': 39.42845454545454,
#   'ORP (mV)': -503.3088181818182,
#   'Temp ©': 36.60109090909091,
#   '[H]': 9.45356209196673e-08,
#   '[CO2aq]': 0.0008959179837181,
#   'pKa1': 6.339126663973064,
#   'pKa2': 10.275121934680133,
#   '[HCO3-]': 0.0043295343756775,
#   '[CO3-2]': 2.424840893770241e-06,
#   'TIC': 0.0052278772002895,
#   'carbon_out': 0.03112191727497283},
#  'I34': {'Days of Operation': 149.1,
#   'Media description': 'Wolfe v2: put in KILLER wolfe + EDTA + switch to HCl in trace elements',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.05348347655,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.043154089358873,
#   'cpd00029_in': 0.0014740080087367,
#   'cpd00141_in': 1.368550704803613e-15,
#   'cpd00211_in': 1e-10,
#   'Media Total VFA (mg COD/L)': 92.85613683615408,
#   'Media Total COD (mg/L) Hach': 0.013993750000000001,
#   'Media Ammonia (mol/L)': 0.0159718144450968,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0006262967750222,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0154561592336605,
#   'media_carbon_in': 3.8477350116983764e-07,
#   'H2 delivery rate setpoint (mL/min)': 0.6,
#   'CO2 delivery rate setpoint (mL/min)': 0.3,
#   'H2 delivery rate (mol/min)': 2.6785714285714284e-05,
#   'H2 delivery rate (e-eq/min)': 0.0001473214285714,
#   'H2 delivery (g COD/min)': 0.0068571428571428,
#   'CO2 delivery rate (mol/min)': 1.3392857142857142e-05,
#   'H2:CO2 ratio': 2.0,
#   'carbon_in': 1.3392857142857142e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.377763064402698e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.096637565908873,
#   'cpd00029_out': 0.0002298403814261,
#   'cpd00141_out': 0.0002298403814261,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 30.77178768656717,
#   'Waste Effluent Total COD (mg/L) Hach': 258.4,
#   'Waste Effluent Ammonia (mol/L)': 0.0160253313214951,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0001485524759034,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0095062148465636,
#   'Gas Flow Out (mL/min at STP)': 0.3518161458338834,
#   '%cpd01024': 0.716158,
#   '%cpd11640': 0.2403746666666667,
#   '%cpd00011': 0.0434676666666666,
#   'CH4 Production (mol/min)': 1.1248033364647425e-05,
#   'cpd11640_out': 3.775343249230854e-06,
#   'cpd00011_out': 6.827065604936889e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.3407520271617246,
#   'Specific CH4 production Rate (L/m2d)': 2.500458747140367,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 9.890849206110345e-08,
#   'Effluent C as measured (mol/min)': 9.186574637787104e-07,
#   'Effluent C as biomass (mol/min)': 5.651072790725968e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.2029648417202216e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 1.6797063157873486,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.9635606447545512,
#   'Accounted H2 (%)': 1.8206524637586337,
#   'Unaccounted H2 (%)': -0.8206524637586339,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.8398531578936743,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.9134610727331482,
#   'C Conversion to CH4 Efficiency (%)': 0.8163982367696717,
#   'accounted_C': 0.8731289673828956,
#   'Unaccounted C (%) based on MT sensors': 0.1268710326171044,
#   'Projected Cell Yield (g/min)': 0.0005485714285714,
#   'R-TSS': 336.4875,
#   'W-TSS': 150.55,
#   'R-VSS': 265.9625,
#   'W-VSS': 121.0625,
#   'SRT': 4.760795879248674,
#   'HRT': 2.9462892566096768,
#   'pH': 6.946,
#   'CO2 (mg/L, aqueous dissolved CO2)': 8.914,
#   'ORP (mV)': -519.811,
#   'Temp ©': 36.75,
#   '[H]': 1.1324003632355569e-07,
#   '[CO2aq]': 0.0002025494785157,
#   'pKa1': 6.338418518518518,
#   'pKa2': 10.273919907407407,
#   '[HCO3-]': 0.0008205642858695,
#   '[CO3-2]': 3.8564943857748963e-07,
#   'TIC': 0.0010234994138239,
#   'carbon_out': 0.009655685979930778},
#  'J12': {'Days of Operation': 161.10000000000002,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': 1.0,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0425248503179126,
#   'cpd00029_in': 0.0010888359304425,
#   'cpd00141_in': 2.691275945440445e-05,
#   'cpd00211_in': 2.7034666666666665,
#   'Media Total VFA (mg COD/L)': 76.48416646133333,
#   'Media Total COD (mg/L) Hach': 0.011772727272727275,
#   'Media Ammonia (mol/L)': 0.0188373458602466,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 3.759805349052167e-06,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0211445557511705,
#   'media_carbon_in': 4.034929853797203e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.2,
#   'CO2 delivery rate setpoint (mL/min)': 0.4,
#   'H2 delivery rate (mol/min)': 5.357142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0002946428571428,
#   'H2 delivery (g COD/min)': 0.0137142857142857,
#   'CO2 delivery rate (mol/min)': 1.785714285714286e-05,
#   'H2:CO2 ratio': 3.0,
#   'carbon_in': 1.785714285714286e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.826063584252258e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.1017464678179126,
#   'cpd00029_out': 0.0001279018574977,
#   'cpd00141_out': 0.0001279018574977,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 23.724204925133336,
#   'Waste Effluent Total COD (mg/L) Hach': 279.8181818181818,
#   'Waste Effluent Ammonia (mol/L)': 0.0174579618854427,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0062538703824876,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0188680397676311,
#   'Gas Flow Out (mL/min at STP)': 0.2931815158539676,
#   '%cpd01024': 0.9120056666666668,
#   '%cpd11640': 0.0519386666666666,
#   '%cpd00011': 0.0360556666666666,
#   'CH4 Production (mol/min)': 1.1936750170568826e-05,
#   'cpd11640_out': 6.797971886056819e-07,
#   'cpd00011_out': 4.719131700204779e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.484076216141084,
#   'Specific CH4 production Rate (L/m2d)': 3.2026186763424698,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 4.793815088777945e-07,
#   'Effluent C as measured (mol/min)': 1.963855914054361e-06,
#   'Effluent C as biomass (mol/min)': 5.889674581266401e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.28880448494671e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.891277346069139,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 1.0162189419013097,
#   'Accounted H2 (%)': 0.9039668935897784,
#   'Unaccounted H2 (%)': 0.0960331064102215,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.6684580095518542,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8930506336533783,
#   'C Conversion to CH4 Efficiency (%)': 0.6536875426195371,
#   'accounted_C': 0.7057829179997878,
#   'Unaccounted C (%) based on MT sensors': 0.2942170820002122,
#   'Projected Cell Yield (g/min)': 0.0010971428571428,
#   'R-TSS': 450.5211267605634,
#   'W-TSS': 131.9718309859155,
#   'R-VSS': 357.9154929577465,
#   'W-VSS': 112.08450704225352,
#   'SRT': 4.775199751338531,
#   'HRT': 2.798349941068876,
#   'pH': 6.949,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.02,
#   'ORP (mV)': -496.168,
#   'Temp ©': 36.159,
#   '[H]': 1.1246049739669261e-07,
#   '[CO2aq]': 0.0009320820741212,
#   'pKa1': 6.341229051851851,
#   'pKa2': 10.27869059074074,
#   '[HCO3-]': 0.0037776794513174,
#   '[CO3-2]': 1.7682127307661156e-06,
#   'TIC': 0.0047115297381694,
#   'carbon_out': 0.025123874006032755},
#  'K12': {'Days of Operation': 181.9,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0441133750335868,
#   'cpd00029_in': 0.0009426088753386,
#   'cpd00141_in': 1.368550704803613e-15,
#   'cpd00211_in': 1e-10,
#   'Media Total VFA (mg COD/L)': 59.3802870763332,
#   'Media Total COD (mg/L) Hach': 0.02003024193548387,
#   'Media Ammonia (mol/L)': 0.0158661186142102,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.019662022753714,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.25,
#   'CO2 delivery rate setpoint (mL/min)': 0.337,
#   'H2 delivery rate (mol/min)': 5.580357142857143e-05,
#   'H2 delivery rate (e-eq/min)': 0.0003069196428571,
#   'H2 delivery (g COD/min)': 0.0142857142857142,
#   'CO2 delivery rate (mol/min)': 1.5044642857142858e-05,
#   'H2:CO2 ratio': 3.70919881305638,
#   'carbon_in': 1.5044642857142858e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.5694073036809608e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.1033349925335868,
#   'cpd00029_out': 0.0001636423441734,
#   'cpd00141_out': 0.0001636423441734,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 31.17146346003636,
#   'Waste Effluent Total COD (mg/L) Hach': 354.17391304347825,
#   'Waste Effluent Ammonia (mol/L)': 0.0172564187665415,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0056302057459299,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0237447564986224,
#   'Gas Flow Out (mL/min at STP)': 0.3035134232953531,
#   '%cpd01024': 0.919604,
#   '%cpd11640': 0.0493403333333333,
#   '%cpd00011': 0.0310553333333333,
#   'CH4 Production (mol/min)': 1.2460364201611604e-05,
#   'cpd11640_out': 6.685470302024027e-07,
#   'cpd00011_out': 4.207906487311738e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.5930419850786057,
#   'Specific CH4 production Rate (L/m2d)': 2.7699621480853467,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 4.963146314853154e-07,
#   'Effluent C as measured (mol/min)': 1.7713779757672348e-06,
#   'Effluent C as biomass (mol/min)': 2.698193617796378e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.3377469481828094e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.8931589059715198,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.8895484152937322,
#   'Accounted H2 (%)': 0.9051392687527468,
#   'Unaccounted H2 (%)': 0.0948607312472532,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.8282259884750739,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8432992028554499,
#   'C Conversion to CH4 Efficiency (%)': 0.79395349903027,
#   'accounted_C': 0.8523899086267762,
#   'Unaccounted C (%) based on MT sensors': 0.1476100913732237,
#   'Projected Cell Yield (g/min)': 0.0011428571428571,
#   'R-TSS': 504.07142857142856,
#   'W-TSS': 120.85714285714286,
#   'R-VSS': 392.1142857142857,
#   'W-VSS': 83.27142857142857,
#   'SRT': 6.623430246671267,
#   'HRT': 2.7553321023338664,
#   'pH': 6.962,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.034,
#   'ORP (mV)': -495.116,
#   'Temp ©': 35.569,
#   '[H]': 1.091440336448754e-07,
#   '[CO2aq]': 0.00093240019087,
#   'pKa1': 6.344034829629629,
#   'pKa2': 10.28345320185185,
#   '[HCO3-]': 0.0038687220086169,
#   '[CO3-2]': 1.8455011589834551e-06,
#   'TIC': 0.004802967700646,
#   'carbon_out': 0.029376733622528066},
#  'L12': {'Days of Operation': 189.1,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0315343519837964,
#   'cpd00029_in': 0.0013075429313459,
#   'cpd00141_in': 1.368550704803613e-15,
#   'cpd00211_in': 1e-10,
#   'Media Total VFA (mg COD/L)': 82.36955608966653,
#   'Media Total COD (mg/L) Hach': 0.0136796875,
#   'Media Ammonia (mol/L)': 0.0160657662947739,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0001455040754442,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0159567115605878,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.331,
#   'CO2 delivery rate setpoint (mL/min)': 0.337,
#   'H2 delivery rate (mol/min)': 5.941964285714285e-05,
#   'H2 delivery rate (e-eq/min)': 0.0003268080357142,
#   'H2 delivery (g COD/min)': 0.0152114285714285,
#   'CO2 delivery rate (mol/min)': 1.5044642857142858e-05,
#   'H2:CO2 ratio': 3.9495548961424327,
#   'carbon_in': 1.5044642857142858e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.5694073036809608e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0907559694837964,
#   'cpd00029_out': 0.0001197148915988,
#   'cpd00141_out': 0.0001197148915988,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 16.7874063609818,
#   'Waste Effluent Total COD (mg/L) Hach': 277.9375,
#   'Waste Effluent Ammonia (mol/L)': 0.0172727498283889,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0020357024977699,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.015809393411102,
#   'Gas Flow Out (mL/min at STP)': 0.3034821401677022,
#   '%cpd01024': 0.948323,
#   '%cpd11640': 0.0350703333333333,
#   '%cpd00011': 0.0166066666666666,
#   'CH4 Production (mol/min)': 1.2848173821886422e-05,
#   'cpd11640_out': 4.751437418033352e-07,
#   'cpd00011_out': 2.2499226522551978e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 2.6737464180565707,
#   'Specific CH4 production Rate (L/m2d)': 2.856172948303022,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 5.050679594515853e-07,
#   'Effluent C as measured (mol/min)': 1.556972022903821e-06,
#   'Effluent C as biomass (mol/min)': 2.996436987822646e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.3578234046563528e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.8649108748617758,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.8995636227920153,
#   'Accounted H2 (%)': 0.8729072834390821,
#   'Unaccounted H2 (%)': 0.1270927165609179,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.8540032451342904,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8533646474214674,
#   'C Conversion to CH4 Efficiency (%)': 0.818664077308148,
#   'accounted_C': 0.8651822898183604,
#   'Unaccounted C (%) based on MT sensors': 0.1348177101816395,
#   'Projected Cell Yield (g/min)': 0.0012169142857142,
#   'R-TSS': 242.12857142857143,
#   'W-TSS': 85.37142857142857,
#   'R-VSS': 174.5857142857143,
#   'W-VSS': 59.25714285714286,
#   'SRT': 6.970616970622907,
#   'HRT': 3.137228590490198,
#   'pH': 7.035,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.036,
#   'ORP (mV)': -499.647,
#   'Temp ©': 36.619,
#   '[H]': 9.225714271547629e-08,
#   '[CO2aq]': 0.0009324456361198,
#   'pKa1': 6.339041496296296,
#   'pKa2': 10.274977368518517,
#   '[HCO3-]': 0.004630011017754,
#   '[CO3-2]': 2.6644320922951247e-06,
#   'TIC': 0.0055651210859662,
#   'carbon_out': 0.017846652880894803},
#  'M12': {'Days of Operation': 209.9,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0239208698046345,
#   'cpd00029_in': 0.0008977688092894,
#   'cpd00141_in': 4.763959674102457e-06,
#   'cpd00211_in': 1e-10,
#   'Media Total VFA (mg COD/L)': 57.08258385971042,
#   'Media Total COD (mg/L) Hach': 0.02334475806451613,
#   'Media Ammonia (mol/L)': 0.016664709336465,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.0012699456271761,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0182592236158519,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.48,
#   'CO2 delivery rate setpoint (mL/min)': 0.379,
#   'H2 delivery rate (mol/min)': 6.607142857142857e-05,
#   'H2 delivery rate (e-eq/min)': 0.0003633928571428,
#   'H2 delivery (g COD/min)': 0.0169142857142857,
#   'CO2 delivery rate (mol/min)': 1.6919642857142856e-05,
#   'H2:CO2 ratio': 3.905013192612137,
#   'carbon_in': 1.6919642857142856e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.7569073036809606e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0831424873046346,
#   'cpd00029_out': 7.421716413549157e-05,
#   'cpd00141_out': 7.421716413549157e-05,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 6.052281995382465,
#   'Waste Effluent Total COD (mg/L) Hach': 503.741935483871,
#   'Waste Effluent Ammonia (mol/L)': 0.0159885915611106,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.002337786954709,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0131021150984919,
#   'Gas Flow Out (mL/min at STP)': 0.3589398847637136,
#   '%cpd01024': 0.946802,
#   '%cpd11640': 0.039671,
#   '%cpd00011': 0.0135266666666666,
#   'CH4 Production (mol/min)': 1.5171651820270254e-05,
#   'cpd11640_out': 6.356921503777358e-07,
#   'cpd00011_out': 2.167526863647545e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 3.1572696846105632,
#   'Specific CH4 production Rate (L/m2d)': 3.3726864308383,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 4.758997462727136e-07,
#   'Effluent C as measured (mol/min)': 8.92590558884854e-07,
#   'Effluent C as biomass (mol/min)': 2.213927806050768e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 1.586430425290772e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.918500002092037,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.8863502467146261,
#   'Accounted H2 (%)': 0.9281212886923486,
#   'Unaccounted H2 (%)': 0.0718787113076514,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.8966886563959201,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8689643008949429,
#   'C Conversion to CH4 Efficiency (%)': 0.8635431014763029,
#   'accounted_C': 0.9029676306581366,
#   'Unaccounted C (%) based on MT sensors': 0.0970323693418634,
#   'Projected Cell Yield (g/min)': 0.0013531428571428,
#   'R-TSS': 998.9142857142856,
#   'W-TSS': 88.87142857142857,
#   'R-VSS': 804.1857142857143,
#   'W-VSS': 66.04285714285714,
#   'SRT': 6.303041815241918,
#   'HRT': 3.424509314702099,
#   'pH': 7.055,
#   'CO2 (mg/L, aqueous dissolved CO2)': 41.031,
#   'ORP (mV)': -505.618,
#   'Temp ©': 35.503,
#   '[H]': 8.81048873008014e-08,
#   '[CO2aq]': 0.0009323320229952,
#   'pKa1': 6.344348696296295,
#   'pKa2': 10.283985968518518,
#   '[HCO3-]': 0.0047887471329929,
#   '[CO3-2]': 2.826415046826668e-06,
#   'TIC': 0.0057239055710351,
#   'carbon_out': 0.015440794643759786},
#  'N12': {'Days of Operation': 238.0,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.033133487381156,
#   'cpd00029_in': 0.0011740099932257,
#   'cpd00141_in': 6.085342822635828e-06,
#   'cpd00211_in': 1e-10,
#   'Media Total VFA (mg COD/L)': 74.63076703431085,
#   'Media Total COD (mg/L) Hach': 0.020584677419354838,
#   'Media Ammonia (mol/L)': 0.0161949500880798,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 7.538334417244818e-05,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0177183538949881,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 1.583,
#   'CO2 delivery rate setpoint (mL/min)': 0.397,
#   'H2 delivery rate (mol/min)': 7.066964285714285e-05,
#   'H2 delivery rate (e-eq/min)': 0.0003886830357142,
#   'H2 delivery (g COD/min)': 0.0180914285714285,
#   'CO2 delivery rate (mol/min)': 1.7723214285714288e-05,
#   'H2:CO2 ratio': 3.9874055415617127,
#   'carbon_in': 1.7723214285714288e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 1.837264446538104e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.092355104881156,
#   'cpd00029_out': 5.069095528455285e-05,
#   'cpd00141_out': 5.069095528455285e-05,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 5.6595407151666,
#   'Waste Effluent Total COD (mg/L) Hach': 552.1290322580645,
#   'Waste Effluent Ammonia (mol/L)': 0.0170435366160556,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0025842101310412,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0147870757084721,
#   'Gas Flow Out (mL/min at STP)': 0.3836650478308722,
#   '%cpd01024': 0.951829,
#   '%cpd11640': 0.0431596666666666,
#   '%cpd00011': 0.005011,
#   'CH4 Production (mol/min)': 1.6302835661241578e-05,
#   'cpd11640_out': 7.392346239299631e-07,
#   'cpd00011_out': 8.582792654823665e-08,
#   'Specific CH4 production Rate (m3/m3d) .155': 3.3926726908968283,
#   'Specific CH4 production Rate (L/m2d)': 3.432837985535122,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 8.989543842095833e-07,
#   'Effluent C as measured (mol/min)': 1.494425406958409e-06,
#   'Effluent C as biomass (mol/min)': 1.1885282003987263e-06,
#   'Total Effluent C (mol/min) based on MT sensors': 1.7287617971999398e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.9227631555573248,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.8906042206771351,
#   'Accounted H2 (%)': 0.9332235823267698,
#   'Unaccounted H2 (%)': 0.0667764176732301,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.9198577300045624,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8827345263641312,
#   'C Conversion to CH4 Efficiency (%)': 0.88734290221315,
#   'accounted_C': 0.940943368526718,
#   'Unaccounted C (%) based on MT sensors': 0.0590566314732818,
#   'Projected Cell Yield (g/min)': 0.0014473142857142,
#   'R-TSS': 443.2463768115942,
#   'W-TSS': 271.3188405797101,
#   'R-VSS': 360.9855072463768,
#   'W-VSS': 230.57971014492756,
#   'SRT': 5.061742489150278,
#   'HRT': 3.082907247938348,
#   'pH': 7.03,
#   'CO2 (mg/L, aqueous dissolved CO2)': 72.335,
#   'ORP (mV)': -500.21,
#   'Temp ©': 36.816,
#   '[H]': 9.332543007969909e-08,
#   '[CO2aq]': 0.0016436410734168,
#   'pKa1': 6.338104651851851,
#   'pKa2': 10.27338714074074,
#   '[HCO3-]': 0.0080854153302783,
#   '[CO3-2]': 4.61652501160252e-06,
#   'TIC': 0.0097336729287067,
#   'carbon_out': 0.017372780264920257},
#  'P12': {'Days of Operation': 283.1,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0269107729929619,
#   'cpd00029_in': 3.3995699000677505e-05,
#   'cpd00141_in': 4.910359929656493e-06,
#   'cpd00211_in': 0.47400000006,
#   'Media Total VFA (mg COD/L)': 3.54653737582292,
#   'Media Total COD (mg/L) Hach': 0.02384375,
#   'Media Ammonia (mol/L)': 0.016347621843805,
#   'Media Dissolved Inorganic Carbon (mol C/L)': 0.001611214800896,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0133810574421345,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 2.775,
#   'CO2 delivery rate setpoint (mL/min)': 0.701,
#   'H2 delivery rate (mol/min)': 0.0001238839285714,
#   'H2 delivery rate (e-eq/min)': 0.0006813616071428,
#   'H2 delivery (g COD/min)': 0.0317142857142857,
#   'CO2 delivery rate (mol/min)': 3.129464285714285e-05,
#   'H2:CO2 ratio': 3.958630527817404,
#   'carbon_in': 3.129464285714285e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.19440730368096e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.0861323904929619,
#   'cpd00029_out': 5.133854793699188e-05,
#   'cpd00141_out': 5.133854793699188e-05,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 4.72724353770332,
#   'Waste Effluent Total COD (mg/L) Hach': 542.6,
#   'Waste Effluent Ammonia (mol/L)': 0.0152201996476805,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': 0.0015923864547966,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0126456598173555,
#   'Gas Flow Out (mL/min at STP)': 0.7240666437730091,
#   '%cpd01024': 0.8886636666666667,
#   '%cpd11640': 0.110011,
#   '%cpd00011': 0.0013253333333333,
#   'CH4 Production (mol/min)': 2.872552315028346e-05,
#   'cpd11640_out': 3.5560399798264515e-06,
#   'cpd00011_out': 4.2840609756569713e-08,
#   'Specific CH4 production Rate (m3/m3d) .155': 5.9778740305518925,
#   'Specific CH4 production Rate (L/m2d)': 6.385737248349713,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 9.7717442711742e-07,
#   'Effluent C as measured (mol/min)': 1.1330289759771471e-06,
#   'Effluent C as biomass (mol/min)': 4.6736415555590186e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 2.974553818715745e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.9274979727082516,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.9063124636889528,
#   'Accounted H2 (%)': 0.9562025837165804,
#   'Unaccounted H2 (%)': 0.0437974162834197,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.9179054473129096,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8973607392644212,
#   'C Conversion to CH4 Efficiency (%)': 0.8992442234020263,
#   'accounted_C': 0.9311755001587072,
#   'Unaccounted C (%) based on MT sensors': 0.0688244998412929,
#   'Projected Cell Yield (g/min)': 0.0025371428571428,
#   'R-TSS': 292.69014084507046,
#   'W-TSS': 135.19718309859155,
#   'R-VSS': 229.05633802816905,
#   'W-VSS': 102.08450704225352,
#   'SRT': 7.2723113784064655,
#   'HRT': 3.305634739645216,
#   'pH': 6.951,
#   'CO2 (mg/L, aqueous dissolved CO2)': 98.011,
#   'ORP (mV)': -495.217,
#   'Temp ©': 36.619,
#   '[H]': 1.1194378834671498e-07,
#   '[CO2aq]': 0.0022270671908018,
#   'pKa1': 6.339041496296296,
#   'pKa2': 10.274977368518517,
#   '[HCO3-]': 0.0091136390392553,
#   '[CO3-2]': 4.3222955038133375e-06,
#   'TIC': 0.011345028525561,
#   'carbon_out': 0.014239179301128077},
#  'Q': {'Days of Operation': 300.0,
#   'Media description': 'Wolfe v3: went back to modified wolfe + EDTA and switched CuSO4 to CUCl2',
#   'Media changes': nan,
#   'Media Influent Flow Rate (mL/min) based on scales linear projection': 0.0592216175,
#   'pH adjustment delivery rate (mL/min) - primarily 1 M HCl, sometimes 1 M NaOH': 0.0465361980916422,
#   'cpd00029_in': 0.000133042570009,
#   'cpd00141_in': 2.294375256603257e-05,
#   'cpd00211_in': 1.9495,
#   'Media Total VFA (mg COD/L)': 14.463519166666666,
#   'Media Total COD (mg/L) Hach': 0.02750201612903226,
#   'Media Ammonia (mol/L)': 0.0168173810921902,
#   'Media Dissolved Inorganic Carbon (mol C/L)': nan,
#   'Media Dissolved Organic Carbon (mol C/L)': 0.0160677639921479,
#   'media_carbon_in': 6.4943017966675e-07,
#   'H2 delivery rate setpoint (mL/min)': 2.77,
#   'CO2 delivery rate setpoint (mL/min)': 0.701,
#   'H2 delivery rate (mol/min)': 0.0001236607142857,
#   'H2 delivery rate (e-eq/min)': 0.0006801339285714,
#   'H2 delivery (g COD/min)': 0.0316571428571428,
#   'CO2 delivery rate (mol/min)': 3.129464285714285e-05,
#   'H2:CO2 ratio': 3.951497860199715,
#   'carbon_in': 3.129464285714285e-05,
#   'Approximate Total Influent C (mol/min) based on Media recipe + gas': 3.19440730368096e-05,
#   'Effluent waste flow rate (mL/min) - measured based on HRT after Day 38.1': 0.1057578155916422,
#   'cpd00029_out': 9.089842237708093e-05,
#   'cpd00141_out': 9.089842237708093e-05,
#   'cpd00211_out': nan,
#   'Waste Effluent Total VFA (mg COD/L)': 12.391540928571429,
#   'Waste Effluent Total COD (mg/L) Hach': 711.0322580645161,
#   'Waste Effluent Ammonia (mol/L)': 0.0155214079544796,
#   'Waste Effluent Dissolved Inorganic Carbon (mol C/L)': nan,
#   'Waste Effluent Dissolved Organic Carbon (mol C/L)': 0.0166594393418601,
#   'Gas Flow Out (mL/min at STP)': 0.6891436170205738,
#   '%cpd01024': 0.9296366666666666,
#   '%cpd11640': 0.0381446666666666,
#   '%cpd00011': 0.0322193333333333,
#   'CH4 Production (mol/min)': 2.860058816882215e-05,
#   'cpd11640_out': 1.1735336409245885e-06,
#   'cpd00011_out': 9.912387460412891e-07,
#   'Specific CH4 production Rate (m3/m3d) .155': 5.9518746578937245,
#   'Specific CH4 production Rate (L/m2d)': 5.7380067550307166,
#   'Waste Effluent Dissolved Inorganic Carbon (mol/min) based on sensor': 1.332043233910707e-06,
#   'Effluent C as measured (mol/min)': 1.765388418614578e-06,
#   'Effluent C as biomass (mol/min)': 9.49336456228752e-07,
#   'Total Effluent C (mol/min) based on MT sensors': 3.092387014877414e-05,
#   'H2 Conversion to CH4 Efficiency (%)': 0.9251309386016118,
#   'H2 conversion to CH4 efficiency (30-day rolling average)': 0.904294122190965,
#   'Accounted H2 (%)': 0.9346208857339984,
#   'Unaccounted H2 (%)': 0.0653791142660016,
#   'C gas only Conversion Efficiency to CH4 (%)': 0.9139132310722058,
#   'CO2 conversion to CH4 efficiency (30-day rolling average)': 0.8913885190864059,
#   'C Conversion to CH4 Efficiency (%)': 0.8953331698141715,
#   'accounted_C': 0.9680628426168488,
#   'Unaccounted C (%) based on MT sensors': 0.031937157383151,
#   'Projected Cell Yield (g/min)': 0.0025325714285714,
#   'R-TSS': 480.9285714285714,
#   'W-TSS': 233.8,
#   'R-VSS': 389.8285714285714,
#   'W-VSS': 179.04285714285714,
#   'SRT': 4.651420618625359,
#   'HRT': 2.692209749505482,
#   'pH': 6.991,
#   'CO2 (mg/L, aqueous dissolved CO2)': 102.531,
#   'ORP (mV)': -498.215,
#   'Temp ©': 34.913,
#   '[H]': 1.0209394837076785e-07,
#   '[CO2aq]': 0.0023297734554295,
#   'pKa1': 6.347154474074074,
#   'pKa2': 10.28874857962963,
#   '[HCO3-]': 0.0102602801414945,
#   '[CO3-2]': 5.16904888077552e-06,
#   'TIC': 0.0125952226458048,
#   'carbon_out': nan}}

# %% [markdown]
# ### loading the media

# %%
# import os
# # os.environ["HOME"] = "~/repos/cobrakbase"
# import cobrakbase

# with open("/home/afreiburger/.kbase/token", 'r') as token:
#     kbase_obj = cobrakbase.KBaseAPI(token.readline())

# media_ws = 207617
# media = kbase_obj.get_from_ws("Wolfe",207617)
# from modelseedpy.core.fbahelper import FBAHelper
# from json import dump
# media_js = FBAHelper.convert_kbase_media(media)

# dump(media_js, open("model_inputs/Wolfe.json", 'w'), indent=2)

from json import load
media = load(open("model_inputs/Wolfe.json", 'r'))

# %% [markdown]
# ###

# %% [markdown]
# ### Adding the media and element constraints

# %%
# %%time
from mscommunity import MSCommunity
from tqdm import tqdm

models = load_models()
for ID, model in tqdm(models.items()):
    sample = ID.split("_")[0]
    models[ID] = MSCommunity(model) #, climit=data_df[sample]["carbon_in"]*1000, o2limit=0)
    display(models[ID].util.model.summary())
    models[ID].util.add_medium = media
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# loading P12_comm
# 100%|██████████| 1/1 [01:38<00:00, 98.19s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Read LP format model from file /tmp/tmp1joddpzd.lp
# Reading time = 0.25 seconds
# : 38032 rows, 82598 columns, 389014 nonzeros
# Neither carbon consumption nor oxygen consumption are defined in P12_comm
# Species0 biomass compound: cpd11416_c22
# skipping atp hydrolysis rxn00062_c22 for Species0
# Making biomass drain reaction for species: Species0
# Species1 biomass compound: cpd11416_c24
# skipping atp hydrolysis rxn00062_c24 for Species1
# Making biomass drain reaction for species: Species1
# Species2 biomass compound: cpd11416_c9
# skipping atp hydrolysis rxn00062_c9 for Species2
# Making biomass drain reaction for species: Species2
# Species3 biomass compound: cpd11416_c28
# skipping atp hydrolysis rxn00062_c28 for Species3
# Making biomass drain reaction for species: Species3
# Species4 biomass compound: cpd11416_c7
# skipping atp hydrolysis rxn00062_c7 for Species4
# Making biomass drain reaction for species: Species4
# Species5 biomass compound: cpd11416_c11
# skipping atp hydrolysis rxn00062_c11 for Species5
# Making biomass drain reaction for species: Species5
# Species6 biomass compound: cpd11416_c12
# skipping atp hydrolysis rxn00062_c12 for Species6
# Making biomass drain reaction for species: Species6
# Species7 biomass compound: cpd11416_c8
# skipping atp hydrolysis rxn00062_c8 for Species7
# Making biomass drain reaction for species: Species7
# Species8 biomass compound: cpd11416_c32
# skipping atp hydrolysis rxn00062_c32 for Species8
# Making biomass drain reaction for species: Species8
# Species9 biomass compound: cpd11416_c31
# skipping atp hydrolysis rxn00062_c31 for Species9
# Making biomass drain reaction for species: Species9
# Species10 biomass compound: cpd11416_c14
# skipping atp hydrolysis rxn00062_c14 for Species10
# Making biomass drain reaction for species: Species10
# Species11 biomass compound: cpd11416_c25
# skipping atp hydrolysis rxn00062_c25 for Species11
# Making biomass drain reaction for species: Species11
# Species12 biomass compound: cpd11416_c18
# skipping atp hydrolysis rxn00062_c18 for Species12
# Making biomass drain reaction for species: Species12
# Species13 biomass compound: cpd11416_c36
# skipping atp hydrolysis rxn00062_c36 for Species13
# Making biomass drain reaction for species: Species13
# Species14 biomass compound: cpd11416_c35
# skipping atp hydrolysis rxn00062_c35 for Species14
# Making biomass drain reaction for species: Species14
# Species15 biomass compound: cpd11416_c33
# skipping atp hydrolysis rxn00062_c33 for Species15
# Making biomass drain reaction for species: Species15
# Species16 biomass compound: cpd11416_c1
# skipping atp hydrolysis rxn00062_c1 for Species16
# Making biomass drain reaction for species: Species16
# Species17 biomass compound: cpd11416_c34
# skipping atp hydrolysis rxn00062_c34 for Species17
# Making biomass drain reaction for species: Species17
# Species18 biomass compound: cpd11416_c2
# skipping atp hydrolysis rxn00062_c2 for Species18
# Making biomass drain reaction for species: Species18
# Species19 biomass compound: cpd11416_c21
# skipping atp hydrolysis rxn00062_c21 for Species19
# Making biomass drain reaction for species: Species19
# Species20 biomass compound: cpd11416_c17
# skipping atp hydrolysis rxn00062_c17 for Species20
# Making biomass drain reaction for species: Species20
# Species21 biomass compound: cpd11416_c30
# skipping atp hydrolysis rxn00062_c30 for Species21
# Making biomass drain reaction for species: Species21
# Species22 biomass compound: cpd11416_c23
# skipping atp hydrolysis rxn00062_c23 for Species22
# Making biomass drain reaction for species: Species22
# Species23 biomass compound: cpd11416_c19
# skipping atp hydrolysis rxn00062_c19 for Species23
# Making biomass drain reaction for species: Species23
# Species24 biomass compound: cpd11416_c13
# skipping atp hydrolysis rxn00062_c13 for Species24
# Making biomass drain reaction for species: Species24
# Species25 biomass compound: cpd11416_c3
# skipping atp hydrolysis rxn00062_c3 for Species25
# Making biomass drain reaction for species: Species25
# Species26 biomass compound: cpd11416_c10
# skipping atp hydrolysis rxn00062_c10 for Species26
# Making biomass drain reaction for species: Species26
# Species27 biomass compound: cpd11416_c15
# skipping atp hydrolysis rxn00062_c15 for Species27
# Making biomass drain reaction for species: Species27
# Species28 biomass compound: cpd11416_c6
# skipping atp hydrolysis rxn00062_c6 for Species28
# Making biomass drain reaction for species: Species28
# Species29 biomass compound: cpd11416_c5
# skipping atp hydrolysis rxn00062_c5 for Species29
# Making biomass drain reaction for species: Species29
# Species30 biomass compound: cpd11416_c29
# skipping atp hydrolysis rxn00062_c29 for Species30
# Making biomass drain reaction for species: Species30
# Species31 biomass compound: cpd11416_c20
# skipping atp hydrolysis rxn00062_c20 for Species31
# Making biomass drain reaction for species: Species31
# Species32 biomass compound: cpd11416_c27
# skipping atp hydrolysis rxn00062_c27 for Species32
# Making biomass drain reaction for species: Species32
# Species33 biomass compound: cpd11416_c4
# skipping atp hydrolysis rxn00062_c4 for Species33
# Making biomass drain reaction for species: Species33
# Species34 biomass compound: cpd11416_c26
# skipping atp hydrolysis rxn00062_c26 for Species34
# Making biomass drain reaction for species: Species34
# Species35 biomass compound: cpd11416_c16
# skipping atp hydrolysis rxn00062_c16 for Species35
# Making biomass drain reaction for species: Species35
# Neither carbon consumption nor oxygen consumption are defined in P12_comm
# <h3>Objective</h3><p>1.0 bio1 = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00009_e0</td>
#       <td>EX_cpd00009_e0</td>
#       <td>1.506</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>13.15</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00027_e0</td>
#       <td>EX_cpd00027_e0</td>
#       <td>10</td>
#       <td>6</td>
#       <td>81.33%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00048_e0</td>
#       <td>EX_cpd00048_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00058_e0</td>
#       <td>EX_cpd00058_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00060_e0</td>
#       <td>EX_cpd00060_e0</td>
#       <td>0.4104</td>
#       <td>5</td>
#       <td>2.78%</td>
#     </tr>
#     <tr>
#       <td>cpd00063_e0</td>
#       <td>EX_cpd00063_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td>129.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00099_e0</td>
#       <td>EX_cpd00099_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00107_e0</td>
#       <td>EX_cpd00107_e0</td>
#       <td>0.6977</td>
#       <td>6</td>
#       <td>5.67%</td>
#     </tr>
#     <tr>
#       <td>cpd00119_e0</td>
#       <td>EX_cpd00119_e0</td>
#       <td>0.1473</td>
#       <td>6</td>
#       <td>1.20%</td>
#     </tr>
#     <tr>
#       <td>cpd00149_e0</td>
#       <td>EX_cpd00149_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00156_e0</td>
#       <td>EX_cpd00156_e0</td>
#       <td>0.6651</td>
#       <td>5</td>
#       <td>4.51%</td>
#     </tr>
#     <tr>
#       <td>cpd00205_e0</td>
#       <td>EX_cpd00205_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00220_e0</td>
#       <td>EX_cpd00220_e0</td>
#       <td>0.01566</td>
#       <td>17</td>
#       <td>0.36%</td>
#     </tr>
#     <tr>
#       <td>cpd00254_e0</td>
#       <td>EX_cpd00254_e0</td>
#       <td>0.00522</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00305_e0</td>
#       <td>EX_cpd00305_e0</td>
#       <td>0.00522</td>
#       <td>12</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td

#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <td>cpd02701_c19</td>
#       <td>SK_cpd02701_c19</td>
#       <td>-0.00522</td>
#       <td>15</td>
#       <td>14.63%</td>
#     </tr>
#     <tr>
#       <td>cpd03091_c19</td>
#       <td>SK_cpd03091_c19</td>
#       <td>-0.01044</td>
#       <td>10</td>
#       <td>19.50%</td>
#     </tr>
#     <tr>
#       <td>cpd11416_c19</td>
#       <td>SK_cpd11416_c19</td>
#       <td>-1.861</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 58 s, sys: 294 ms, total: 58.3 s
# Wall time: 58.2 s

# %%
# %%time
# With Carbon and Oxygen constraints
display(models[ID].util.model.summary())
# Out:
# <h3>Objective</h3><p>1.0 bio1 = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00009_e0</td>
#       <td>EX_cpd00009_e0</td>
#       <td>0.0006401</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>0.005617</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00027_e0</td>
#       <td>EX_cpd00027_e0</td>
#       <td>0.00431</td>
#       <td>6</td>
#       <td>82.63%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00048_e0</td>
#       <td>EX_cpd00048_e0</td>
#       <td>3.327E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00058_e0</td>
#       <td>EX_cpd00058_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00060_e0</td>
#       <td>EX_cpd00060_e0</td>
#       <td>0.0001733</td>
#       <td>5</td>
#       <td>2.77%</td>
#     </tr>
#     <tr>
#       <td>cpd00063_e0</td>
#       <td>EX_cpd00063_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td>0.01276</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00099_e0</td>
#       <td>EX_cpd00099_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00119_e0</td>
#       <td>EX_cpd00119_e0</td>
#       <td>6.26E-05</td>
#       <td>6</td>
#       <td>1.20%</td>
#     </tr>
#     <tr>
#       <td>cpd00149_e0</td>
#       <td>EX_cpd00149_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00156_e0</td>
#       <td>EX_cpd00156_e0</td>
#       <td>0.0005791</td>
#       <td>5</td>
#       <td>9.25%</td>
#     </tr>
#     <tr>
#       <td>cpd00205_e0</td>
#       <td>EX_cpd00205_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00254_e0</td>
#       <td>EX_cpd00254_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00305_e0</td>
#       <td>EX_cpd00305_e0</td>
#       <td>2.218E-06</td>
#       <td>12</td>
#       <td>0.09%</td>
#     </tr>
#     <tr>
#       <td>cpd00322_e0</td>
#       <td>EX_cpd00322_e0</td>
#       <td>0.000191</td>
#       <td>6</td>
#       <td>3.66%</td>
#     </tr>
#     <tr>
#       <td>cpd00393_e0</td>
#       <td>EX_cpd00393_e0</td>
#       <td>6.654E-06</td>
#       <td>19</td>
#       <td>0.40%</td>
#     </tr>
#     <tr>
#       <td>cpd10515_e0</td>
#       <td>EX_cpd10515_e0</td>
#       <td>6.654E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd10516_e0</td>
#       <td>EX_cpd10516_e0</td>
#       <td>2.218E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd11416_c19</td>
#       <td>DM_cpd11416_c19</td>
#       <td>-0.0007909</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00001_e0</td>
#       <td>EX_cpd00001_e0</td>
#       <td>-0.04921</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00007_e0</td>
#       <td>EX_cpd00007_e0</td>
#       <td>-0.001814</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00082_e0</td>
#       <td>EX_cpd00082_e0</td>
#       <td>-2.46E-05</td>
#       <td>6</td>
#       <td>64.89%</td>
#     </tr>
#     <tr>
#       <td>cpd00116_e0</td>
#       <td>EX_cpd00116_e0</td>
#       <td>-2.218E-06</td>
#       <td>1</td>
#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <td>cpd02701_c19</td>
#       <td>SK_cpd02701_c19</td>
#       <td>-2.218E-06</td>
#       <td>15</td>
#       <td>14.63%</td>
#     </tr>
#     <tr>
#       <td>cpd03091_c19</td>
#       <td>SK_cpd03091_c19</td>
#       <td>-4.436E-06</td>
#       <td>10</td>
#       <td>19.50%</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 1min 2s, sys: 217 ms, total: 1min 2s
# Wall time: 1min 2s

# %% [markdown]
# ## Objective

# %%
# %%time
for ID, model in models.items():
    print(ID)
    print(model.util.model.objective.expression)
    print(model.run_fba())
# Out:
# P12_comm
# 1.0*bio1 - 1.0*bio1_reverse_b18f7
# <Solution 0.000 at 0x7fa586236980>
# CPU times: user 3min 16s, sys: 421 ms, total: 3min 16s
# Wall time: 3min 16s
