# %% [markdown]
# # Loading KBase Genome Objects into ModelSEEDpy
#
# This notebook demonstrates how to load genome object JSON files from the `genome_objects` directory and use them with ModelSEEDpy for metabolic modeling.
#
# ## Prerequisites
#
# Make sure you have ModelSEEDpy installed:
# ```bash
# pip install modelseedpy
# ```

# %% [markdown]
# ## Setup
#
# Import the genome loading utilities:

# %%
from load_genomes_to_modelseedpy import (
    list_available_genomes,
    load_genome,
    load_all_genomes,
    get_msgenome,
    build_model,
    export_genome_summary,
    GenomeLoader
)

import pandas as pd
import json
# Out:
# modelseedpy 0.3.3

# %% [markdown]
# ## 1. List Available Genomes
#
# First, let's see what genomes are available in the `genome_objects` directory:

# %%
# List all available genomes
genomes = list_available_genomes()

print(f"Found {len(genomes)} genomes")
print("\nFirst 20 genomes:")
for genome_id in genomes[:20]:
    print(f"  - {genome_id}")

# %% [markdown]
# ## 2. Load a Single Genome
#
# Load and inspect a single genome object:

# %%
# Load a single genome
genome_id = 'Acetobacterium.1'
genome = load_genome(genome_id)

# Display genome information
print(f"Genome ID: {genome['id']}")
print(f"Scientific name: {genome['scientific_name']}")
print(f"Domain: {genome['domain']}")
print(f"Taxonomy: {genome['taxonomy']}")
print(f"\nStatistics:")
print(f"  Features: {len(genome['features'])}")
print(f"  CDSs: {len(genome['cdss'])}")
print(f"  DNA size: {genome['dna_size']:,} bp")
print(f"  GC content: {genome['gc_content']:.2%}")
print(f"  Contigs: {genome['num_contigs']}")

# %% [markdown]
# ### Inspect genome features

# %%
# Look at the first few features
print("First 5 features:")
for feature in genome['features'][:5]:
    print(f"\nFeature ID: {feature['id']}")
    print(f"  Type: {feature['type']}")
    print(f"  Functions: {feature.get('functions', [])}")
    print(f"  DNA length: {feature['dna_sequence_length']} bp")
    if 'protein_translation' in feature:
        print(f"  Protein length: {feature['protein_translation_length']} aa")

# %% [markdown]
# ## 3. Load All Genomes
#
# Load all genome objects at once:

# %%
# Load all genomes (this may take a minute)
all_genomes = load_all_genomes(verbose=True)

# %% [markdown]
# ### Summary statistics

# %%
# Calculate summary statistics
total_features = sum(len(g['features']) for g in all_genomes.values())
total_dna = sum(g['dna_size'] for g in all_genomes.values())
avg_gc = sum(g['gc_content'] for g in all_genomes.values()) / len(all_genomes)

print(f"Summary across {len(all_genomes)} genomes:")
print(f"  Total features: {total_features:,}")
print(f"  Total DNA: {total_dna:,} bp ({total_dna/1e9:.2f} Gbp)")
print(f"  Average GC content: {avg_gc:.2%}")

# %% [markdown]
# ## 4. Create a Genome Summary Table
#
# Export and visualize a summary of all genomes:

# %%
# Export to TSV
export_genome_summary('genome_summary.tsv')

# Load and display as pandas DataFrame
df = pd.read_csv('genome_summary.tsv', sep='\t')
print(f"\nGenome summary table ({len(df)} genomes):")
df
# Out:
# Exporting summary for 459 genomes to genome_summary.tsv
# Loading genome: Acetoanaerobium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2595
#   DNA size: 0 bp
#   GC content: 39.61%
# Loading genome: Acetobacterium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3320
#   DNA size: 0 bp
#   GC content: 42.58%
# Loading genome: Acholeplasma.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 655
#   DNA size: 0 bp
#   GC content: 39.13%
# Loading genome: Achromobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 18009
#   DNA size: 0 bp
#   GC content: 65.53%
# Loading genome: Achromobacter.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5728
#   DNA size: 0 bp
#   GC content: 65.92%
# Loading genome: Acinetobacter.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9845
#   DNA size: 0 bp
#   GC content: 39.54%
# Loading genome: Acinetobacter.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4538
#   DNA size: 0 bp
#   GC content: 41.38%
# Loading genome: Actinomyces.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2345
#   DNA size: 0 bp
#   GC content: 64.03%
# Loading genome: Afipia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11557
#   DNA size: 0 bp
#   GC content: 61.21%
# Loading genome: Alcaligenaceae.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5860
#   DNA size: 0 bp
#   GC content: 61.55%
# Loading genome: Alcaligenaceae.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7060
#   DNA size: 0 bp
#   GC content: 57.79%
# Loading genome: Alcaligenes.14
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8880
#   DNA size: 0 bp
#   GC content: 56.80%
# Loading genome: Alkaliphilus_oremlandii_OhILAs.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4828
#   DNA size: 0 bp
#   GC content: 47.50%
# Loading genome: Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2731
#   DNA size: 0 bp
#   GC content: 62.96%
# Loading genome: Alphaproteobacteria.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4099
#   DNA size: 0 bp
#   GC content: 65.46%
# Loading genome: Amaricoccus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4819
#   DNA size: 0 bp
#   GC content: 70.42%
# Loading genome: Amaricoccus.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5299
#   DNA size: 0 bp
#   GC content: 57.79%
# Loading genome: Aminiphilus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2481
#   DNA size: 0 bp
#   GC content: 58.07%
# Loading genome: Aminivibrio.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4344
#   DNA size: 0 bp
#   GC content: 59.48%
# Loading genome: Anaerocolumna.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3574
#   DNA size: 0 bp
#   GC content: 34.67%
# Loading genome: Anaerosalibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1302
#   DNA size: 0 bp
#   GC content: 30.74%
# Loading genome: Anaerostignum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2368
#   DNA size: 0 bp
#   GC content: 40.46%
# Loading genome: Anaerovoracaceae.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3936
#   DNA size: 0 bp
#   GC content: 58.13%
# Loading genome: Anaerovorax.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5323
#   DNA size: 0 bp
#   GC content: 45.87%
# Loading genome: Anaerovorax.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3948
#   DNA size: 0 bp
#   GC content: 42.77%
# Loading genome: Anaerovorax.15
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4392
#   DNA size: 0 bp
#   GC content: 41.52%
# Loading genome: Anaerovorax.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3164
#   DNA size: 0 bp
#   GC content: 57.86%
# Loading genome: Andreesenia_angusta.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2688
#   DNA size: 0 bp
#   GC content: 43.64%
# Loading genome: Angelakisella.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 949
#   DNA size: 0 bp
#   GC content: 61.27%
# Loading genome: Aquamicrobium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8580
#   DNA size: 0 bp
#   GC content: 64.95%
# Loading genome: Aquamicrobium.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7337
#   DNA size: 0 bp
#   GC content: 62.81%
# Loading genome: Aquamicrobium.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4520
#   DNA size: 0 bp
#   GC content: 62.11%
# Loading genome: Azoarcus.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 18992
#   DNA size: 0 bp
#   GC content: 64.45%
# Loading genome: Bacillaceae.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1497
#   DNA size: 0 bp
#   GC content: 43.76%
# Loading genome: Bacillus.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1646
#   DNA size: 0 bp
#   GC content: 35.67%
# Loading genome: Bacillus.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8233
#   DNA size: 0 bp
#   GC content: 39.34%
# Loading genome: Bacillus.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2111
#   DNA size: 0 bp
#   GC content: 37.70%
# Loading genome: Bacillus.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5365
#   DNA size: 0 bp
#   GC content: 36.90%
# Loading genome: Bacteria.21
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3214
#   DNA size: 0 bp
#   GC content: 42.72%
# Loading genome: Bacteroides.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 335
#   DNA size: 0 bp
#   GC content: 39.57%
# Loading genome: Bauldia.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2210
#   DNA size: 0 bp
#   GC content: 66.69%
# Loading genome: Bosea.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7519
#   DNA size: 0 bp
#   GC content: 66.70%
# Loading genome: Bosea.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11168
#   DNA size: 0 bp
#   GC content: 67.04%
# Loading genome: Brevundimonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7799
#   DNA size: 0 bp
#   GC content: 63.41%
# Loading genome: Brevundimonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12735
#   DNA size: 0 bp
#   GC content: 64.89%
# Loading genome: Brevundimonas.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4390
#   DNA size: 0 bp
#   GC content: 68.20%
# Loading genome: Brooklawnia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 22978
#   DNA size: 0 bp
#   GC content: 65.67%
# Loading genome: Burkholderiales.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 21109
#   DNA size: 0 bp
#   GC content: 67.05%
# Loading genome: Ca_Brevefilum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1598
#   DNA size: 0 bp
#   GC content: 50.96%
# Loading genome: Ca_Caldatribacterium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2783
#   DNA size: 0 bp
#   GC content: 47.74%
# Loading genome: Ca_Cloacimonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1855
#   DNA size: 0 bp
#   GC content: 37.87%
# Loading genome: Ca_Cloacimonas.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1935
#   DNA size: 0 bp
#   GC content: 53.70%
# Loading genome: Ca_Phosphitivorax.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1198
#   DNA size: 0 bp
#   GC content: 57.97%
# Loading genome: Ca_Soleaferrea.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1332
#   DNA size: 0 bp
#   GC content: 50.69%
# Loading genome: Camelimonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4687
#   DNA size: 0 bp
#   GC content: 66.81%
# Loading genome: Caproiciproducens.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5312
#   DNA size: 0 bp
#   GC content: 51.87%
# Loading genome: Caproiciproducens.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4262
#   DNA size: 0 bp
#   GC content: 48.51%
# Loading genome: Caulobacteraceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3899
#   DNA size: 0 bp
#   GC content: 68.67%
# Loading genome: Christensenellaceae.17
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1446
#   DNA size: 0 bp
#   GC content: 48.86%
# Loading genome: Christensenellaceae_R-7_group.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4538
#   DNA size: 0 bp
#   GC content: 49.63%
# Loading genome: Christensenellaceae_R-7_group.15
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1017
#   DNA size: 0 bp
#   GC content: 64.70%
# Loading genome: Christensenellaceae_R-7_group.18
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1017
#   DNA size: 0 bp
#   GC content: 64.70%
# Loading genome: Christensenellaceae_R-7_group.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 936
#   DNA size: 0 bp
#   GC content: 59.27%
# Loading genome: Christensenellaceae_R-7_group.20
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4392
#   DNA size: 0 bp
#   GC content: 58.04%
# Loading genome: Christensenellaceae_R-7_group.29
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1691
#   DNA size: 0 bp
#   GC content: 56.36%
# Loading genome: Christensenellaceae_R-7_group.34
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3331
#   DNA size: 0 bp
#   GC content: 55.09%
# Loading genome: Christensenellaceae_R-7_group.37
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5121
#   DNA size: 0 bp
#   GC content: 56.51%
# Loading genome: Christensenellaceae_R-7_group.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1210
#   DNA size: 0 bp
#   GC content: 51.07%
# Loading genome: Christensenellaceae_R-7_group.48
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 877
#   DNA size: 0 bp
#   GC content: 60.84%
# Loading genome: Christensenellaceae_R-7_group.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1143
#   DNA size: 0 bp
#   GC content: 64.30%
# Loading genome: Christensenellaceae_R-7_group.54
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4252
#   DNA size: 0 bp
#   GC content: 52.90%
# Loading genome: Christensenellaceae_R-7_group.59
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4043
#   DNA size: 0 bp
#   GC content: 52.72%
# Loading genome: Christensenellaceae_R-7_group.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4399
#   DNA size: 0 bp
#   GC content: 53.22%
# Loading genome: Christensenellaceae_R-7_group.62
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2348
#   DNA size: 0 bp
#   GC content: 62.08%
# Loading genome: Christensenellaceae_R-7_group.64
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1295
#   DNA size: 0 bp
#   GC content: 54.83%
# Loading genome: Christensenellaceae_R-7_group.65
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2717
#   DNA size: 0 bp
#   GC content: 56.18%
# Loading genome: Christensenellaceae_R-7_group.79
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2150
#   DNA size: 0 bp
#   GC content: 48.75%
# Loading genome: Christensenellaceae_R-7_group.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4223
#   DNA size: 0 bp
#   GC content: 55.64%
# Loading genome: Clostridia.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 19605
#   DNA size: 0 bp
#   GC content: 41.32%
# Loading genome: Clostridia.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 844
#   DNA size: 0 bp
#   GC content: 53.75%
# Loading genome: Clostridia.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3207
#   DNA size: 0 bp
#   GC content: 36.20%
# Loading genome: Clostridiaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9020
#   DNA size: 0 bp
#   GC content: 39.64%
# Loading genome: Clostridiaceae.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3859
#   DNA size: 0 bp
#   GC content: 30.38%
# Loading genome: Clostridiaceae.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4212
#   DNA size: 0 bp
#   GC content: 32.71%
# Loading genome: Clostridiaceae.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4006
#   DNA size: 0 bp
#   GC content: 32.14%
# Loading genome: Clostridium_sensu_stricto_1.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8068
#   DNA size: 0 bp
#   GC content: 28.31%
# Loading genome: Clostridium_sensu_stricto_1.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5466
#   DNA size: 0 bp
#   GC content: 37.16%
# Loading genome: Clostridium_sensu_stricto_1.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3597
#   DNA size: 0 bp
#   GC content: 37.13%
# Loading genome: Clostridium_sensu_stricto_1.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4795
#   DNA size: 0 bp
#   GC content: 26.97%
# Loading genome: Clostridium_sensu_stricto_11.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3455
#   DNA size: 0 bp
#   GC content: 26.91%
# Loading genome: Clostridium_sensu_stricto_13.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2339
#   DNA size: 0 bp
#   GC content: 30.29%
# Loading genome: Clostridium_sensu_stricto_13.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1814
#   DNA size: 0 bp
#   GC content: 31.31%
# Loading genome: Clostridium_sensu_stricto_5.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4193
#   DNA size: 0 bp
#   GC content: 31.98%
# Loading genome: Clostridium_sensu_stricto_7.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4773
#   DNA size: 0 bp
#   GC content: 31.18%
# Loading genome: Clostridium_sensu_stricto_7.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6964
#   DNA size: 0 bp
#   GC content: 30.74%
# Loading genome: Colidextribacter.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1669
#   DNA size: 0 bp
#   GC content: 55.69%
# Loading genome: Colidextribacter.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2938
#   DNA size: 0 bp
#   GC content: 57.33%
# Loading genome: Comamonadaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 17638
#   DNA size: 0 bp
#   GC content: 64.39%
# Loading genome: Comamonadaceae.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7801
#   DNA size: 0 bp
#   GC content: 61.83%
# Loading genome: Comamonadaceae.14
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4693
#   DNA size: 0 bp
#   GC content: 64.79%
# Loading genome: Comamonadaceae.17
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11065
#   DNA size: 0 bp
#   GC content: 61.71%
# Loading genome: Comamonadaceae.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4303
#   DNA size: 0 bp
#   GC content: 68.41%
# Loading genome: Comamonadaceae.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5824
#   DNA size: 0 bp
#   GC content: 66.51%
# Loading genome: Comamonas.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3187
#   DNA size: 0 bp
#   GC content: 56.80%
# Loading genome: Cryptanaerobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3105
#   DNA size: 0 bp
#   GC content: 49.17%
# Loading genome: DMER64.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2229
#   DNA size: 0 bp
#   GC content: 48.54%
# Loading genome: Dechlorobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1913
#   DNA size: 0 bp
#   GC content: 60.30%
# Loading genome: Dehalobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4818
#   DNA size: 0 bp
#   GC content: 44.03%
# Loading genome: Dehalobacterium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2037
#   DNA size: 0 bp
#   GC content: 45.41%
# Loading genome: Dehalobacterium.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7125
#   DNA size: 0 bp
#   GC content: 45.11%
# Loading genome: Desulfitibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12689
#   DNA size: 0 bp
#   GC content: 46.79%
# Loading genome: Desulfitibacter.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1270
#   DNA size: 0 bp
#   GC content: 51.64%
# Loading genome: Desulfitibacter.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3200
#   DNA size: 0 bp
#   GC content: 40.57%
# Loading genome: Desulfobulbus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4483
#   DNA size: 0 bp
#   GC content: 53.01%
# Loading genome: Desulfococcaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3071
#   DNA size: 0 bp
#   GC content: 51.14%
# Loading genome: Desulfomicrobium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3555
#   DNA size: 0 bp
#   GC content: 58.54%
# Loading genome: Desulfosporosinus.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7290
#   DNA size: 0 bp
#   GC content: 52.69%
# Loading genome: Desulfosporosinus.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3635
#   DNA size: 0 bp
#   GC content: 43.78%
# Loading genome: Desulfosporosinus.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12666
#   DNA size: 0 bp
#   GC content: 51.72%
# Loading genome: Desulfovibrio.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5059
#   DNA size: 0 bp
#   GC content: 66.66%
# Loading genome: Desulfovibrio.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8662
#   DNA size: 0 bp
#   GC content: 60.53%
# Loading genome: Desulfovibrio.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5347
#   DNA size: 0 bp
#   GC content: 57.49%
# Loading genome: Desulfovibrio.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4941
#   DNA size: 0 bp
#   GC content: 68.86%
# Loading genome: Desulfovibrionaceae.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7558
#   DNA size: 0 bp
#   GC content: 56.89%
# Loading genome: Desulfurispora.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8190
#   DNA size: 0 bp
#   GC content: 48.35%
# Loading genome: Desulfuromonadaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1588
#   DNA size: 0 bp
#   GC content: 60.34%
# Loading genome: Dethiobacter.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4478
#   DNA size: 0 bp
#   GC content: 48.97%
# Loading genome: Dethiobacter.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1738
#   DNA size: 0 bp
#   GC content: 53.07%
# Loading genome: Dethiobacteraceae.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6641
#   DNA size: 0 bp
#   GC content: 53.40%
# Loading genome: Dethiobacteraceae.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5204
#   DNA size: 0 bp
#   GC content: 47.33%
# Loading genome: Devosia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6062
#   DNA size: 0 bp
#   GC content: 63.09%
# Loading genome: Devosia.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6025
#   DNA size: 0 bp
#   GC content: 62.05%
# Loading genome: Dysgonomonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2234
#   DNA size: 0 bp
#   GC content: 37.52%
# Loading genome: EBM-39.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6163
#   DNA size: 0 bp
#   GC content: 53.04%
# Loading genome: Enterobacteriaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 15787
#   DNA size: 0 bp
#   GC content: 51.80%
# Loading genome: Enterococcus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8799
#   DNA size: 0 bp
#   GC content: 36.56%
# Loading genome: Enterococcus.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11873
#   DNA size: 0 bp
#   GC content: 39.06%
# Loading genome: Ercella.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1312
#   DNA size: 0 bp
#   GC content: 54.84%
# Loading genome: Ercella.13
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2744
#   DNA size: 0 bp
#   GC content: 51.22%
# Loading genome: Ercella.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3422
#   DNA size: 0 bp
#   GC content: 53.63%
# Loading genome: Ercella.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2809
#   DNA size: 0 bp
#   GC content: 45.54%
# Loading genome: Erysipelothrix.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3455
#   DNA size: 0 bp
#   GC content: 45.60%
# Loading genome: Erysipelothrix.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2738
#   DNA size: 0 bp
#   GC content: 55.75%
# Loading genome: Erysipelothrix.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10081
#   DNA size: 0 bp
#   GC content: 39.36%
# Loading genome: Fastidiosipila.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7949
#   DNA size: 0 bp
#   GC content: 48.79%
# Loading genome: Fastidiosipila.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2017
#   DNA size: 0 bp
#   GC content: 51.93%
# Loading genome: Fermentimonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3758
#   DNA size: 0 bp
#   GC content: 39.31%
# Loading genome: Fermentimonas.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13166
#   DNA size: 0 bp
#   GC content: 47.08%
# Loading genome: Firmicutes.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8000
#   DNA size: 0 bp
#   GC content: 45.93%
# Loading genome: Firmicutes.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 18885
#   DNA size: 0 bp
#   GC content: 48.41%
# Loading genome: Firmicutes.19
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3851
#   DNA size: 0 bp
#   GC content: 49.85%
# Loading genome: Firmicutes.23
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2635
#   DNA size: 0 bp
#   GC content: 33.38%
# Loading genome: Flavobacterium.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2099
#   DNA size: 0 bp
#   GC content: 33.84%
# Loading genome: Fonticella.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1225
#   DNA size: 0 bp
#   GC content: 27.23%
# Loading genome: Galbitalea.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3444
#   DNA size: 0 bp
#   GC content: 67.08%
# Loading genome: Geobacteraceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3772
#   DNA size: 0 bp
#   GC content: 58.38%
# Loading genome: Gordonia.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5980
#   DNA size: 0 bp
#   GC content: 67.48%
# Loading genome: Gordonia.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4636
#   DNA size: 0 bp
#   GC content: 69.24%
# Loading genome: Haloplasmataceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2695
#   DNA size: 0 bp
#   GC content: 29.11%
# Loading genome: Hungateiclostridiaceae.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4653
#   DNA size: 0 bp
#   GC content: 51.50%
# Loading genome: Hungateiclostridiaceae.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1801
#   DNA size: 0 bp
#   GC content: 52.92%
# Loading genome: Hungateiclostridiaceae.12
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3197
#   DNA size: 0 bp
#   GC content: 50.69%
# Loading genome: Hungateiclostridiaceae.24
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3668
#   DNA size: 0 bp
#   GC content: 31.70%
# Loading genome: Hungateiclostridiaceae.29
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11357
#   DNA size: 0 bp
#   GC content: 39.48%
# Loading genome: Hungateiclostridiaceae.38
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 14368
#   DNA size: 0 bp
#   GC content: 39.36%
# Loading genome: Hungateiclostridiaceae.40
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8550
#   DNA size: 0 bp
#   GC content: 38.97%
# Loading genome: Hydrogenedensaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7147
#   DNA size: 0 bp
#   GC content: 59.77%
# Loading genome: Hydrogenophaga.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3992
#   DNA size: 0 bp
#   GC content: 67.43%
# Loading genome: Hydrogenophaga.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5039
#   DNA size: 0 bp
#   GC content: 69.19%
# Loading genome: Hydrogenophaga.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9327
#   DNA size: 0 bp
#   GC content: 49.31%
# Loading genome: Hyphomicrobium.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11548
#   DNA size: 0 bp
#   GC content: 60.65%
# Loading genome: Hyphomicrobium.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2328
#   DNA size: 0 bp
#   GC content: 64.26%
# Loading genome: Hyphomicrobium.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3567
#   DNA size: 0 bp
#   GC content: 60.96%
# Loading genome: Hyphomonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4334
#   DNA size: 0 bp
#   GC content: 62.20%
# Loading genome: IMCC26207.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4252
#   DNA size: 0 bp
#   GC content: 62.70%
# Loading genome: Intestinibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3881
#   DNA size: 0 bp
#   GC content: 28.84%
# Loading genome: Intestinimonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2967
#   DNA size: 0 bp
#   GC content: 58.39%
# Loading genome: Intestinimonas.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5960
#   DNA size: 0 bp
#   GC content: 58.37%
# Loading genome: JGI-0000079-D21.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2740
#   DNA size: 0 bp
#   GC content: 52.66%
# Loading genome: LNR_A2-18.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2788
#   DNA size: 0 bp
#   GC content: 48.18%
# Loading genome: Lachnoclostridium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9956
#   DNA size: 0 bp
#   GC content: 46.03%
# Loading genome: Lachnoclostridium.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1964
#   DNA size: 0 bp
#   GC content: 44.93%
# Loading genome: Lachnoclostridium.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8242
#   DNA size: 0 bp
#   GC content: 49.40%
# Loading genome: Lachnospiraceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1928
#   DNA size: 0 bp
#   GC content: 41.19%
# Loading genome: Lachnospiraceae.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1530
#   DNA size: 0 bp
#   GC content: 38.45%
# Loading genome: Lachnospiraceae.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3813
#   DNA size: 0 bp
#   GC content: 47.85%
# Loading genome: Lachnospiraceae.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1993
#   DNA size: 0 bp
#   GC content: 44.56%
# Loading genome: Lentimicrobium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3156
#   DNA size: 0 bp
#   GC content: 45.56%
# Loading genome: Lentimicrobium.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3164
#   DNA size: 0 bp
#   GC content: 57.86%
# Loading genome: Leptolinea.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 816
#   DNA size: 0 bp
#   GC content: 52.44%
# Loading genome: Leucobacter.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4546
#   DNA size: 0 bp
#   GC content: 64.26%
# Loading genome: Leucobacter.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3144
#   DNA size: 0 bp
#   GC content: 68.24%
# Loading genome: Limnobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3042
#   DNA size: 0 bp
#   GC content: 68.87%
# Loading genome: Lysinibacillus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8746
#   DNA size: 0 bp
#   GC content: 37.43%
# Loading genome: Marinilabiliaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7040
#   DNA size: 0 bp
#   GC content: 43.63%
# Loading genome: Mesotoga.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6510
#   DNA size: 0 bp
#   GC content: 53.50%
# Loading genome: Methanobacteriaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2459
#   DNA size: 0 bp
#   GC content: 25.62%
# Loading genome: Methanobacterium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5131
#   DNA size: 0 bp
#   GC content: 40.29%
# Loading genome: Methanobacterium.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6385
#   DNA size: 0 bp
#   GC content: 44.27%
# Loading genome: Methanobacterium.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2906
#   DNA size: 0 bp
#   GC content: 40.79%
# Loading genome: Methanobacterium.47
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3069
#   DNA size: 0 bp
#   GC content: 38.32%
# Loading genome: Methanobacterium.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1055
#   DNA size: 0 bp
#   GC content: 33.20%
# Loading genome: Methanobacterium.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2846
#   DNA size: 0 bp
#   GC content: 35.57%
# Loading genome: Methanobacterium.90
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 928
#   DNA size: 0 bp
#   GC content: 37.29%
# Loading genome: Methanobacterium.92
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2322
#   DNA size: 0 bp
#   GC content: 39.27%
# Loading genome: Methanobacterium.99
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2227
#   DNA size: 0 bp
#   GC content: 35.95%
# Loading genome: Methanolinea.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1078
#   DNA size: 0 bp
#   GC content: 53.40%
# Loading genome: Methanomethylophilaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1527
#   DNA size: 0 bp
#   GC content: 46.90%
# Loading genome: Methanosarcina.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5232
#   DNA size: 0 bp
#   GC content: 40.16%
# Loading genome: Methanothermobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3773
#   DNA size: 0 bp
#   GC content: 48.77%
# Loading genome: Methanothrix.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1266
#   DNA size: 0 bp
#   GC content: 55.35%
# Loading genome: Microbacterium.10
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2934
#   DNA size: 0 bp
#   GC content: 70.26%
# Loading genome: Microbacterium.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8205
#   DNA size: 0 bp
#   GC content: 69.98%
# Loading genome: Microvirga.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5642
#   DNA size: 0 bp
#   GC content: 69.51%
# Loading genome: Monoglobus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13792
#   DNA size: 0 bp
#   GC content: 41.37%
# Loading genome: Monoglobus.13
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13670
#   DNA size: 0 bp
#   GC content: 41.53%
# Loading genome: Monoglobus.14
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 16466
#   DNA size: 0 bp
#   GC content: 41.00%
# Loading genome: Mycobacterium.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10458
#   DNA size: 0 bp
#   GC content: 59.95%
# Loading genome: Mycobacterium.13
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13439
#   DNA size: 0 bp
#   GC content: 65.71%
# Loading genome: Mycobacterium.14
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2986
#   DNA size: 0 bp
#   GC content: 67.55%
# Loading genome: Mycobacterium.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8554
#   DNA size: 0 bp
#   GC content: 67.10%
# Loading genome: Mycobacterium.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10299
#   DNA size: 0 bp
#   GC content: 62.22%
# Loading genome: Mycobacterium.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1744
#   DNA size: 0 bp
#   GC content: 66.63%
# Loading genome: NK4A214_group.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3789
#   DNA size: 0 bp
#   GC content: 52.13%
# Loading genome: OPB41.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2145
#   DNA size: 0 bp
#   GC content: 66.28%
# Loading genome: Ochrobactrum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8980
#   DNA size: 0 bp
#   GC content: 56.42%
# Loading genome: Oscillibacter.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3314
#   DNA size: 0 bp
#   GC content: 58.70%
# Loading genome: Oscillibacter.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5524
#   DNA size: 0 bp
#   GC content: 55.31%
# Loading genome: Oscillibacter.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1438
#   DNA size: 0 bp
#   GC content: 54.84%
# Loading genome: Oscillospiraceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6421
#   DNA size: 0 bp
#   GC content: 55.66%
# Loading genome: Oscillospiraceae.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4677
#   DNA size: 0 bp
#   GC content: 59.22%
# Loading genome: Oscillospiraceae.15
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3312
#   DNA size: 0 bp
#   GC content: 60.43%
# Loading genome: Oscillospiraceae.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1301
#   DNA size: 0 bp
#   GC content: 60.80%
# Loading genome: Oscillospirales.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11116
#   DNA size: 0 bp
#   GC content: 50.64%
# Loading genome: Oxobacteraceae.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10970
#   DNA size: 0 bp
#   GC content: 38.87%
# Loading genome: Paludibacter.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5566
#   DNA size: 0 bp
#   GC content: 40.49%
# Loading genome: Pannonibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5356
#   DNA size: 0 bp
#   GC content: 63.09%
# Loading genome: Papillibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7550
#   DNA size: 0 bp
#   GC content: 56.75%
# Loading genome: Paraclostridium.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4141
#   DNA size: 0 bp
#   GC content: 51.20%
# Loading genome: Paraclostridium.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7392
#   DNA size: 0 bp
#   GC content: 32.48%
# Loading genome: Paraclostridium.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6811
#   DNA size: 0 bp
#   GC content: 40.07%
# Loading genome: Paracoccus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3897
#   DNA size: 0 bp
#   GC content: 68.93%
# Loading genome: Paracoccus.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10184
#   DNA size: 0 bp
#   GC content: 65.79%
# Loading genome: Parapusillimonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11850
#   DNA size: 0 bp
#   GC content: 57.00%
# Loading genome: Parvibaculum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4442
#   DNA size: 0 bp
#   GC content: 61.85%
# Loading genome: Pelotomaculum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3584
#   DNA size: 0 bp
#   GC content: 48.20%
# Loading genome: Peptoclostridium.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2471
#   DNA size: 0 bp
#   GC content: 30.25%
# Loading genome: Peptostreptococcales-Tissierellales.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13684
#   DNA size: 0 bp
#   GC content: 34.65%
# Loading genome: Peptostreptococcales-Tissierellales.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4135
#   DNA size: 0 bp
#   GC content: 69.85%
# Loading genome: Petrimonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3044
#   DNA size: 0 bp
#   GC content: 46.07%
# Loading genome: Petrimonas.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2050
#   DNA size: 0 bp
#   GC content: 40.96%
# Loading genome: Phenylobacterium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1952
#   DNA size: 0 bp
#   GC content: 68.62%
# Loading genome: Pir4_lineage.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3053
#   DNA size: 0 bp
#   GC content: 62.05%
# Loading genome: Propionibacteriaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3209
#   DNA size: 0 bp
#   GC content: 70.95%
# Loading genome: Propionicicella.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 18203
#   DNA size: 0 bp
#   GC content: 70.07%
# Loading genome: Proteiniborus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3186
#   DNA size: 0 bp
#   GC content: 32.62%
# Loading genome: Proteiniborus.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6559
#   DNA size: 0 bp
#   GC content: 32.39%
# Loading genome: Proteiniclasticum.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4704
#   DNA size: 0 bp
#   GC content: 43.56%
# Loading genome: Proteiniphilum.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6549
#   DNA size: 0 bp
#   GC content: 43.99%
# Loading genome: Proteiniphilum.13
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2927
#   DNA size: 0 bp
#   GC content: 45.33%
# Loading genome: Proteiniphilum.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2747
#   DNA size: 0 bp
#   GC content: 50.11%
# Loading genome: Proteiniphilum.22
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2439
#   DNA size: 0 bp
#   GC content: 37.43%
# Loading genome: Proteiniphilum.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3098
#   DNA size: 0 bp
#   GC content: 43.63%
# Loading genome: Proteiniphilum.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3455
#   DNA size: 0 bp
#   GC content: 49.60%
# Loading genome: Pseudaminobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5898
#   DNA size: 0 bp
#   GC content: 63.17%
# Loading genome: Pseudarcobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4813
#   DNA size: 0 bp
#   GC content: 26.75%
# Loading genome: Pseudochelatococcus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3661
#   DNA size: 0 bp
#   GC content: 61.33%
# Loading genome: Pseudomonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7379
#   DNA size: 0 bp
#   GC content: 60.62%
# Loading genome: Pseudomonas.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10138
#   DNA size: 0 bp
#   GC content: 62.02%
# Loading genome: Pseudomonas.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4493
#   DNA size: 0 bp
#   GC content: 49.04%
# Loading genome: Pseudomonas.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4510
#   DNA size: 0 bp
#   GC content: 60.05%
# Loading genome: Pusillimonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1779
#   DNA size: 0 bp
#   GC content: 62.86%
# Loading genome: RBG-16-49-21.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 807
#   DNA size: 0 bp
#   GC content: 35.86%
# Loading genome: Ralstonia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7823
#   DNA size: 0 bp
#   GC content: 65.58%
# Loading genome: Rheinheimera.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4308
#   DNA size: 0 bp
#   GC content: 51.38%
# Loading genome: Rhizobiaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2162
#   DNA size: 0 bp
#   GC content: 69.02%
# Loading genome: Rhodanobacter.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9980
#   DNA size: 0 bp
#   GC content: 61.92%
# Loading genome: Rhodanobacter.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10672
#   DNA size: 0 bp
#   GC content: 66.46%
# Loading genome: Rhodobacter.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12298
#   DNA size: 0 bp
#   GC content: 58.13%
# Loading genome: Rhodobacteraceae.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4782
#   DNA size: 0 bp
#   GC content: 59.36%
# Loading genome: Rhodococcus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7025
#   DNA size: 0 bp
#   GC content: 69.91%
# Loading genome: Rhodococcus.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11108
#   DNA size: 0 bp
#   GC content: 60.43%
# Loading genome: Rhodocyclaceae.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5105
#   DNA size: 0 bp
#   GC content: 50.34%
# Loading genome: Romboutsia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7056
#   DNA size: 0 bp
#   GC content: 33.99%
# Loading genome: Romboutsia.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5241
#   DNA size: 0 bp
#   GC content: 29.79%
# Loading genome: Ruminiclostridium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8227
#   DNA size: 0 bp
#   GC content: 45.30%
# Loading genome: Ruminococcaceae.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8602
#   DNA size: 0 bp
#   GC content: 50.89%
# Loading genome: Ruminococcaceae.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1182
#   DNA size: 0 bp
#   GC content: 59.88%
# Loading genome: Ruminococcaceae.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8137
#   DNA size: 0 bp
#   GC content: 53.49%
# Loading genome: Ruminococcaceae.9
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3069
#   DNA size: 0 bp
#   GC content: 42.67%
# Loading genome: Rummeliibacillus.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4543
#   DNA size: 0 bp
#   GC content: 35.67%
# Loading genome: Sedimentibacter.18
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3077
#   DNA size: 0 bp
#   GC content: 30.08%
# Loading genome: Sedimentibacter.19
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8515
#   DNA size: 0 bp
#   GC content: 40.96%
# Loading genome: Sedimentibacter.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7280
#   DNA size: 0 bp
#   GC content: 48.85%
# Loading genome: Sedimentibacter.8
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3534
#   DNA size: 0 bp
#   GC content: 30.88%
# Loading genome: Shinella.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3786
#   DNA size: 0 bp
#   GC content: 46.77%
# Loading genome: Smithella.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1262
#   DNA size: 0 bp
#   GC content: 54.08%
# Loading genome: Soehngenia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4718
#   DNA size: 0 bp
#   GC content: 34.25%
# Loading genome: Soehngenia.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4259
#   DNA size: 0 bp
#   GC content: 37.35%
# Loading genome: Soehngenia.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1236
#   DNA size: 0 bp
#   GC content: 42.41%
# Loading genome: Sphaerochaeta.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2111
#   DNA size: 0 bp
#   GC content: 52.91%
# Loading genome: Sphaerochaeta.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3600
#   DNA size: 0 bp
#   GC content: 54.00%
# Loading genome: Sphaerochaeta.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6615
#   DNA size: 0 bp
#   GC content: 51.73%
# Loading genome: Sphingopyxis.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6776
#   DNA size: 0 bp
#   GC content: 64.60%
# Loading genome: Sphingopyxis.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4112
#   DNA size: 0 bp
#   GC content: 66.43%
# Loading genome: Sphingosinicella.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3812
#   DNA size: 0 bp
#   GC content: 64.69%
# Loading genome: Sporanaerobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3094
#   DNA size: 0 bp
#   GC content: 31.26%
# Loading genome: Sporomusaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11310
#   DNA size: 0 bp
#   GC content: 53.57%
# Loading genome: Stappia.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11847
#   DNA size: 0 bp
#   GC content: 63.90%
# Loading genome: Stenotrophomonas.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7971
#   DNA size: 0 bp
#   GC content: 70.07%
# Loading genome: Stenotrophomonas.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7404
#   DNA size: 0 bp
#   GC content: 68.52%
# Loading genome: Stenotrophomonas.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11018
#   DNA size: 0 bp
#   GC content: 65.89%
# Loading genome: Sulfurospirillum.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9103
#   DNA size: 0 bp
#   GC content: 43.78%
# Loading genome: Syner-01.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2231
#   DNA size: 0 bp
#   GC content: 62.63%
# Loading genome: Syner-01.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2420
#   DNA size: 0 bp
#   GC content: 60.01%
# Loading genome: Syner-01.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1415
#   DNA size: 0 bp
#   GC content: 59.39%
# Loading genome: Synergistaceae.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7255
#   DNA size: 0 bp
#   GC content: 57.87%
# Loading genome: Syntrophobacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2504
#   DNA size: 0 bp
#   GC content: 57.32%
# Loading genome: Syntrophobacter.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1805
#   DNA size: 0 bp
#   GC content: 57.14%
# Loading genome: Syntrophomonadaceae.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4944
#   DNA size: 0 bp
#   GC content: 48.76%
# Loading genome: Syntrophomonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2933
#   DNA size: 0 bp
#   GC content: 63.37%
# Loading genome: Syntrophomonas.11
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1286
#   DNA size: 0 bp
#   GC content: 45.37%
# Loading genome: Syntrophomonas.19
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10799
#   DNA size: 0 bp
#   GC content: 48.17%
# Loading genome: Syntrophomonas.20
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5384
#   DNA size: 0 bp
#   GC content: 46.90%
# Loading genome: Taibaiella.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1115
#   DNA size: 0 bp
#   GC content: 48.38%
# Loading genome: Terrisporobacter.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 13912
#   DNA size: 0 bp
#   GC content: 30.77%
# Loading genome: Terrisporobacter.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10019
#   DNA size: 0 bp
#   GC content: 38.09%
# Loading genome: Thauera.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8637
#   DNA size: 0 bp
#   GC content: 67.16%
# Loading genome: Thermobrachium.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11114
#   DNA size: 0 bp
#   GC content: 32.80%
# Loading genome: Thermovirga.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8455
#   DNA size: 0 bp
#   GC content: 53.16%
# Loading genome: Thermovirga.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1037
#   DNA size: 0 bp
#   GC content: 55.89%
# Loading genome: Thiobacillus.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3740
#   DNA size: 0 bp
#   GC content: 66.75%
# Loading genome: Thiobacillus.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4054
#   DNA size: 0 bp
#   GC content: 63.04%
# Loading genome: Thiopseudomonas.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3298
#   DNA size: 0 bp
#   GC content: 48.57%
# Loading genome: Tissierella.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9963
#   DNA size: 0 bp
#   GC content: 33.08%
# Loading genome: Turicibacter.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3425
#   DNA size: 0 bp
#   GC content: 45.44%
# Loading genome: UCG-009.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2377
#   DNA size: 0 bp
#   GC content: 52.47%
# Loading genome: UCG-009.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2288
#   DNA size: 0 bp
#   GC content: 48.54%
# Loading genome: UCG-010.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2274
#   DNA size: 0 bp
#   GC content: 62.88%
# Loading genome: Veillonellales-Selenomonadales.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
# ...
# Loading genome: midas_g_109927.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5686
#   DNA size: 0 bp
#   GC content: 56.23%
# Loading genome: midas_g_110683.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3845
#   DNA size: 0 bp
#   GC content: 54.59%
# Loading genome: midas_g_110683.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1332
#   DNA size: 0 bp
#   GC content: 50.69%
# Loading genome: midas_g_110683.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1323
#   DNA size: 0 bp
#   GC content: 48.65%
# Loading genome: midas_g_112372.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2536
#   DNA size: 0 bp
#   GC content: 47.72%
# Loading genome: midas_g_112760.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3851
#   DNA size: 0 bp
#   GC content: 51.75%
# Loading genome: midas_g_112829.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4612
#   DNA size: 0 bp
#   GC content: 59.03%
# Loading genome: midas_g_114295.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5659
#   DNA size: 0 bp
#   GC content: 62.22%
# Loading genome: midas_g_119665.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 895
#   DNA size: 0 bp
#   GC content: 62.61%
# Loading genome: midas_g_12.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2979
#   DNA size: 0 bp
#   GC content: 46.49%
# Loading genome: midas_g_1251.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 20250
#   DNA size: 0 bp
#   GC content: 47.60%
# Loading genome: midas_g_1408.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 862
#   DNA size: 0 bp
#   GC content: 45.36%
# Loading genome: midas_g_1408.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1479
#   DNA size: 0 bp
#   GC content: 48.99%
# Loading genome: midas_g_141.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 893
#   DNA size: 0 bp
#   GC content: 53.91%
# Loading genome: midas_g_15299.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2335
#   DNA size: 0 bp
#   GC content: 44.05%
# Loading genome: midas_g_156.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2279
#   DNA size: 0 bp
#   GC content: 50.74%
# Loading genome: midas_g_156.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1556
#   DNA size: 0 bp
#   GC content: 50.19%
# Loading genome: midas_g_156.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2578
#   DNA size: 0 bp
#   GC content: 44.92%
# Loading genome: midas_g_1737.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2218
#   DNA size: 0 bp
#   GC content: 42.40%
# Loading genome: midas_g_1799.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1099
#   DNA size: 0 bp
#   GC content: 58.53%
# Loading genome: midas_g_1799.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5431
#   DNA size: 0 bp
#   GC content: 52.78%
# Loading genome: midas_g_19.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3272
#   DNA size: 0 bp
#   GC content: 47.99%
# Loading genome: midas_g_1946.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1080
#   DNA size: 0 bp
#   GC content: 54.15%
# Loading genome: midas_g_2022.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2302
#   DNA size: 0 bp
#   GC content: 60.14%
# Loading genome: midas_g_2178.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8328
#   DNA size: 0 bp
#   GC content: 60.95%
# Loading genome: midas_g_21833.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3846
#   DNA size: 0 bp
#   GC content: 62.38%
# Loading genome: midas_g_230.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 635
#   DNA size: 0 bp
#   GC content: 58.22%
# Loading genome: midas_g_249.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4539
#   DNA size: 0 bp
#   GC content: 49.18%
# Loading genome: midas_g_249.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 981
#   DNA size: 0 bp
#   GC content: 49.71%
# Loading genome: midas_g_25828.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5931
#   DNA size: 0 bp
#   GC content: 51.47%
# Loading genome: midas_g_2604.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 11237
#   DNA size: 0 bp
#   GC content: 38.93%
# Loading genome: midas_g_269.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1071
#   DNA size: 0 bp
#   GC content: 70.08%
# Loading genome: midas_g_269.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1165
#   DNA size: 0 bp
#   GC content: 68.34%
# Loading genome: midas_g_2901.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 918
#   DNA size: 0 bp
#   GC content: 52.40%
# Loading genome: midas_g_30443.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2043
#   DNA size: 0 bp
#   GC content: 57.70%
# Loading genome: midas_g_3064.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3019
#   DNA size: 0 bp
#   GC content: 63.49%
# Loading genome: midas_g_31962.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1718
#   DNA size: 0 bp
#   GC content: 29.74%
# Loading genome: midas_g_33659.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5183
#   DNA size: 0 bp
#   GC content: 37.75%
# Loading genome: midas_g_3409.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6098
#   DNA size: 0 bp
#   GC content: 63.39%
# Loading genome: midas_g_34283.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1011
#   DNA size: 0 bp
#   GC content: 68.79%
# Loading genome: midas_g_343.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2928
#   DNA size: 0 bp
#   GC content: 62.66%
# Loading genome: midas_g_3595.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 891
#   DNA size: 0 bp
#   GC content: 44.52%
# Loading genome: midas_g_36215.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7547
#   DNA size: 0 bp
#   GC content: 41.96%
# Loading genome: midas_g_36215.6
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 876
#   DNA size: 0 bp
#   GC content: 33.62%
# Loading genome: midas_g_36376.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1389
#   DNA size: 0 bp
#   GC content: 64.22%
# Loading genome: midas_g_399.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1612
#   DNA size: 0 bp
#   GC content: 67.44%
# Loading genome: midas_g_399.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1297
#   DNA size: 0 bp
#   GC content: 67.09%
# Loading genome: midas_g_399.5
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1305
#   DNA size: 0 bp
#   GC content: 66.01%
# Loading genome: midas_g_4042.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3389
#   DNA size: 0 bp
#   GC content: 58.73%
# Loading genome: midas_g_410.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1542
#   DNA size: 0 bp
#   GC content: 46.78%
# Loading genome: midas_g_4301.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1019
#   DNA size: 0 bp
#   GC content: 48.72%
# Loading genome: midas_g_4306.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 959
#   DNA size: 0 bp
#   GC content: 55.55%
# Loading genome: midas_g_497.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2219
#   DNA size: 0 bp
#   GC content: 69.59%
# Loading genome: midas_g_49937.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3345
#   DNA size: 0 bp
#   GC content: 64.29%
# Loading genome: midas_g_515.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1942
#   DNA size: 0 bp
#   GC content: 56.65%
# Loading genome: midas_g_52.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3384
#   DNA size: 0 bp
#   GC content: 65.76%
# Loading genome: midas_g_52206.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1088
#   DNA size: 0 bp
#   GC content: 40.18%
# Loading genome: midas_g_531.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 815
#   DNA size: 0 bp
#   GC content: 62.73%
# Loading genome: midas_g_5426.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 867
#   DNA size: 0 bp
#   GC content: 57.80%
# Loading genome: midas_g_554.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3244
#   DNA size: 0 bp
#   GC content: 50.99%
# Loading genome: midas_g_55650.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1558
#   DNA size: 0 bp
#   GC content: 50.60%
# Loading genome: midas_g_5574.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2327
#   DNA size: 0 bp
#   GC content: 66.38%
# Loading genome: midas_g_5574.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2128
#   DNA size: 0 bp
#   GC content: 68.06%
# Loading genome: midas_g_57.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 43
#   DNA size: 0 bp
#   GC content: 60.85%
# Loading genome: midas_g_5834.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5093
#   DNA size: 0 bp
#   GC content: 59.00%
# Loading genome: midas_g_6187.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5393
#   DNA size: 0 bp
#   GC content: 60.17%
# Loading genome: midas_g_63015.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9371
#   DNA size: 0 bp
#   GC content: 50.35%
# Loading genome: midas_g_63491.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7691
#   DNA size: 0 bp
#   GC content: 54.63%
# Loading genome: midas_g_667.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1368
#   DNA size: 0 bp
#   GC content: 62.57%
# Loading genome: midas_g_669.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 7940
#   DNA size: 0 bp
#   GC content: 48.80%
# Loading genome: midas_g_70.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3947
#   DNA size: 0 bp
#   GC content: 64.01%
# Loading genome: midas_g_70329.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1669
#   DNA size: 0 bp
#   GC content: 46.87%
# Loading genome: midas_g_73510.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3554
#   DNA size: 0 bp
#   GC content: 47.49%
# Loading genome: midas_g_75.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3772
#   DNA size: 0 bp
#   GC content: 62.21%
# Loading genome: midas_g_75908.12
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3214
#   DNA size: 0 bp
#   GC content: 36.44%
# Loading genome: midas_g_75908.13
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1960
#   DNA size: 0 bp
#   GC content: 40.24%
# Loading genome: midas_g_75908.4
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3069
#   DNA size: 0 bp
#   GC content: 32.62%
# Loading genome: midas_g_75908.7
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 8874
#   DNA size: 0 bp
#   GC content: 35.29%
# Loading genome: midas_g_76028.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6408
#   DNA size: 0 bp
#   GC content: 52.26%
# Loading genome: midas_g_76594.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 17375
#   DNA size: 0 bp
#   GC content: 43.10%
# Loading genome: midas_g_76603.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 988
#   DNA size: 0 bp
#   GC content: 54.81%
# Loading genome: midas_g_77817.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1283
#   DNA size: 0 bp
#   GC content: 48.58%
# Loading genome: midas_g_8129.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6873
#   DNA size: 0 bp
#   GC content: 59.04%
# Loading genome: midas_g_82137.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6560
#   DNA size: 0 bp
#   GC content: 59.01%
# Loading genome: midas_g_82137.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2920
#   DNA size: 0 bp
#   GC content: 57.70%
# Loading genome: midas_g_83754.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3730
#   DNA size: 0 bp
#   GC content: 39.76%
# Loading genome: midas_g_84729.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 724
#   DNA size: 0 bp
#   GC content: 64.45%
# Loading genome: midas_g_85764.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4934
#   DNA size: 0 bp
#   GC content: 47.99%
# Loading genome: midas_g_9023.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2056
#   DNA size: 0 bp
#   GC content: 50.02%
# Loading genome: midas_g_91392.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1162
#   DNA size: 0 bp
#   GC content: 61.43%
# Loading genome: midas_g_92370.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 9090
#   DNA size: 0 bp
#   GC content: 56.15%
# Loading genome: midas_g_9269.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 309
#   DNA size: 0 bp
#   GC content: 43.02%
# Loading genome: midas_g_93128.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 6541
#   DNA size: 0 bp
#   GC content: 47.64%
# Loading genome: midas_g_93451.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 1138
#   DNA size: 0 bp
#   GC content: 40.34%
# Loading genome: midas_g_93469.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5754
#   DNA size: 0 bp
#   GC content: 60.25%
# Loading genome: midas_g_94288.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 3331
#   DNA size: 0 bp
#   GC content: 35.65%
# Loading genome: midas_g_97311.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 10806
#   DNA size: 0 bp
#   GC content: 46.81%
# Loading genome: midas_g_97727.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 5920
#   DNA size: 0 bp
#   GC content: 46.72%
# Loading genome: midas_g_97954.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 17743
#   DNA size: 0 bp
#   GC content: 41.77%
# Loading genome: midas_g_97954.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12951
#   DNA size: 0 bp
#   GC content: 44.62%
# Loading genome: midas_g_97954.3
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 12840
#   DNA size: 0 bp
#   GC content: 41.31%
# Loading genome: midas_g_98017.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 4112
#   DNA size: 0 bp
#   GC content: 49.85%
# Loading genome: midas_g_98017.2
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2515
#   DNA size: 0 bp
#   GC content: 56.86%
# Loading genome: midas_g_98124.1
#   Scientific name: Bacteria
#   Taxonomy: Bacteria...
#   Features: 2891
#   DNA size: 0 bp
#   GC content: 41.54%
# Summary exported to genome_summary.tsv
#
# Genome summary table (459 genomes):
#              genome_id scientific_name    domain  taxonomy  num_features  \
# 0    Acetoanaerobium.1        Bacteria  Bacteria  Bacteria          2595
# 1     Acetobacterium.1        Bacteria  Bacteria  Bacteria          3320
# 2       Acholeplasma.2        Bacteria  Bacteria  Bacteria           655
# 3      Achromobacter.1        Bacteria  Bacteria  Bacteria         18009
# 4      Achromobacter.2        Bacteria  Bacteria  Bacteria          5728
# ..                 ...             ...       ...       ...           ...
# 454    midas_g_97954.2        Bacteria  Bacteria  Bacteria         12951
# 455    midas_g_97954.3        Bacteria  Bacteria  Bacteria         12840
# 456    midas_g_98017.1        Bacteria  Bacteria  Bacteria          4112
# 457    midas_g_98017.2        Bacteria  Bacteria  Bacteria          2515
# 458    midas_g_98124.1        Bacteria  Bacteria  Bacteria          2891
#
#      num_cdss  dna_size  gc_content  num_contigs
# 0        2595         0      0.3961         2595
# 1        3320         0      0.4258         3320
# 2         655         0      0.3913          655
# 3       18009         0      0.6553        18009
# 4        5728         0      0.6592         5728
# ..        ...       ...         ...          ...
# 454     12951         0      0.4462        12951
# 455     12840         0      0.4131        12840
# 456      4112         0      0.4985         4112
# 457      2515         0      0.5686         2515
# 458      2891         0      0.4154         2891
#
# [459 rows x 9 columns]

# %% [markdown]
# ### Visualize genome statistics

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 10))

# DNA size distribution
# axes[0, 0].hist(df['dna_size'] / 1e6, bins=20, edgecolor='black')
# axes[0, 0].set_xlabel('Genome Size (Mbp)')
# axes[0, 0].set_ylabel('Count')
# axes[0, 0].set_title('Distribution of Genome Sizes')

# GC content distribution
axes[0].hist(df['gc_content'] * 100, bins=20, edgecolor='black', color='green')
axes[0].set_xlabel('GC Content (%)')
axes[0].set_ylabel('Count')
axes[0].set_title('Distribution of GC Content')

# Number of features
axes[1].hist(df['num_features'], bins=20, edgecolor='black', color='orange')
axes[1].set_xlabel('Number of Features')
axes[1].set_ylabel('Number of genomes')
axes[1].set_title('Distribution of Feature Counts')

# Domain distribution
# domain_counts = df['domain'].value_counts()
# axes[1, 1].pie(domain_counts.values, labels=domain_counts.index, autopct='%1.1f%%')
# axes[1, 1].set_title('Distribution by Domain')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Create MSGenome Objects
#
# Convert KBase genomes to ModelSEEDpy MSGenome objects:

# %%
# Create MSGenome object
genome_id = 'Acetobacterium.1'
msgenome = get_msgenome(genome_id)

print(f"MSGenome created for {genome_id}")
print(f"  ID: {msgenome.id}")
print(f"  Features: {len(msgenome.features)}")

# %% [markdown]
# ## 6. Build Metabolic Models
#
# Build genome-scale metabolic models using ModelSEEDpy:

# %%
# Build a metabolic model
genome_id = 'Acetobacterium.1'
model = build_model(genome_id, template='GramPositive')

print(f"\nModel statistics:")
print(f"  Reactions: {len(model.reactions)}")
print(f"  Metabolites: {len(model.metabolites)}")
print(f"  Genes: {len(model.genes)}")

# %% [markdown]
# ### Test the model with FBA

# %%
# Run flux balance analysis
solution = model.optimize()

print(f"Optimization status: {solution.status}")
if solution.status == 'optimal':
    print(f"Objective value: {solution.objective_value:.4f}")
    print(f"\nTop 10 fluxes:")
    fluxes = solution.fluxes.abs().sort_values(ascending=False)
    for rxn_id, flux in fluxes.head(10).items():
        rxn = model.reactions.get_by_id(rxn_id)
        print(f"  {rxn_id}: {flux:.3f} - {rxn.name}")
else:
    print("Model may need gap-filling to achieve growth")

# %% [markdown]
# ### Save the model

# %%
# Save model to SBML file
from cobra.io import write_sbml_model

output_file = f"{genome_id}_model.xml"
write_sbml_model(model, output_file)
print(f"Model saved to {output_file}")

# %% [markdown]
# ## 7. Batch Process Multiple Genomes
#
# Build models for multiple genomes:

# %%
# Select a few genomes to process
genome_ids_to_process = list_available_genomes()[:5]

print(f"Building models for {len(genome_ids_to_process)} genomes...\n")

models = {}
for genome_id in genome_ids_to_process:
    try:
        print(f"Processing {genome_id}...")
        model = build_model(genome_id)
        models[genome_id] = model
        
        # Test optimization
        solution = model.optimize()
        print(f"  Status: {solution.status}")
        if solution.status == 'optimal':
            print(f"  Growth: {solution.objective_value:.4f}")
        print()
        
    except Exception as e:
        print(f"  Error: {e}\n")
        continue

print(f"Successfully built {len(models)} models")

# %% [markdown]
# ## 8. Advanced: Genome Comparison
#
# Compare features across multiple genomes:

# %%
# Load a few genomes for comparison
comparison_genomes = {gid: load_genome(gid) for gid in list_available_genomes()[:5]}

# Collect all unique functions
all_functions = set()
for genome in comparison_genomes.values():
    for feature in genome['features']:
        all_functions.update(feature.get('functions', []))

print(f"Total unique functions across {len(comparison_genomes)} genomes: {len(all_functions)}")

# Create presence/absence matrix
function_matrix = {}
for func in list(all_functions)[:20]:  # Just first 20 for display
    function_matrix[func] = {}
    for genome_id, genome in comparison_genomes.items():
        # Check if this function exists in the genome
        has_function = any(
            func in feature.get('functions', [])
            for feature in genome['features']
        )
        function_matrix[func][genome_id] = 1 if has_function else 0

# Convert to DataFrame
comparison_df = pd.DataFrame(function_matrix).T
print("\nFunction presence/absence matrix (1 = present, 0 = absent):")
comparison_df

# %% [markdown]
# ## Summary
#
# This notebook demonstrated how to:
# 1. List available genome objects
# 2. Load individual or all genomes
# 3. Inspect genome structure and features
# 4. Create summary tables and visualizations
# 5. Convert to ModelSEEDpy MSGenome objects
# 6. Build and analyze metabolic models
# 7. Batch process multiple genomes
# 8. Compare genomes
#
# For more information, see:
# - `load_genomes_to_modelseedpy.py` - Main loading utilities
# - `example_load_genomes.py` - Additional examples
# - ModelSEEDpy documentation: https://github.com/ModelSEED/ModelSEEDpy
